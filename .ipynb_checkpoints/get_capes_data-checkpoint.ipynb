# %% [markdown]
# ## Using selenium and pandas

# %% [markdown]
# ### Humanities

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os, time
import pandas as pd

# os.environ["CHROMEDRIVER_PATH"] = "/chromedriver"
# os.environ["GOOGLE_CHROME_BIN"] = "/usr/bin/google-chrome"
# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary_location = os.environ.get("GOOGLE_CHROME_BIN")
# driver = webdriver.Chrome(executable_path=os.environ.get("CHROMEDRIVER_PATH"), chrome_options=chrome_options)
# dir_path = os.path.dirname(os.path.abspath(''))
driver = webdriver.Chrome(executable_path='/home/nicole/Documents/Docs/UCSD/SP21/CSE 194/CSE_194_Project/chromedriver')
driver.implicitly_wait(30)

driver.get('https://cape.ucsd.edu/responses/Results.aspx')
sso_id = driver.find_element_by_id('ssousername')
sso_id.send_keys("nmartind")
pw = driver.find_element_by_id('ssopassword')
pw.send_keys("") #insert password

login = driver.find_element_by_name('_eventId_proceed')
login.send_keys(Keys.ENTER)
time.sleep(15)

#once logged in, select department
dept = driver.find_element_by_id('ContentPlaceHolder1_ddlDepartments')
for option in dept.find_elements_by_tag_name('option'):
    if option.get_attribute("value") == 'HUM ': #different department name here
        option.click() 
        break

driver.find_element_by_id('ContentPlaceHolder1_btnSubmit').click()
driver.implicitly_wait(15)


profs = {}

#populate dict with prof names and link to each of the classes they've taught
table_id = driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs')
tbody = table_id.find_element_by_tag_name('tbody')
rows = tbody.find_elements_by_tag_name("tr")
for row in rows:
    prof = (row.find_elements_by_tag_name("td")[0]).text
    course = (row.find_elements_by_tag_name("td")[1]).find_element_by_tag_name("a").get_attribute("href")
    if prof in profs:
        profs[prof].append(course)
    else:
        profs[prof] = [course]
    
'''
# get table
df=pd.read_html(driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs').get_attribute('outerHTML'))[0] 

#extract columns
df2 = df[['Instructor','Course', 'Term', 'Enroll', 'Evals Made', 'Rcmnd Class', 'Rcmnd Instr', 'Study Hrs/wk', 'Avg Grade Expected', 'Avg Grade Received']] #fix

#convert to csv
#f2.to_csv('hum_capes.csv', index=False)
'''


print("DONE w first dict")

prof_dict1 = {}
prof_dict2 = {}


#iterating through profs dict
for name, link_arr in profs.items():
    #for each link, click full details
    for link in link_arr:
        driver.get(link)
        try:
            button = driver.find_element_by_id("btnClick")
            button.click()

            #get proficiency mean score and add them to dict 1 for that prof
            proficient_mean = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_16").text
            if name in prof_dict1:
                prof_dict1[name].append(proficient_mean)
            else:
                prof_dict1[name] = [proficient_mean]

            #get explaining material well mean score and add them to dict 2 for that prof
            prof_material = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_19").text
            if name in prof_dict2:
                prof_dict2[name].append(prof_material)
            else:
                prof_dict2[name] = [prof_material]
        except:
            print("differently formatted")
            break

print("DONE")
# Out:
# DONE w first dict
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# DONE

# %%
import numpy as np

prof_means1 = {}
prof_means2 = {}

for name, means in prof_dict1.items():
    means_int = [float(numeric_string) for numeric_string in means]
    prof_means1[name] = np.mean(means_int)
    
for name, means in prof_dict2.items():
    means_int = [float(numeric_string) for numeric_string in means]
    prof_means2[name] = np.mean(means_int)

# %%
prof_means1
# Out:
# {'Chodorow, Stanley A.': 4.430666666666666,
#  'Markman, Kristina': 4.6375,
#  'Lyon, Antony J.': 4.7165625,
#  'Cox, Stephen D.': 4.609999999999999,
#  'Giordano, Kailey Nicole': 4.705714285714286,
#  'Kontje, Todd Curtis': 4.448571428571428,
#  'Watkins, Eric': 4.44125,
#  'West, Geoffrey Scott': 4.52,
#  'Patterson, Patrick H.': 4.63,
#  'Zroka, Amy Liane': 4.338571428571429,
#  'Boettcher, Carolin': 4.0,
#  'Thompson, Katherine Anne Merit': 4.785,
#  'Caldwell, Michael Alan': 4.82,
#  'Tronzo, William': 4.890000000000001,
#  'Watts, Edward J.': 4.628571428571428,
#  'Demetriou, Denise': 4.355,
#  'Greene, Blythe Anastasia': 4.35,
#  'Smarr, Janet L.': 4.375,
#  'Parrish, Michael E.': 4.454000000000001,
#  'Lerer, Seth': 4.7425,
#  'Johnson, Monte': 4.41,
#  'Henderson, David Kenneth': 4.563333333333333,
#  'Herbst, Matthew': 4.87,
#  'Cassedy, Steven Dennis': 4.596,
#  'Caciola, Nancy A': 4.595,
#  "O'Brien, William Arctander": 4.583333333333333,
#  'Solomon, Amanda Lee Albaniel': 4.69,
#  'Jed, Stephanie H': 4.916666666666667,
#  'Lee, John Hoon': 4.6338888888888885,
#  'Edwards, Anthony': 4.495,
#  'Zroka, Ryan Edward': 4.48,
#  'Marino, John A.': 4.755,
#  'Lundell, Michael J': 4.64}

# %%
prof_means2
# Out:
# {'Chodorow, Stanley A.': 4.008,
#  'Markman, Kristina': 4.564166666666667,
#  'Lyon, Antony J.': 4.6203125,
#  'Cox, Stephen D.': 4.351111111111112,
#  'Giordano, Kailey Nicole': 4.6899999999999995,
#  'Kontje, Todd Curtis': 4.261428571428572,
#  'Watkins, Eric': 4.24,
#  'West, Geoffrey Scott': 4.36,
#  'Patterson, Patrick H.': 4.466666666666667,
#  'Zroka, Amy Liane': 4.121428571428571,
#  'Boettcher, Carolin': 3.7,
#  'Thompson, Katherine Anne Merit': 4.7375,
#  'Caldwell, Michael Alan': 4.796875,
#  'Tronzo, William': 4.8100000000000005,
#  'Watts, Edward J.': 4.547142857142857,
#  'Demetriou, Denise': 3.86,
#  'Greene, Blythe Anastasia': 4.3,
#  'Smarr, Janet L.': 3.9825,
#  'Parrish, Michael E.': 4.258,
#  'Lerer, Seth': 4.6325,
#  'Johnson, Monte': 4.0649999999999995,
#  'Henderson, David Kenneth': 4.3,
#  'Herbst, Matthew': 4.78,
#  'Cassedy, Steven Dennis': 4.2620000000000005,
#  'Caciola, Nancy A': 4.483333333333333,
#  "O'Brien, William Arctander": 4.3566666666666665,
#  'Solomon, Amanda Lee Albaniel': 4.7325,
#  'Jed, Stephanie H': 4.67,
#  'Lee, John Hoon': 4.500555555555556,
#  'Edwards, Anthony': 4.175,
#  'Zroka, Ryan Edward': 4.51,
#  'Marino, John A.': 4.205,
#  'Lundell, Michael J': 4.44}

# %%
d = {'Proficiency of Material Means': prof_means1, 'Explaining Material Well Means': prof_means2}
df = pd.DataFrame(data=d)

# %%
df
# Out:
#                                 Proficiency of Material Means  \
# Chodorow, Stanley A.                                 4.430667
# Markman, Kristina                                    4.637500
# Lyon, Antony J.                                      4.716563
# Cox, Stephen D.                                      4.610000
# Giordano, Kailey Nicole                              4.705714
# Kontje, Todd Curtis                                  4.448571
# Watkins, Eric                                        4.441250
# West, Geoffrey Scott                                 4.520000
# Patterson, Patrick H.                                4.630000
# Zroka, Amy Liane                                     4.338571
# Boettcher, Carolin                                   4.000000
# Thompson, Katherine Anne Merit                       4.785000
# Caldwell, Michael Alan                               4.820000
# Tronzo, William                                      4.890000
# Watts, Edward J.                                     4.628571
# Demetriou, Denise                                    4.355000
# Greene, Blythe Anastasia                             4.350000
# Smarr, Janet L.                                      4.375000
# Parrish, Michael E.                                  4.454000
# Lerer, Seth                                          4.742500
# Johnson, Monte                                       4.410000
# Henderson, David Kenneth                             4.563333
# Herbst, Matthew                                      4.870000
# Cassedy, Steven Dennis                               4.596000
# Caciola, Nancy A                                     4.595000
# O'Brien, William Arctander                           4.583333
# Solomon, Amanda Lee Albaniel                         4.690000
# Jed, Stephanie H                                     4.916667
# Lee, John Hoon                                       4.633889
# Edwards, Anthony                                     4.495000
# Zroka, Ryan Edward                                   4.480000
# Marino, John A.                                      4.755000
# Lundell, Michael J                                   4.640000
#
#                                 Explaining Material Well Means
# Chodorow, Stanley A.                                  4.008000
# Markman, Kristina                                     4.564167
# Lyon, Antony J.                                       4.620312
# Cox, Stephen D.                                       4.351111
# Giordano, Kailey Nicole                               4.690000
# Kontje, Todd Curtis                                   4.261429
# Watkins, Eric                                         4.240000
# West, Geoffrey Scott                                  4.360000
# Patterson, Patrick H.                                 4.466667
# Zroka, Amy Liane                                      4.121429
# Boettcher, Carolin                                    3.700000
# Thompson, Katherine Anne Merit                        4.737500
# Caldwell, Michael Alan                                4.796875
# Tronzo, William                                       4.810000
# Watts, Edward J.                                      4.547143
# Demetriou, Denise                                     3.860000
# Greene, Blythe Anastasia                              4.300000
# Smarr, Janet L.                                       3.982500
# Parrish, Michael E.                                   4.258000
# Lerer, Seth                                           4.632500
# Johnson, Monte                                        4.065000
# Henderson, David Kenneth                              4.300000
# Herbst, Matthew                                       4.780000
# Cassedy, Steven Dennis                                4.262000
# Caciola, Nancy A                                      4.483333
# O'Brien, William Arctander                            4.356667
# Solomon, Amanda Lee Albaniel                          4.732500
# Jed, Stephanie H                                      4.670000
# Lee, John Hoon                                        4.500556
# Edwards, Anthony                                      4.175000
# Zroka, Ryan Edward                                    4.510000
# Marino, John A.                                       4.205000
# Lundell, Michael J                                    4.440000

# %%
df.to_csv('hum_means.csv')

# %% [markdown]
# ### Computer Science

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os, time
import pandas as pd

# os.environ["CHROMEDRIVER_PATH"] = "/chromedriver"
# os.environ["GOOGLE_CHROME_BIN"] = "/usr/bin/google-chrome"
# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary_location = os.environ.get("GOOGLE_CHROME_BIN")
# driver = webdriver.Chrome(executable_path=os.environ.get("CHROMEDRIVER_PATH"), chrome_options=chrome_options)
# dir_path = os.path.dirname(os.path.abspath(''))
driver = webdriver.Chrome(executable_path='/home/nicole/Documents/Docs/UCSD/SP21/CSE 194/CSE_194_Project/chromedriver')
driver.implicitly_wait(30)

driver.get('https://cape.ucsd.edu/responses/Results.aspx')
sso_id = driver.find_element_by_id('ssousername')
sso_id.send_keys("nmartind")
pw = driver.find_element_by_id('ssopassword')
pw.send_keys("") #insert password

login = driver.find_element_by_name('_eventId_proceed')
login.send_keys(Keys.ENTER)
time.sleep(15)

#once logged in, select department
dept = driver.find_element_by_id('ContentPlaceHolder1_ddlDepartments')
for option in dept.find_elements_by_tag_name('option'):
    if option.get_attribute("value") == 'CSE': #different department name here
        option.click() 
        break

driver.find_element_by_id('ContentPlaceHolder1_btnSubmit').click()
driver.implicitly_wait(15)


profs = {}

#populate dict with prof names and link to each of the classes they've taught
table_id = driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs')
tbody = table_id.find_element_by_tag_name('tbody')
rows = tbody.find_elements_by_tag_name("tr")
for row in rows:
    prof = (row.find_elements_by_tag_name("td")[0]).text
    course = (row.find_elements_by_tag_name("td")[1]).find_element_by_tag_name("a").get_attribute("href")
    if prof in profs:
        profs[prof].append(course)
    else:
        profs[prof] = [course]
    
'''
# get table
df=pd.read_html(driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs').get_attribute('outerHTML'))[0] 

#extract columns
df2 = df[['Instructor','Course', 'Term', 'Enroll', 'Evals Made', 'Rcmnd Class', 'Rcmnd Instr', 'Study Hrs/wk', 'Avg Grade Expected', 'Avg Grade Received']] #fix

#convert to csv
#f2.to_csv('hum_capes.csv', index=False)
'''


print("DONE w first dict")

prof_dict1 = {}
prof_dict2 = {}


#iterating through profs dict
for name, link_arr in profs.items():
    #for each link, click full details
    for link in link_arr:
        driver.get(link)
        try:
            button = driver.find_element_by_id("btnClick")
            button.click()

            #get proficiency mean score and add them to dict 1 for that prof
            proficient_mean = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_16").text
            if name in prof_dict1:
                prof_dict1[name].append(proficient_mean)
            else:
                prof_dict1[name] = [proficient_mean]

            #get explaining material well mean score and add them to dict 2 for that prof
            prof_material = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_19").text
            if name in prof_dict2:
                prof_dict2[name].append(prof_material)
            else:
                prof_dict2[name] = [prof_material]
        except:
            print("differently formatted")
            break

print("DONE")
# Out:
# DONE w first dict
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# DONE

# %%
prof_dict1
# Out:
# {'Moshiri, Alexander Niema': ['4.81',
#   '4.80',
#   '4.76',
#   '4.57',
#   '4.68',
#   '4.75',
#   '4.61'],
#  'Kane, Daniel Mertz': ['4.79',
#   '4.90',
#   '4.87',
#   '4.73',
#   '4.74',
#   '4.50',
#   '4.65'],
#  'Jones, Miles E': ['4.65',
#   '4.45',
#   '4.48',
#   '4.46',
#   '4.57',
#   '4.92',
#   '4.66',
#   '4.71',
#   '4.68',
#   '4.28',
#   '4.39',
#   '4.49',
#   '4.30',
#   '4.54',
#   '4.41',
#   '4.06',
#   '4.04',
#   '4.31',
#   '4.48',
#   '4.26',
#   '4.23',
#   '4.59',
#   '4.23',
#   '4.03',
#   '4.19',
#   '4.11',
#   '4.22',
#   '4.08',
#   '4.00',
#   '4.17',
#   '4.37',
#   '4.67',
#   '4.10',
#   '3.92',
#   '4.39',
#   '4.49',
#   '3.71',
#   '4.12',
#   '4.24',
#   '4.19',
#   '4.29',
#   '4.17',
#   '3.85',
#   '3.95',
#   '4.15',
#   '4.30',
#   '4.08'],
#  'Meyer, Kyle Phillip': ['3.86', '4.20', '4.17', '4.02'],
#  'Cao, Yingjun': ['4.58',
#   '4.48',
#   '4.68',
#   '4.78',
#   '4.74',
#   '4.53',
#   '4.71',
#   '4.68',
#   '4.55',
#   '4.45',
#   '4.66',
#   '4.65',
#   '4.41',
#   '4.68',
#   '4.67',
#   '4.71',
#   '4.50',
#   '4.68',
#   '4.49',
#   '4.46',
#   '4.71',
#   '4.19',
#   '4.37',
#   '4.52',
#   '4.61',
#   '4.64',
#   '4.34',
#   '4.43',
#   '4.59',
#   '4.40',
#   '4.30',
#   '4.56',
#   '4.64',
#   '4.49',
#   '4.78',
#   '4.74',
#   '4.74',
#   '4.58',
#   '4.67',
#   '4.65',
#   '4.70',
#   '4.47',
#   '4.60',
#   '4.63',
#   '4.71',
#   '4.61',
#   '4.63',
#   '4.67',
#   '4.75',
#   '4.61',
#   '4.45',
#   '4.53',
#   '4.68',
#   '4.51',
#   '4.59',
#   '4.62',
#   '4.60',
#   '4.54',
#   '4.66',
#   '4.60'],
#  'Powell, Thomas Allan': ['4.17',
#   '4.38',
#   '4.73',
#   '4.45',
#   '4.14',
#   '5.00',
#   '4.19',
#   '4.54',
#   '4.17',
#   '4.63',
#   '4.48',
#   '4.42',
#   '4.59',
#   '4.89',
#   '5.00',
#   '4.81',
#   '4.67',
#   '4.76',
#   '4.60',
#   '4.48',
#   '4.88',
#   '5.00',
#   '4.82',
#   '4.76',
#   '4.35',
#   '4.52',
#   '4.61',
#   '4.65',
#   '4.70',
#   '4.79',
#   '4.77',
#   '4.92',
#   '4.71'],
#  'Gillespie, Gary N': ['4.55',
#   '4.26',
#   '4.50',
#   '4.06',
#   '4.26',
#   '4.23',
#   '4.27',
#   '4.32',
#   '4.27',
#   '4.33',
#   '4.43',
#   '4.67',
#   '4.09',
#   '3.70',
#   '4.36',
#   '4.32',
#   '4.24',
#   '4.88',
#   '3.42',
#   '4.60',
#   '4.63',
#   '4.41',
#   '4.22',
#   '3.61',
#   '4.13',
#   '4.28',
#   '3.98',
#   '3.69',
#   '4.59',
#   '4.28',
#   '4.56',
#   '4.23',
#   '4.07',
#   '4.31',
#   '3.77',
#   '3.83',
#   '4.05',
#   '4.19',
#   '4.50',
#   '4.00',
#   '4.39',
#   '4.49',
#   '3.98',
#   '4.22',
#   '4.25',
#   '4.58',
#   '3.74',
#   '4.24',
#   '4.44',
#   '4.40',
#   '4.71',
#   '4.68',
#   '4.19',
#   '4.25',
#   '4.44',
#   '4.67',
#   '4.57',
#   '4.47',
#   '4.25',
#   '4.19',
#   '4.67',
#   '4.18',
#   '4.77',
#   '4.64',
#   '4.29',
#   '4.02',
#   '4.83',
#   '4.67',
#   '4.04',
#   '4.71',
#   '5.00',
#   '4.60',
#   '4.13',
#   '4.18',
#   '4.35',
#   '4.36',
#   '4.29',
#   '4.34',
#   '4.67',
#   '4.24',
#   '4.34',
#   '4.80',
#   '4.14',
#   '4.60',
#   '4.59',
#   '4.54',
#   '4.37',
#   '4.42',
#   '4.43',
#   '4.34',
#   '4.43',
#   '4.25',
#   '4.01',
#   '4.43',
#   '4.33',
#   '3.94',
#   '3.89',
#   '4.03',
#   '4.82',
#   '3.90',
#   '4.30',
#   '4.13',
#   '4.00',
#   '4.57'],
#  'Miranda, Gregory Joseph': ['4.43',
#   '4.53',
#   '4.41',
#   '4.43',
#   '4.49',
#   '4.49',
#   '4.30',
#   '4.67',
#   '4.42',
#   '4.67',
#   '4.42',
#   '4.43',
#   '4.27',
#   '4.67',
#   '4.85',
#   '4.50',
#   '4.60',
#   '4.83',
#   '5.00',
#   '4.10'],
#  'Pasquale, Joseph': ['4.75',
#   '4.77',
#   '4.55',
#   '4.86',
#   '4.80',
#   '4.69',
#   '5.00',
#   '5.00',
#   '4.95',
#   '4.84',
#   '4.76',
#   '4.79',
#   '4.74',
#   '4.81',
#   '4.72',
#   '4.78',
#   '4.87',
#   '4.45',
#   '4.83',
#   '4.80',
#   '4.84',
#   '4.84',
#   '4.67',
#   '4.55',
#   '4.82',
#   '4.91',
#   '4.82',
#   '5.00',
#   '5.00',
#   '4.75',
#   '4.70',
#   '4.78'],
#  'Snoeren, Alex C.': ['4.54',
#   '4.64',
#   '4.79',
#   '4.60',
#   '4.68',
#   '5.00',
#   '4.87',
#   '4.74',
#   '4.50',
#   '4.71',
#   '4.78'],
#  'Heninger, Nadia A': ['4.61', '4.43'],
#  'Jhala, Ranjit': ['4.77',
#   '4.58',
#   '4.67',
#   '4.65',
#   '4.67',
#   '4.58',
#   '4.59',
#   '4.48',
#   '4.79',
#   '4.31',
#   '4.40',
#   '3.72',
#   '4.65',
#   '4.23'],
#  'Vianu, Victor Dan': ['4.44',
#   '4.56',
#   '4.30',
#   '4.48',
#   '4.54',
#   '4.46',
#   '4.22',
#   '4.16',
#   '4.25',
#   '4.33',
#   '4.52',
#   '4.26',
#   '4.56',
#   '4.64'],
#  'Rosing, Tajana Simunic': ['4.41',
#   '4.58',
#   '4.67',
#   '4.61',
#   '4.63',
#   '4.50',
#   '4.52',
#   '4.53',
#   '4.45',
#   '4.29',
#   '4.43',
#   '4.57'],
#  'Eldon, John': [' ',
#   ' ',
#   ' ',
#   '4.56',
#   ' ',
#   '4.36',
#   ' ',
#   '4.00',
#   ' ',
#   ' ',
#   ' ',
#   '4.44',
#   ' ',
#   '4.40',
#   ' ',
#   ' ',
#   '4.13',
#   ' ',
#   '4.06',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   ' ',
#   '4.70',
#   '4.38',
#   '4.40',
#   '4.53',
#   '4.33',
#   '4.54',
#   '3.83',
#   '4.53',
#   '4.37',
#   '4.48',
#   '4.56',
#   '4.33',
#   '4.36',
#   '4.33',
#   '4.44',
#   '4.59',
#   '4.44',
#   '4.42',
#   '4.62',
#   '4.17',
#   '4.33',
#   '4.41',
#   '4.60',
#   '4.50',
#   '4.12',
#   '4.50',
#   '4.44'],
#  'Chin, Bryan W.': ['4.45',
#   '4.38',
#   '4.50',
#   '3.33',
#   '4.54',
#   '4.64',
#   '4.50',
#   '4.69',
#   '4.18',
#   '4.26',
#   '4.39'],
#  'Chaudhuri, Kamalika': ['4.56',
#   '4.54',
#   '4.41',
#   '4.78',
#   '4.62',
#   '4.53',
#   '4.44',
#   '4.53',
#   '4.53',
#   '4.36'],
#  'Ochoa, Benjamin Lawrence': ['4.76',
#   '4.75',
#   '4.62',
#   '4.40',
#   '4.47',
#   '4.45',
#   '4.45',
#   '5.00',
#   '4.61',
#   '4.34',
#   '4.36',
#   '4.84',
#   '4.51',
#   '4.68',
#   '4.56',
#   '4.55',
#   '4.59',
#   '4.08'],
#  'Muller, P Keith': ['4.31', '4.55', '4.53', '4.80'],
#  'Schulze, Jurgen P.': ['4.88',
#   '4.66',
#   '5.00',
#   '4.48',
#   '4.86',
#   '4.77',
#   '4.46',
#   '4.78',
#   '4.88',
#   '4.63',
#   '4.50',
#   '4.88',
#   '4.70',
#   '4.45',
#   '4.76',
#   '4.70',
#   '4.59',
#   '4.61',
#   '4.66',
#   '4.88',
#   '4.61',
#   '4.94',
#   '4.84'],
#  'Chern, Albert Ren-Haur': ['4.39'],
#  'Rotenberg, Steven Paul': ['4.59',
#   '4.79',
#   '5.00',
#   '4.81',
#   '4.67',
#   '4.91',
#   '4.85',
#   '4.93',
#   '4.83',
#   '4.77'],
#  'Klemmer, Scott R': ['3.29',
#   '3.17',
#   '3.25',
#   '4.22',
#   '4.48',
#   '4.65',
#   '4.45',
#   '4.37'],
#  'Swanson, Steven James': ['4.20',
#   '4.48',
#   '4.71',
#   '4.29',
#   '4.62',
#   '4.19',
#   '5.00',
#   '4.88',
#   '4.46',
#   '4.63',
#   '4.71',
#   '4.67',
#   '4.33',
#   '4.64',
#   '4.67',
#   '4.60',
#   '4.60',
#   '5.00',
#   '4.75',
#   '4.86',
#   '4.75',
#   '4.46',
#   '4.29',
#   '4.46',
#   '4.71'],
#  'Pevzner, Pavel Arkadjevich': ['5.00',
#   '4.75',
#   '4.83',
#   '4.67',
#   '4.54',
#   '4.20',
#   '4.80',
#   '5.00',
#   '4.80'],
#  'Shalev, Aaron D': ['4.94', '4.57', '4.77', '4.09', '5.00'],
#  'Soosai Raj, Adalbert Geral': ['4.89',
#   '4.65',
#   '4.77',
#   '4.75',
#   '4.48',
#   '4.82',
#   '4.70',
#   '4.56',
#   '4.35'],
#  'Halicioglu, Daniel T': ['5.00',
#   '4.89',
#   '5.00',
#   '4.50',
#   '5.00',
#   '5.00',
#   '4.94',
#   '4.50',
#   '4.80',
#   '4.75',
#   '5.00',
#   '5.00',
#   '4.33',
#   '5.00',
#   '4.77',
#   '4.33',
#   '5.00',
#   '4.83'],
#  'Alvarado, Christine J.': ['4.80',
#   '4.75',
#   '4.66',
#   '4.90',
#   '4.43',
#   '4.67',
#   '4.71',
#   '4.76',
#   '4.60',
#   '4.71',
#   '4.45',
#   '4.74',
#   '4.74',
#   '4.66',
#   '4.70',
#   '4.74',
#   '4.75',
#   '4.75',
#   '4.72',
#   '4.67',
#   '4.86',
#   '4.70',
#   '4.67',
#   '4.63',
#   '4.77',
#   '4.66',
#   '4.63',
#   '4.31',
#   '4.65',
#   '4.74',
#   '4.46',
#   '4.38',
#   '4.73',
#   '4.50',
#   '4.63',
#   '4.68',
#   '4.60',
#   '4.59',
#   '4.67',
#   '4.48',
#   '4.55',
#   '4.25',
#   '4.79',
#   '4.58',
#   '4.56',
#   '4.67',
#   '4.79',
#   '4.82',
#   '4.37',
#   '4.83',
#   '4.56',
#   '4.59',
#   '4.64',
#   '4.69',
#   '4.41'],
#  'Minnes Kemp, Mor Mia': ['0.00',
#   '4.68',
#   '4.73',
#   '4.65',
#   '4.74',
#   '4.68',
#   '4.68',
#   '4.65',
#   '4.70',
#   '4.80',
#   '4.78',
#   '4.78',
#   '4.81',
#   '4.74',
#   '4.85',
#   '4.77',
#   '0.00',
#   '5.00',
#   '4.70',
#   '4.64',
#   '4.59',
#   '4.62',
#   '4.70',
#   '4.74',
#   '4.67',
#   '0.00',
#   '4.80',
#   '4.71',
#   '5.00',
#   '4.58',
#   '4.64',
#   '4.50',
#   '4.70',
#   '4.50',
#   '5.00',
#   '4.71',
#   '4.61',
#   '4.79',
#   '4.59',
#   '4.69',
#   '4.57'],
#  'Porter, Leonard Emerson': ['4.57',
#   '4.58',
#   '4.83',
#   '4.71',
#   '4.67',
#   '4.54',
#   '4.49',
#   '4.47',
#   '4.44',
#   '4.38',
#   '4.58',
#   '4.67',
#   '4.71',
#   '4.72',
#   '4.83',
#   '4.67',
#   '4.63',
#   '4.57',
#   '4.58',
#   '4.75',
#   '4.72',
#   '4.60',
#   '4.67',
#   '4.67',
#   '4.66',
#   '4.57',
#   '4.36',
#   '4.43',
#   '4.72',
#   '4.74'],
#  'Cottrell, Garrison W': ['4.58',
#   '4.56',
#   '4.42',
#   '4.64',
#   '5.00',
#   '4.46',
#   '4.86',
#   '4.67',
#   '4.71',
#   '4.52',
#   '4.64',
#   '4.71',
#   '4.33',
#   '4.18',
#   '4.56',
#   '4.50',
#   '4.80',
#   '4.15',
#   '4.43',
#   '4.17',
#   '4.71',
#   '4.78',
#   '4.29',
#   '4.73',
#   '4.12',
#   '4.14',
#   '4.56',
#   '4.67',
#   '4.60',
#   '3.67',
#   '4.43',
#   '4.57',
#   '4.41',
#   '4.63'],
#  'Politz, Joseph Gibbs': ['4.67',
#   '4.74',
#   '4.53',
#   '4.78',
#   '4.71',
#   '4.74',
#   '4.75',
#   '4.61',
#   '4.69',
#   '4.64',
#   '4.70',
#   '4.81',
#   '4.79',
#   '4.72',
#   '4.52',
#   '4.55',
#   '4.90',
#   '4.68',
#   '4.65',
#   '4.66',
#   '4.73',
#   '4.57',
#   '4.57',
#   '4.67',
#   '4.83'],
#  'Sahoo, Debashis': ['4.31', '3.20', '3.91', '4.03', '4.01', '4.13', '3.59'],
#  'Dasgupta, Sanjoy': ['4.85',
#   '4.86',
#   '4.75',
#   '4.69',
#   '4.86',
#   '4.80',
#   '4.80',
#   '4.85',
#   '4.81'],
#  'Bellare, Mihir': ['4.75',
#   '4.81',
#   '4.74',
#   '4.50',
#   '4.76',
#   '5.00',
#   '4.71',
#   '4.75',
#   '4.67',
#   '4.78',
#   '4.27'],
#  'August, Robert Henry': ['4.38', '4.43', '4.67', '4.17', '4.45'],
#  'Weibel, Nadir': ['5.00',
#   '4.75',
#   '4.00',
#   '4.80',
#   '5.00',
#   '4.29',
#   '4.75',
#   '4.57',
#   '4.75',
#   '4.50',
#   '4.63',
#   '4.63'],
#  'Voelker, Geoffrey M.': ['4.84',
#   '4.78',
#   '4.90',
#   '4.84',
#   '4.90',
#   '4.90',
#   '4.92',
#   '4.78',
#   '4.75',
#   '4.88',
#   '4.82',
#   '4.56',
#   '4.83',
#   '4.85',
#   '4.88'],
#  'Porter, George M': ['4.81',
#   '4.65',
#   '4.78',
#   '4.38',
#   '4.69',
#   '4.74',
#   '4.59',
#   '4.74'],
#  'Stefan, Deian': ['4.71', '4.58', '4.81', '4.52', '4.64', '4.22'],
#  'Polikarpova, Nadezhda': ['4.81', '4.74', '4.57', '4.54', '4.50'],
#  'Orailoglu, Alex': ['4.00',
#   '3.81',
#   '4.80',
#   '4.55',
#   '4.33',
#   '4.26',
#   '4.55',
#   '4.00',
#   '4.12',
#   '4.25',
#   '4.10',
#   '4.71',
#   '4.58',
#   '4.42',
#   '4.53',
#   '5.00',
#   '4.33',
#   '4.75',
#   '4.57'],
#  'Pannuto, Patrick William': ['4.54'],
#  'Tullsen, Dean Michael': ['4.51',
#   '4.75',
#   '4.56',
#   '5.00',
#   '5.00',
#   '4.88',
#   '4.40',
#   '4.21',
#   '5.00',
#   '4.75',
#   '4.59',
#   '4.42',
#   '5.00',
#   '4.66',
#   '4.63',
#   '5.00',
#   '4.59',
#   '4.54'],
#  'Esmaeilzadeh, Hadi': ['4.33', '4.32', '4.38', '4.06'],
#  'Gao, Sicun': ['4.60', '4.67', '4.59', '4.65'],
#  'Berg-Kirkpatrick, Taylor D': ['4.82', '4.79', '4.33'],
#  'Su, Hao': ['4.39', '4.42', '4.34'],
#  'McAuley, Julian John': ['4.50',
#   '4.68',
#   '4.63',
#   '4.43',
#   '4.58',
#   '4.67',
#   '4.71'],
#  'Ostertag, Michael Henry': ['4.62', '4.52', '4.47', '4.56', '4.37', '4.39'],
#  'Lovett, Shachar': ['4.38',
#   '4.50',
#   '4.52',
#   '4.40',
#   '4.56',
#   '4.57',
#   '4.44',
#   '4.52',
#   '4.00',
#   '4.08',
#   '4.53'],
#  'Howden, William E.': ['4.80', '4.67', '4.56', '4.90', '4.75'],
#  'Lerner, Sorin': ['4.74',
#   '4.65',
#   '4.75',
#   '4.51',
#   '4.48',
#   '4.71',
#   '4.70',
#   '4.71',
#   '4.69',
#   '4.58',
#   '4.51',
#   '4.51',
#   '4.65',
#   '3.97',
#   '4.58',
#   '4.61',
#   '4.40'],
#  'Braun, Oliver': ['4.64',
#   '4.64',
#   '4.46',
#   '4.30',
#   '4.42',
#   '4.62',
#   '4.48',
#   '4.57',
#   '4.59'],
#  'Jaiswal, Ragesh': ['4.80', '4.90', '4.11', '3.73', '4.30', '4.20', '3.90'],
#  'Tseng, Hung-Wei': ['4.02',
#   '4.00',
#   '4.73',
#   '4.55',
#   '4.67',
#   '4.00',
#   '4.37',
#   '4.17',
#   '4.46',
#   '4.67',
#   '4.50'],
#  'Geumlek, Joseph Donald': ['4.86', '4.74', '4.61', '4.68', '4.50'],
#  'Kumar, Rakesh': ['4.00',
#   '4.50',
#   '4.33',
#   '4.63',
#   '4.41',
#   '4.44',
#   '4.67',
#   '4.82',
#   '4.78',
#   '4.66',
#   '4.42',
#   '4.61',
#   '4.34',
#   '4.29',
#   '4.42',
#   '4.58',
#   '4.33',
#   '4.38',
#   '4.38',
#   '4.33',
#   '4.55',
#   '4.46',
#   '4.53',
#   '4.41'],
#  'Bach, Quang Tran': ['4.31',
#   '4.52',
#   '4.68',
#   '4.40',
#   '4.75',
#   '4.78',
#   '4.25',
#   '4.76',
#   '4.63',
#   '4.49',
#   '4.47',
#   '4.49'],
#  'Valstar, Andries': ['4.19', '4.43'],
#  'Dubnov, Shlomo': ['4.80'],
#  'Impagliazzo, Russell': ['3.85',
#   '3.80',
#   '3.84',
#   '4.13',
#   '5.00',
#   '4.43',
#   '3.93',
#   '3.64',
#   '4.01',
#   '3.78',
#   '4.23',
#   '4.41'],
#  'Allos, Haytham Issa': ['4.32', '4.00', '3.81', '3.70', '4.12', '4.27'],
#  'Zhou, Yuan-Yuan': ['4.46',
#   '4.59',
#   '4.45',
#   '4.58',
#   '4.55',
#   '4.40',
#   '4.69',
#   '4.50',
#   '4.38'],
#  'Zhang, Yiying': ['4.67'],
#  'Savage, Stefan': ['4.83', '4.78', '4.73', '4.69', '4.45'],
#  'Deutsch, Alin Bernard': ['4.86',
#   '4.47',
#   '4.57',
#   '4.11',
#   '4.17',
#   '4.19',
#   '4.17',
#   '4.40',
#   '4.18',
#   '4.26',
#   '4.50',
#   '4.36',
#   '4.32',
#   '4.11',
#   '5.00'],
#  'Kumar, Arun Kumar': ['4.67', '4.81', '5.00', '4.68'],
#  'Gupta, Rajesh K.': ['4.80',
#   '4.33',
#   '4.44',
#   '4.14',
#   '4.09',
#   '4.67',
#   '4.33',
#   '4.19',
#   '4.07',
#   '3.57'],
#  'Kastner, Ryan Charles': ['4.67',
#   '5.00',
#   '0.00',
#   '4.50',
#   '4.40',
#   '4.53',
#   '4.61',
#   '4.30'],
#  'Eldridge, Justin Matthew': ['4.88'],
#  'Chandraker, Manmohan Krishna': ['4.88', '4.10', '4.22', '4.58'],
#  'Ramamoorthi, Ravi': ['4.88', '4.72', '4.85', '4.84', '4.75', '4.83', '4.88'],
#  'Riek, Laurel D': ['4.57', '4.80', '5.00'],
#  'Gymrek, Melissa Ann': ['4.84', '4.69', '4.49'],
#  'Chandrasekhar, Arjun': ['4.38', '4.47'],
#  'Griswold, William G.': ['4.32',
#   '4.45',
#   '4.32',
#   '4.28',
#   '3.84',
#   '4.33',
#   '4.45',
#   '3.74',
#   '4.50'],
#  'Tsaur, Lih-Feng': ['4.00', '3.77', '3.67'],
#  'Freiling, Christopher Fran': ['4.08', '4.30'],
#  'Kriegman, David J': ['4.45', '4.18', '4.43', '4.18', '4.25'],
#  'Paturi, Ramamohan': ['4.00',
#   '4.58',
#   '4.71',
#   '4.68',
#   '4.75',
#   '4.50',
#   '4.09',
#   '4.59',
#   '4.80',
#   '4.69',
#   '4.75'],
#  'Shang, Jingbo': ['4.88'],
#  'Kahng, Andrew Byun': ['4.47',
#   '4.26',
#   '4.28',
#   '4.60',
#   '4.34',
#   '4.48',
#   '4.43',
#   '4.19',
#   '4.35'],
#  'Freund, Yoav': ['3.45',
#   '3.73',
#   '3.44',
#   '3.20',
#   '4.05',
#   '3.77',
#   '3.96',
#   '4.13',
#   '3.71',
#   '3.77'],
#  'Micciancio, Daniele': ['4.82',
#   '4.32',
#   '4.37',
#   '4.29',
#   '4.27',
#   '3.93',
#   '4.50',
#   '4.41',
#   '4.17',
#   '4.33',
#   '3.98',
#   '3.97',
#   '4.50'],
#  'Zhao, Jishen': ['4.39', '4.18'],
#  'Nakashole, Ndapandula': ['4.60', '4.42', '4.13'],
#  'Merrill, Devon James': ['4.80', '4.75', '4.50', '4.50'],
#  'Polyzos, George C': ['4.20', '4.00', '3.67', '3.89', '4.13'],
#  'Pister, Kaiser Stefan': ['4.52', '4.60'],
#  'Gupta, Anjum': ['4.60', '4.55', '4.00', '4.32', '4.40', '5.00', '4.40'],
#  'Zaitsev, Anna L': ['3.76', '3.65', '3.63', '3.97', '4.23', '3.45', '4.31'],
#  'Bakst, Alexander Goldberg': ['4.71'],
#  'Cheng, Chung Kuan': ['4.30',
#   '3.68',
#   '4.21',
#   '4.28',
#   '4.10',
#   '4.12',
#   '4.22',
#   '4.03',
#   '4.26'],
#  'Altintas De Callaf, Ilkay': ['4.16',
#   '4.17',
#   '4.25',
#   '4.13',
#   '4.20',
#   '4.16',
#   '4.30',
#   '4.34',
#   '4.32',
#   '4.34',
#   '4.38',
#   '4.15',
#   '4.20',
#   '4.40',
#   '4.40',
#   '4.08',
#   '4.04',
#   '3.91',
#   '4.03',
#   '4.02',
#   '4.03',
#   '4.42',
#   '4.21',
#   '4.06',
#   '4.01',
#   '4.25',
#   '4.71',
#   '4.17',
#   '4.17',
#   '4.18',
#   '4.06'],
#  'Bafna, Vineet': ['4.62', '3.75', '4.17', '4.80', '4.60', '4.83'],
#  'Lerner, Ian Amihay': ['4.67'],
#  'Ord, Richard': ['4.85',
#   '4.71',
#   '4.74',
#   '4.70',
#   '4.81',
#   '4.78',
#   '4.54',
#   '4.60',
#   '4.65',
#   '4.75',
#   '4.76',
#   '4.74',
#   '4.87',
#   '4.94',
#   '4.77',
#   '4.85',
#   '4.80',
#   '4.78',
#   '4.67',
#   '4.84',
#   '4.55',
#   '4.73',
#   '4.84',
#   '4.74',
#   '4.77',
#   '4.68',
#   '4.61',
#   '4.65',
#   '4.72',
#   '4.43',
#   '4.63',
#   '4.83',
#   '4.77',
#   '4.74',
#   '4.60',
#   '4.70',
#   '4.84',
#   '4.77',
#   '4.76',
#   '4.77',
#   '4.70',
#   '4.71',
#   '4.70',
#   '4.71',
#   '4.60',
#   '4.73',
#   '4.90',
#   '4.61',
#   '4.73',
#   '4.88',
#   '4.81',
#   '4.86',
#   '4.86'],
#  'Safonova, Iana': ['3.25'],
#  'Guo, Philip J': ['4.65', '4.67', '4.43'],
#  'Bandeira, Nuno Filipe Cabrita': ['4.63', '4.41', '4.66', '4.35'],
#  'Cosman, Benjamin Leverett': ['4.70'],
#  'Jemmott, Colin William': ['4.63', '4.67'],
#  'Fraenkel, Aaron Mcmillan': ['4.70'],
#  'Cyranka, Jacek': ['4.64'],
#  'Marx, Susan S': ['4.67',
#   '3.93',
#   '3.84',
#   '3.62',
#   '4.23',
#   '4.08',
#   '3.79',
#   '3.72',
#   '4.26',
#   '4.56',
#   '4.50',
#   '4.00',
#   '4.30',
#   '4.19',
#   '4.08',
#   '3.93',
#   '4.25',
#   '4.19',
#   '4.12',
#   '4.39',
#   '4.43',
#   '3.73',
#   '3.79',
#   '4.33',
#   '4.20',
#   '4.33',
#   '4.10',
#   '4.39',
#   '4.20',
#   '4.20',
#   '4.33',
#   '4.33',
#   '4.44',
#   '4.14',
#   '3.73',
#   '4.00',
#   '4.67',
#   '4.15',
#   '4.13',
#   '4.15',
#   '4.06',
#   '3.75',
#   '4.25',
#   '4.03',
#   '4.52',
#   '4.56',
#   '4.67',
#   '5.00',
#   '4.63',
#   '4.14',
#   '4.14',
#   '3.87',
#   '4.04',
#   '3.95',
#   '4.01',
#   '3.83',
#   '4.42',
#   '4.83',
#   '4.75',
#   '4.60',
#   '4.75',
#   '3.78',
#   '4.21',
#   '4.40',
#   '3.69',
#   '3.83',
#   '3.88',
#   '4.22',
#   '4.23',
#   '4.00'],
#  'Nguyen, Hau Cao': ['2.39', '2.71', '3.56', '3.40', '3.16', '3.50', '4.06'],
#  'Papadopoulos, Philip Micha': ['4.56',
#   '4.60',
#   '4.38',
#   '4.41',
#   '4.53',
#   '4.40',
#   '4.59',
#   '4.29',
#   '4.32',
#   '4.23'],
#  'Gantman, Alexander': ['4.30'],
#  'Chu, Isaac Y': ['3.64',
#   '3.80',
#   '4.15',
#   '4.64',
#   '4.20',
#   '4.67',
#   '4.38',
#   '4.17',
#   '3.95',
#   '3.72',
#   '5.00',
#   '4.53',
#   '4.47',
#   '4.50',
#   '4.39',
#   '4.39',
#   '5.00',
#   '4.17',
#   '4.35',
#   '4.27',
#   '4.83',
#   '5.00'],
#  'Saul, Lawrence': ['4.83', '4.71', '4.62', '4.70', '4.67', '4.62', '4.64'],
#  'Bansal, Vikas': ['4.50'],
#  'Tiefenbruck, Janine LoBue': ['4.94',
#   '4.82',
#   '4.60',
#   '4.62',
#   '4.60',
#   '4.63',
#   '4.64',
#   '4.58',
#   '4.55',
#   '4.65',
#   '4.53',
#   '4.51',
#   '4.48',
#   '5.00',
#   '4.44',
#   '4.07'],
#  'Barr, Iris': ['3.95'],
#  'Shacham, Hovav': ['5.00',
#   '4.83',
#   '4.77',
#   '4.93',
#   '4.86',
#   '4.69',
#   '4.83',
#   '4.61',
#   '4.41',
#   '4.74',
#   '4.77',
#   '3.50',
#   '4.89',
#   '4.75'],
#  'Vardy, Alexander': ['4.61', '4.39'],
#  'Papakonstantinou, Yannis': ['4.60',
#   '3.87',
#   '4.75',
#   '4.08',
#   '4.75',
#   '4.44',
#   '4.17',
#   '4.78',
#   '4.67',
#   '4.00',
#   '5.00',
#   '4.50',
#   '4.67',
#   '4.50',
#   '3.78',
#   '4.57',
#   '4.83',
#   '4.35',
#   '4.50'],
#  'Levchenko, Kirill I.': ['4.29', '4.41'],
#  'Guthals, Sarah Marie': ['5.00'],
#  'Langlois, Marina': ['5.00',
#   '4.15',
#   '4.42',
#   '4.40',
#   '4.47',
#   '4.61',
#   '4.62',
#   '4.48',
#   '4.46',
#   '4.35',
#   '4.66',
#   '4.35',
#   '4.29',
#   '4.29',
#   '4.27',
#   '4.12',
#   '4.41',
#   '4.67',
#   '4.20'],
#  'Imani, Mohsen': ['4.49', '4.51'],
#  'Liao, Soohyun Nam': ['3.91', '3.88'],
#  'Deblasio, Michael Joseph': ['4.67'],
#  'Kohlbrenner, David William': ['4.33'],
#  'Kesden, Gregory M': ['3.76',
#   '4.26',
#   '4.12',
#   '4.25',
#   '3.95',
#   '4.26',
#   '3.89',
#   '4.14',
#   '3.91'],
#  'Loksa, Dastyni Craig': ['4.16', '4.12'],
#  'Raiko, Mikhail P.': ['4.77'],
#  'Mirza, Diba': ['4.63',
#   '4.48',
#   '4.73',
#   '4.67',
#   '4.61',
#   '4.69',
#   '4.66',
#   '4.64',
#   '4.49',
#   '4.67',
#   '4.45',
#   '4.54',
#   '4.42',
#   '4.54',
#   '4.42',
#   '4.40',
#   '4.24',
#   '4.50',
#   '4.34',
#   '4.40',
#   '4.57'],
#  'Mercati, Pietro': ['4.78', '4.81'],
#  'Yen, Dorothy': ['4.32'],
#  'Ferrante, Jeanne': ['4.62', '4.24', '4.48', '4.33'],
#  'Zhang, Weifeng': ['4.11', '3.92'],
#  'Mangione-Tran, Carmine': ['3.71'],
#  'Jensen, Henrik': ['5.00', '4.83', '4.86'],
#  'Hoover, Gregory William': ['4.09',
#   '4.42',
#   '4.75',
#   '4.44',
#   '4.85',
#   '4.58',
#   '4.66'],
#  'Aksanli, Baris': ['4.73'],
#  'Taylor, Michael': ['3.56', '4.50', '4.16', '4.62', '4.42', '4.50'],
#  'Gaasterland, Theresa': ['4.52', '4.73', '4.24', '3.70', '4.15'],
#  'Grady, Daniel Carl': ['3.92'],
#  'Jundt, Adam H': ['4.57', '4.53', '4.57', '4.50'],
#  'Yang, Shengqi': ['4.32'],
#  'Baden, Scott B.': ['4.49', '3.50', '3.01', '4.28', '3.78', '4.53'],
#  'Savage, Stefan Roberts': ['4.68', '4.52', '4.59'],
#  'Bournoutian, Garo': ['4.51', '4.53', '4.48', '4.77', '4.56'],
#  'Gayles, Eric S': ['4.10', '4.00', '4.01', '4.46'],
#  'Chockalingam, Ganapathy': ['4.60', '4.40', '4.21', '4.70', '4.53', '4.20'],
#  'Kunin, Jay Stuart': ['4.25', '4.00', '4.00', '4.50'],
#  'Shonle, Macneil Charles': ['4.41', '4.30', '3.60', '3.40'],
#  'Rhodes, Neil Campbell': ['5.00'],
#  'Frankie, Tasha Christine': ['4.70', '4.29', '4.42'],
#  'Glick, John H': ['4.30', '4.38'],
#  'Kulikov, Alexander': ['3.86'],
#  'Menarini, Massimiliano': ['3.78', '3.59', '3.92', '3.87'],
#  'Klemperer, Peter Friedrich': ['3.94', '4.47', '4.44', '4.23', '3.94'],
#  'Kim, Yeon Kyung': ['3.92'],
#  'Arsanjani, Ali Paul': ['3.76', '4.26'],
#  'Barngrover, Christopher M': ['4.34'],
#  'Porter, Jesse D': ['4.17'],
#  'Kim, Choon': ['3.67', '3.61', '3.30', '4.00', '3.73', '4.24'],
#  'Graham, Ronald L': ['4.78',
#   '4.87',
#   '4.86',
#   '4.76',
#   '4.03',
#   '4.63',
#   '4.83',
#   '3.96'],
#  'Der, Matthew Francis': ['4.78'],
#  'Rubalcaba, Robert Ramon': ['4.68', '4.54'],
#  'Chakraboty, Sourav': ['4.09', '3.97', '3.94', '3.73'],
#  'Murillo Arnal, Ana Cristin': ['4.28',
#   '4.20',
#   '4.28',
#   '4.20',
#   '4.23',
#   '4.21',
#   '4.04',
#   '4.22',
#   '4.60',
#   '4.16',
#   '4.10',
#   '4.20'],
#  'Kube, Paul Richard': ['4.53',
#   '4.34',
#   '4.38',
#   '4.37',
#   '4.58',
#   '4.51',
#   '4.56',
#   '4.56',
#   '4.58',
#   '4.53'],
#  'Chugh, Ravi K': ['4.55'],
#  'Engel, Wolfgang F.': ['5.00'],
#  'Elkan, Charles Peter': ['3.96', '4.12'],
#  'Belongie, Serge J.': ['4.74', '4.93'],
#  'Hofri, Matan': ['3.83'],
#  'Wang, Jianwu': ['3.86'],
#  'Chandrashekhar, Roshni': ['4.17'],
#  'Varna, Rakesh Laxmisha': ['4.34'],
#  'Katsis, Ioannis': ['4.25'],
#  'Cicotti, Pietro': ['3.50'],
#  'Krueger, Ingolf': ['4.50', '4.71'],
#  'Lee, Cynthia Bailey': ['4.38',
#   '4.78',
#   '4.43',
#   '4.54',
#   '4.56',
#   '4.66',
#   '4.52',
#   '4.41',
#   '4.43',
#   '4.41'],
#  'Tang, Lingjia': ['4.83'],
#  'Mars, Jason': ['4.76', '4.41'],
#  'Simon, Elizabeth A': ['4.68'],
#  'Webb, Kevin C': ['4.26'],
#  'Lin, Albert Yu Min': ['4.40'],
#  'Schurgers, Curt': ['4.60']}

# %%
prof_dict2
# Out:
# {'Moshiri, Alexander Niema': ['4.77',
#   '4.75',
#   '4.74',
#   '4.62',
#   '4.67',
#   '4.75',
#   '4.57'],
#  'Kane, Daniel Mertz': ['4.59',
#   '4.75',
#   '4.52',
#   '4.18',
#   '4.39',
#   '4.27',
#   '3.91'],
#  'Jones, Miles E': ['4.46',
#   '4.17',
#   '4.42',
#   '4.37',
#   '4.43',
#   '4.46',
#   '4.43',
#   '4.53',
#   '4.66',
#   '4.08',
#   '3.99',
#   '4.31',
#   '4.25',
#   '4.43',
#   '4.06',
#   '3.58',
#   '3.65',
#   '4.06',
#   '4.27',
#   '4.00',
#   '4.08',
#   '4.50',
#   '4.07',
#   '3.76',
#   '3.84',
#   '3.87',
#   '3.98',
#   '3.97',
#   '3.75',
#   '3.94',
#   '4.12',
#   '4.67',
#   '3.82',
#   '3.71',
#   '4.18',
#   '4.37',
#   '3.45',
#   '3.96',
#   '4.16',
#   '4.09',
#   '3.94',
#   '4.12',
#   '3.85',
#   '3.67',
#   '4.00',
#   '4.27',
#   '4.06'],
#  'Meyer, Kyle Phillip': ['3.01', '3.21', '3.88', '3.09'],
#  'Cao, Yingjun': ['4.31',
#   '4.41',
#   '4.54',
#   '4.61',
#   '4.74',
#   '4.63',
#   '4.54',
#   '4.38',
#   '4.52',
#   '4.41',
#   '4.52',
#   '4.50',
#   '4.43',
#   '4.45',
#   '4.28',
#   '4.53',
#   '4.26',
#   '4.43',
#   '4.20',
#   '4.12',
#   '4.67',
#   '4.06',
#   '4.18',
#   '4.35',
#   '4.24',
#   '4.59',
#   '3.95',
#   '4.09',
#   '4.56',
#   '4.27',
#   '4.20',
#   '4.35',
#   '4.28',
#   '4.26',
#   '4.72',
#   '4.62',
#   '4.48',
#   '4.32',
#   '4.38',
#   '4.47',
#   '4.57',
#   '4.33',
#   '4.39',
#   '4.26',
#   '4.45',
#   '4.45',
#   '4.54',
#   '4.53',
#   '4.61',
#   '4.55',
#   '4.36',
#   '4.40',
#   '4.55',
#   '4.42',
#   '4.43',
#   '4.33',
#   '4.30',
#   '4.29',
#   '4.51',
#   '4.51'],
#  'Powell, Thomas Allan': ['3.63',
#   '3.74',
#   '3.93',
#   '4.60',
#   '3.97',
#   '5.00',
#   '4.08',
#   '4.27',
#   '4.17',
#   '4.19',
#   '3.89',
#   '3.61',
#   '4.06',
#   '4.46',
#   '4.86',
#   '4.34',
#   '4.50',
#   '4.44',
#   '4.34',
#   '4.24',
#   '4.75',
#   '5.00',
#   '4.71',
#   '4.58',
#   '3.80',
#   '4.63',
#   '4.16',
#   '4.36',
#   '4.50',
#   '4.63',
#   '4.57',
#   '4.58',
#   '4.25'],
#  'Gillespie, Gary N': ['3.82',
#   '3.80',
#   '4.45',
#   '3.74',
#   '3.81',
#   '3.88',
#   '3.70',
#   '3.44',
#   '3.29',
#   '3.92',
#   '3.49',
#   '4.67',
#   '4.13',
#   '3.35',
#   '3.91',
#   '3.66',
#   '3.81',
#   '4.80',
#   '2.81',
#   '3.51',
#   '4.11',
#   '3.92',
#   '3.82',
#   '3.31',
#   '3.65',
#   '3.63',
#   '3.46',
#   '3.29',
#   '4.03',
#   '3.61',
#   '4.11',
#   '3.58',
#   '3.45',
#   '4.06',
#   '3.35',
#   '3.56',
#   '4.05',
#   '4.14',
#   '3.86',
#   '3.60',
#   '3.81',
#   '4.13',
#   '3.77',
#   '4.03',
#   '3.99',
#   '4.52',
#   '3.22',
#   '3.85',
#   '4.47',
#   '4.32',
#   '4.31',
#   '4.34',
#   '3.79',
#   '4.00',
#   '4.26',
#   '4.60',
#   '4.11',
#   '3.80',
#   '3.80',
#   '3.82',
#   '4.24',
#   '3.73',
#   '4.20',
#   '4.31',
#   '3.83',
#   '3.50',
#   '4.45',
#   '4.33',
#   '3.86',
#   '4.67',
#   '4.83',
#   '3.60',
#   '3.60',
#   '3.74',
#   '4.38',
#   '3.88',
#   '3.60',
#   '4.00',
#   '4.11',
#   '3.80',
#   '4.05',
#   '4.69',
#   '3.94',
#   '4.50',
#   '4.04',
#   '4.00',
#   '3.76',
#   '3.43',
#   '3.62',
#   '3.89',
#   '4.42',
#   '3.85',
#   '3.64',
#   '4.21',
#   '3.94',
#   '3.53',
#   '3.83',
#   '3.96',
#   '4.76',
#   '3.60',
#   '4.01',
#   '3.86',
#   '3.88',
#   '4.50'],
#  'Miranda, Gregory Joseph': ['4.35',
#   '4.32',
#   '4.07',
#   '4.31',
#   '4.12',
#   '4.18',
#   '4.21',
#   '3.33',
#   '4.07',
#   '3.89',
#   '4.27',
#   '4.24',
#   '3.93',
#   '4.33',
#   '4.58',
#   '4.25',
#   '4.00',
#   '4.28',
#   '4.75',
#   '3.29'],
#  'Pasquale, Joseph': ['4.65',
#   '4.58',
#   '4.37',
#   '4.82',
#   '4.66',
#   '4.63',
#   '4.75',
#   '4.75',
#   '4.77',
#   '4.73',
#   '4.51',
#   '4.66',
#   '4.64',
#   '4.70',
#   '4.60',
#   '4.75',
#   '4.87',
#   '4.36',
#   '5.00',
#   '4.80',
#   '4.72',
#   '4.83',
#   '4.67',
#   '4.73',
#   '4.75',
#   '4.82',
#   '4.64',
#   '5.00',
#   '5.00',
#   '4.72',
#   '4.56',
#   '4.62'],
#  'Snoeren, Alex C.': ['4.38',
#   '4.50',
#   '4.63',
#   '4.46',
#   '4.55',
#   '4.78',
#   '4.84',
#   '4.62',
#   '4.25',
#   '4.63',
#   '4.72'],
#  'Heninger, Nadia A': ['4.22', '3.43'],
#  'Jhala, Ranjit': ['4.67',
#   '4.41',
#   '4.47',
#   '4.77',
#   '4.38',
#   '4.51',
#   '4.56',
#   '4.35',
#   '4.74',
#   '4.00',
#   '4.34',
#   '3.46',
#   '4.56',
#   '4.27'],
#  'Vianu, Victor Dan': ['3.93',
#   '4.24',
#   '3.49',
#   '3.79',
#   '3.97',
#   '3.61',
#   '3.52',
#   '3.06',
#   '3.51',
#   '3.59',
#   '3.63',
#   '3.38',
#   '3.77',
#   '3.67'],
#  'Rosing, Tajana Simunic': ['3.74',
#   '3.91',
#   '4.35',
#   '4.33',
#   '4.26',
#   '4.07',
#   '4.11',
#   '4.10',
#   '4.01',
#   '3.90',
#   '4.07',
#   '4.17'],
#  'Eldon, John': ['4.41',
#   '4.47',
#   '4.43',
#   '3.79',
#   '4.49',
#   '3.45',
#   '4.45',
#   '3.40',
#   '4.58',
#   '4.32',
#   '4.50',
#   '3.98',
#   '4.83',
#   '3.36',
#   '4.33',
#   '4.52',
#   '3.50',
#   '4.57',
#   '3.47',
#   '4.22',
#   '4.27',
#   '4.35',
#   '4.07',
#   '3.96',
#   '4.74',
#   '4.20',
#   '3.56',
#   '3.69',
#   '4.10',
#   '3.67',
#   '3.81',
#   '3.17',
#   '3.88',
#   '4.14',
#   '4.32',
#   '4.56',
#   '3.98',
#   '3.91',
#   '4.19',
#   '4.27',
#   '4.40',
#   '4.08',
#   '4.08',
#   '4.33',
#   '3.91',
#   '3.78',
#   '4.19',
#   '4.10',
#   '4.00',
#   '3.62',
#   '4.13',
#   '4.16'],
#  'Chin, Bryan W.': ['4.09',
#   '4.12',
#   '3.91',
#   '2.67',
#   '4.06',
#   '4.40',
#   '4.27',
#   '4.41',
#   '3.60',
#   '3.12',
#   '3.86'],
#  'Chaudhuri, Kamalika': ['4.26',
#   '4.09',
#   '4.20',
#   '4.48',
#   '4.35',
#   '4.40',
#   '4.03',
#   '4.16',
#   '4.15',
#   '3.73'],
#  'Ochoa, Benjamin Lawrence': ['4.31',
#   '4.25',
#   '4.33',
#   '3.70',
#   '4.26',
#   '4.33',
#   '4.30',
#   '4.67',
#   '4.32',
#   '4.10',
#   '3.80',
#   '4.39',
#   '4.24',
#   '4.22',
#   '3.72',
#   '3.86',
#   '4.18',
#   '3.00'],
#  'Muller, P Keith': ['3.70', '4.34', '4.47', '4.44'],
#  'Schulze, Jurgen P.': ['4.83',
#   '4.45',
#   '4.83',
#   '4.41',
#   '4.71',
#   '4.46',
#   '4.31',
#   '4.67',
#   '4.88',
#   '4.35',
#   '4.13',
#   '4.81',
#   '4.50',
#   '4.15',
#   '4.56',
#   '4.60',
#   '4.53',
#   '4.61',
#   '4.33',
#   '4.88',
#   '3.87',
#   '4.75',
#   '4.36'],
#  'Chern, Albert Ren-Haur': ['3.30'],
#  'Rotenberg, Steven Paul': ['4.59',
#   '4.71',
#   '4.88',
#   '4.50',
#   '4.57',
#   '4.45',
#   '4.83',
#   '4.87',
#   '4.75',
#   '4.62'],
#  'Klemmer, Scott R': ['2.26',
#   '2.42',
#   '2.50',
#   '4.00',
#   '4.37',
#   '4.40',
#   '4.29',
#   '3.85'],
#  'Swanson, Steven James': ['4.20',
#   '4.22',
#   '4.57',
#   '3.94',
#   '4.38',
#   '4.31',
#   '5.00',
#   '4.63',
#   '4.15',
#   '4.50',
#   '4.71',
#   '4.67',
#   '4.17',
#   '4.55',
#   '4.44',
#   '4.40',
#   '4.50',
#   '5.00',
#   '4.75',
#   '4.57',
#   '4.75',
#   '4.02',
#   '3.91',
#   '4.31',
#   '4.55'],
#  'Pevzner, Pavel Arkadjevich': ['4.00',
#   '3.75',
#   '3.67',
#   '4.22',
#   '3.38',
#   '3.40',
#   '4.00',
#   '4.80',
#   '4.60'],
#  'Shalev, Aaron D': ['4.82', '4.22', '4.69', '3.80', '5.00'],
#  'Soosai Raj, Adalbert Geral': ['4.89',
#   '4.65',
#   '4.69',
#   '4.65',
#   '4.44',
#   '4.50',
#   '4.54',
#   '4.36',
#   '3.96'],
#  'Halicioglu, Daniel T': ['5.00',
#   '5.00',
#   '4.60',
#   '4.00',
#   '5.00',
#   '4.57',
#   '4.88',
#   '3.92',
#   '4.80',
#   '4.50',
#   '5.00',
#   '5.00',
#   '3.92',
#   '4.60',
#   '4.54',
#   '4.33',
#   '5.00',
#   '4.86'],
#  'Alvarado, Christine J.': ['4.75',
#   '4.50',
#   '4.42',
#   '4.90',
#   '4.50',
#   '4.50',
#   '4.75',
#   '4.70',
#   '4.52',
#   '4.49',
#   '4.54',
#   '4.71',
#   '4.69',
#   '4.55',
#   '4.70',
#   '4.77',
#   '4.61',
#   '4.60',
#   '4.61',
#   '4.71',
#   '4.81',
#   '4.58',
#   '4.59',
#   '4.58',
#   '4.69',
#   '4.65',
#   '4.56',
#   '4.29',
#   '4.60',
#   '4.70',
#   '4.44',
#   '4.31',
#   '4.70',
#   '4.38',
#   '4.63',
#   '4.56',
#   '4.52',
#   '4.55',
#   '4.64',
#   '4.43',
#   '4.48',
#   '4.25',
#   '4.74',
#   '4.54',
#   '4.52',
#   '4.67',
#   '4.76',
#   '4.80',
#   '4.38',
#   '4.77',
#   '4.48',
#   '4.57',
#   '4.69',
#   '4.64',
#   '4.27'],
#  'Minnes Kemp, Mor Mia': ['5.00',
#   '4.30',
#   '4.43',
#   '4.48',
#   '4.55',
#   '4.43',
#   '4.45',
#   '4.35',
#   '4.49',
#   '4.62',
#   '4.65',
#   '4.62',
#   '4.72',
#   '4.68',
#   '4.81',
#   '4.71',
#   '0.00',
#   '4.83',
#   '4.53',
#   '4.57',
#   '4.36',
#   '4.54',
#   '4.51',
#   '4.64',
#   '4.38',
#   '0.00',
#   '4.66',
#   '4.39',
#   '5.00',
#   '4.01',
#   '3.97',
#   '4.50',
#   '4.51',
#   '4.50',
#   '5.00',
#   '4.49',
#   '4.34',
#   '4.60',
#   '4.45',
#   '4.63',
#   '4.33'],
#  'Porter, Leonard Emerson': ['4.41',
#   '4.30',
#   '4.68',
#   '4.69',
#   '4.51',
#   '4.32',
#   '4.18',
#   '4.32',
#   '4.28',
#   '4.19',
#   '4.46',
#   '4.56',
#   '4.49',
#   '4.57',
#   '4.66',
#   '4.61',
#   '4.40',
#   '4.47',
#   '4.42',
#   '4.56',
#   '4.61',
#   '4.51',
#   '4.56',
#   '4.52',
#   '4.50',
#   '4.22',
#   '4.29',
#   '4.25',
#   '4.67',
#   '4.57'],
#  'Cottrell, Garrison W': ['4.08',
#   '3.67',
#   '4.00',
#   '4.64',
#   '4.50',
#   '3.32',
#   '3.57',
#   '4.44',
#   '4.00',
#   '3.35',
#   '3.71',
#   '3.75',
#   '3.67',
#   '2.82',
#   '3.80',
#   '3.75',
#   '4.20',
#   '3.62',
#   '3.81',
#   '3.46',
#   '3.86',
#   '4.56',
#   '3.50',
#   '4.27',
#   '3.47',
#   '3.86',
#   '3.89',
#   '4.00',
#   '3.90',
#   '3.33',
#   '3.71',
#   '4.29',
#   '3.88',
#   '4.00'],
#  'Politz, Joseph Gibbs': ['4.33',
#   '4.50',
#   '4.49',
#   '4.60',
#   '4.43',
#   '4.61',
#   '4.80',
#   '4.57',
#   '4.69',
#   '4.45',
#   '4.54',
#   '4.66',
#   '4.63',
#   '4.60',
#   '4.44',
#   '4.46',
#   '4.78',
#   '4.54',
#   '4.57',
#   '4.68',
#   '4.66',
#   '4.34',
#   '4.45',
#   '4.48',
#   '4.68'],
#  'Sahoo, Debashis': ['4.17', '2.94', '3.57', '3.50', '3.63', '3.38', '3.16'],
#  'Dasgupta, Sanjoy': ['4.72',
#   '4.74',
#   '4.73',
#   '4.66',
#   '4.78',
#   '4.70',
#   '4.72',
#   '4.76',
#   '4.69'],
#  'Bellare, Mihir': ['4.53',
#   '4.44',
#   '4.22',
#   '4.15',
#   '3.95',
#   '4.58',
#   '4.43',
#   '4.50',
#   '4.00',
#   '4.16',
#   '3.33'],
#  'August, Robert Henry': ['4.15', '4.50', '4.58', '3.50', '3.97'],
#  'Weibel, Nadir': ['5.00',
#   '4.25',
#   '4.29',
#   '4.20',
#   '4.75',
#   '4.43',
#   '4.38',
#   '4.50',
#   '4.75',
#   '4.29',
#   '4.60',
#   '4.43'],
#  'Voelker, Geoffrey M.': ['4.69',
#   '4.80',
#   '4.78',
#   '4.87',
#   '4.80',
#   '4.73',
#   '4.83',
#   '4.78',
#   '4.55',
#   '4.86',
#   '4.72',
#   '4.67',
#   '4.71',
#   '4.90',
#   '5.00'],
#  'Porter, George M': ['4.84',
#   '4.49',
#   '4.43',
#   '4.19',
#   '4.62',
#   '4.54',
#   '4.52',
#   '4.29'],
#  'Stefan, Deian': ['4.32', '4.22', '4.33', '3.67', '3.95', '3.36'],
#  'Polikarpova, Nadezhda': ['4.74', '4.47', '3.98', '3.90', '3.46'],
#  'Orailoglu, Alex': ['2.50',
#   '2.86',
#   '3.60',
#   '2.67',
#   '2.57',
#   '3.70',
#   '3.64',
#   '3.43',
#   '2.67',
#   '3.73',
#   '3.50',
#   '3.57',
#   '3.33',
#   '2.56',
#   '3.00',
#   '3.25',
#   '3.67',
#   '3.50',
#   '3.71'],
#  'Pannuto, Patrick William': ['4.33'],
#  'Tullsen, Dean Michael': ['4.14',
#   '5.00',
#   '3.90',
#   '5.00',
#   '4.33',
#   '4.75',
#   '3.83',
#   '3.69',
#   '4.75',
#   '4.75',
#   '4.29',
#   '3.68',
#   '4.50',
#   '4.09',
#   '4.43',
#   '4.80',
#   '4.32',
#   '4.08'],
#  'Esmaeilzadeh, Hadi': ['3.75', '3.84', '3.84', '3.77'],
#  'Gao, Sicun': ['4.55', '4.39', '4.15', '4.33'],
#  'Berg-Kirkpatrick, Taylor D': ['4.67', '4.61', '3.00'],
#  'Su, Hao': ['3.41', '3.54', '3.88'],
#  'McAuley, Julian John': ['4.11',
#   '4.41',
#   '4.16',
#   '3.93',
#   '4.13',
#   '4.26',
#   '4.47'],
#  'Ostertag, Michael Henry': ['4.58', '4.45', '4.33', '4.24', '4.31', '4.29'],
#  'Lovett, Shachar': ['3.60',
#   '4.02',
#   '4.27',
#   '3.96',
#   '4.23',
#   '4.04',
#   '3.76',
#   '3.79',
#   '3.43',
#   '3.07',
#   '4.00'],
#  'Howden, William E.': ['4.67', '4.50', '4.56', '4.90', '4.75'],
#  'Lerner, Sorin': ['4.67',
#   '4.50',
#   '4.63',
#   '4.39',
#   '4.27',
#   '4.61',
#   '4.68',
#   '4.59',
#   '4.62',
#   '4.48',
#   '4.33',
#   '4.44',
#   '4.48',
#   '3.78',
#   '4.40',
#   '4.35',
#   '4.33'],
#  'Braun, Oliver': ['4.55',
#   '4.36',
#   '4.38',
#   '3.97',
#   '4.45',
#   '4.38',
#   '4.44',
#   '4.34',
#   '4.42'],
#  'Jaiswal, Ragesh': ['4.60', '4.70', '3.78', '2.82', '3.67', '3.30', '2.84'],
#  'Tseng, Hung-Wei': ['3.31',
#   '3.60',
#   '4.27',
#   '4.18',
#   '4.50',
#   '4.40',
#   '4.22',
#   '3.89',
#   '4.08',
#   '4.38',
#   '4.50'],
#  'Geumlek, Joseph Donald': ['4.86', '4.70', '4.55', '4.50', '4.50'],
#  'Kumar, Rakesh': ['4.00',
#   '4.00',
#   '4.00',
#   '4.50',
#   '4.26',
#   '4.11',
#   '4.33',
#   '4.64',
#   '4.50',
#   '4.34',
#   '4.07',
#   '4.57',
#   '4.10',
#   '4.15',
#   '4.23',
#   '4.11',
#   '4.03',
#   '4.26',
#   '4.23',
#   '4.14',
#   '4.40',
#   '4.27',
#   '4.27',
#   '4.12'],
#  'Bach, Quang Tran': ['4.00',
#   '4.28',
#   '4.43',
#   '4.00',
#   '4.58',
#   '4.56',
#   '4.08',
#   '4.66',
#   '4.24',
#   '4.17',
#   '4.26',
#   '4.35'],
#  'Valstar, Andries': ['4.15', '4.30'],
#  'Dubnov, Shlomo': ['3.40'],
#  'Impagliazzo, Russell': ['3.57',
#   '3.80',
#   '2.65',
#   '3.06',
#   '4.67',
#   '3.43',
#   '3.24',
#   '2.70',
#   '3.27',
#   '3.03',
#   '3.26',
#   '3.28'],
#  'Allos, Haytham Issa': ['4.16', '3.89', '3.35', '3.25', '3.89', '4.30'],
#  'Zhou, Yuan-Yuan': ['4.06',
#   '4.23',
#   '4.13',
#   '4.15',
#   '4.11',
#   '4.07',
#   '3.50',
#   '3.82',
#   '3.43'],
#  'Zhang, Yiying': ['4.14'],
#  'Savage, Stefan': ['4.67', '4.54', '4.33', '4.53', '4.28'],
#  'Deutsch, Alin Bernard': ['4.43',
#   '4.17',
#   '3.71',
#   '3.53',
#   '3.48',
#   '3.38',
#   '3.33',
#   '3.70',
#   '3.60',
#   '3.90',
#   '4.25',
#   '3.86',
#   '3.14',
#   '3.44',
#   '4.75'],
#  'Kumar, Arun Kumar': ['4.39', '4.66', '4.75', '3.95'],
#  'Gupta, Rajesh K.': ['4.60',
#   '4.00',
#   '3.94',
#   '3.82',
#   '3.40',
#   '3.83',
#   '3.78',
#   '3.31',
#   '3.05',
#   '3.57'],
#  'Kastner, Ryan Charles': ['4.50',
#   '5.00',
#   '0.00',
#   '4.67',
#   '4.40',
#   '4.00',
#   '4.44'],
#  'Eldridge, Justin Matthew': ['4.81'],
#  'Chandraker, Manmohan Krishna': ['4.69', '3.90', '2.56', '3.58'],
#  'Ramamoorthi, Ravi': ['4.67', '4.27', '4.46', '4.47', '4.34', '4.43', '4.67'],
#  'Riek, Laurel D': ['4.17', '4.80', '5.00'],
#  'Gymrek, Melissa Ann': ['4.75', '4.52', '4.34'],
#  'Chandrasekhar, Arjun': ['3.76', '4.35'],
#  'Griswold, William G.': ['4.17',
#   '4.28',
#   '4.06',
#   '3.96',
#   '3.45',
#   '4.22',
#   '4.40',
#   '3.23',
#   '4.47'],
#  'Tsaur, Lih-Feng': ['3.04', '2.98', '2.84'],
#  'Freiling, Christopher Fran': ['3.50', '3.90'],
#  'Kriegman, David J': ['4.10', '3.91', '3.71', '3.09', '3.33'],
#  'Paturi, Ramamohan': ['3.60',
#   '4.25',
#   '4.43',
#   '3.96',
#   '4.69',
#   '3.67',
#   '3.73',
#   '4.00',
#   '4.60',
#   '4.12',
#   '4.63'],
#  'Shang, Jingbo': ['4.13'],
#  'Kahng, Andrew Byun': ['4.13',
#   '4.21',
#   '3.61',
#   '4.37',
#   '3.87',
#   '3.74',
#   '3.96',
#   '3.48',
#   '3.92'],
#  'Freund, Yoav': ['2.93',
#   '3.17',
#   '2.49',
#   '2.51',
#   '3.21',
#   '3.05',
#   '2.91',
#   '3.06',
#   '3.65',
#   '2.50'],
#  'Micciancio, Daniele': ['4.45',
#   '3.95',
#   '3.64',
#   '3.75',
#   '3.83',
#   '3.51',
#   '4.00',
#   '3.18',
#   '3.35',
#   '3.67',
#   '3.17',
#   '2.87',
#   '3.14'],
#  'Zhao, Jishen': ['3.86', '3.73'],
#  'Nakashole, Ndapandula': ['4.20', '4.16', '3.13'],
#  'Merrill, Devon James': ['4.60', '4.75', '4.33', '4.00'],
#  'Polyzos, George C': ['3.30', '3.50', '3.00', '3.50', '3.50'],
#  'Pister, Kaiser Stefan': ['4.34', '4.40'],
#  'Gupta, Anjum': ['4.60', '4.45', '3.90', '4.16', '4.40', '5.00', '3.80'],
#  'Zaitsev, Anna L': ['3.50', '3.45', '3.30', '3.58', '4.04', '3.26', '4.19'],
#  'Bakst, Alexander Goldberg': ['4.64'],
#  'Cheng, Chung Kuan': ['3.40',
#   '2.88',
#   '3.36',
#   '3.39',
#   '3.37',
#   '3.36',
#   '3.40',
#   '3.16',
#   '3.51'],
#  'Altintas De Callaf, Ilkay': ['3.94',
#   '4.00',
#   '3.98',
#   '3.71',
#   '3.93',
#   '3.92',
#   '3.99',
#   '4.01',
#   '4.06',
#   '3.76',
#   '3.97',
#   '3.42',
#   '3.90',
#   '4.14',
#   '3.93',
#   '3.62',
#   '3.59',
#   '3.46',
#   '3.51',
#   '3.69',
#   '3.73',
#   '4.15',
#   '3.80',
#   '3.92',
#   '3.67',
#   '3.82',
#   '4.29',
#   '3.82',
#   '3.76',
#   '3.72',
#   '3.31'],
#  'Bafna, Vineet': ['3.77', '3.33', '2.33', '3.80', '4.60', '4.83'],
#  'Lerner, Ian Amihay': ['4.67'],
#  'Ord, Richard': ['4.60',
#   '4.37',
#   '4.62',
#   '4.48',
#   '4.56',
#   '4.44',
#   '4.18',
#   '4.34',
#   '4.24',
#   '4.45',
#   '4.50',
#   '4.52',
#   '4.56',
#   '4.69',
#   '4.48',
#   '4.52',
#   '4.59',
#   '4.48',
#   '4.58',
#   '4.52',
#   '4.37',
#   '4.41',
#   '4.61',
#   '4.64',
#   '4.50',
#   '4.59',
#   '4.42',
#   '4.61',
#   '4.59',
#   '4.37',
#   '4.34',
#   '4.58',
#   '4.56',
#   '4.22',
#   '4.44',
#   '4.63',
#   '4.71',
#   '4.67',
#   '4.76',
#   '4.63',
#   '4.50',
#   '4.47',
#   '4.42',
#   '4.71',
#   '4.44',
#   '4.63',
#   '4.51',
#   '4.49',
#   '4.57',
#   '4.80',
#   '4.59',
#   '4.71',
#   '4.72'],
#  'Safonova, Iana': ['2.33'],
#  'Guo, Philip J': ['4.59', '4.63', '4.40'],
#  'Bandeira, Nuno Filipe Cabrita': ['4.75', '4.14', '4.46', '4.20'],
#  'Cosman, Benjamin Leverett': ['4.07'],
#  'Jemmott, Colin William': ['4.13', '4.67'],
#  'Fraenkel, Aaron Mcmillan': ['4.60'],
#  'Cyranka, Jacek': ['4.09'],
#  'Marx, Susan S': ['4.17',
#   '3.21',
#   '3.17',
#   '3.04',
#   '3.79',
#   '3.63',
#   '3.37',
#   '3.17',
#   '3.62',
#   '4.44',
#   '4.21',
#   '3.45',
#   '3.80',
#   '3.58',
#   '3.67',
#   '3.56',
#   '3.75',
#   '3.90',
#   '3.68',
#   '4.14',
#   '4.11',
#   '3.19',
#   '3.47',
#   '3.75',
#   '3.30',
#   '4.04',
#   '3.65',
#   '3.96',
#   '3.71',
#   '3.83',
#   '3.85',
#   '4.14',
#   '4.19',
#   '3.71',
#   '3.85',
#   '3.57',
#   '4.11',
#   '3.72',
#   '3.87',
#   '4.05',
#   '3.61',
#   '3.66',
#   '3.90',
#   '3.60',
#   '3.88',
#   '4.33',
#   '4.17',
#   '5.00',
#   '3.88',
#   '3.64',
#   '3.92',
#   '3.38',
#   '3.34',
#   '3.45',
#   '3.65',
#   '3.40',
#   '3.87',
#   '4.67',
#   '4.50',
#   '4.40',
#   '4.00',
#   '3.36',
#   '3.78',
#   '4.04',
#   '3.25',
#   '2.65',
#   '3.09',
#   '3.82',
#   '3.95',
#   '3.68'],
#  'Nguyen, Hau Cao': ['2.18', '2.36', '2.74', '2.77', '3.15', '3.38', '3.61'],
#  'Papadopoulos, Philip Micha': ['4.29',
#   '4.06',
#   '4.08',
#   '4.14',
#   '4.12',
#   '4.02',
#   '4.13',
#   '3.78',
#   '3.81',
#   '3.45'],
#  'Gantman, Alexander': ['4.30'],
#  'Chu, Isaac Y': ['3.53',
#   '3.15',
#   '3.85',
#   '4.45',
#   '3.96',
#   '4.67',
#   '4.05',
#   '4.08',
#   '3.92',
#   '3.58',
#   '5.00',
#   '4.29',
#   '4.28',
#   '4.16',
#   '4.21',
#   '4.27',
#   '5.00',
#   '3.69',
#   '4.18',
#   '3.96',
#   '4.67',
#   '4.75'],
#  'Saul, Lawrence': ['4.60', '4.31', '4.41', '4.63', '4.37', '4.22', '4.15'],
#  'Bansal, Vikas': ['3.67'],
#  'Tiefenbruck, Janine LoBue': ['4.78',
#   '4.65',
#   '4.80',
#   '4.56',
#   '4.56',
#   '4.58',
#   '4.54',
#   '4.43',
#   '4.44',
#   '4.36',
#   '4.38',
#   '4.29',
#   '4.28',
#   '5.00',
#   '4.32',
#   '3.71'],
#  'Barr, Iris': ['3.86'],
#  'Shacham, Hovav': ['4.87',
#   '4.96',
#   '4.69',
#   '4.67',
#   '4.50',
#   '4.33',
#   '4.87',
#   '4.07',
#   '3.81',
#   '4.59',
#   '4.29',
#   '3.53',
#   '4.77',
#   '4.20'],
#  'Vardy, Alexander': ['4.21', '3.96'],
#  'Papakonstantinou, Yannis': ['4.60',
#   '2.80',
#   '4.42',
#   '3.13',
#   '4.75',
#   '4.33',
#   '3.31',
#   '4.78',
#   '4.67',
#   '3.18',
#   '4.75',
#   '4.50',
#   '4.67',
#   '4.25',
#   '2.76',
#   '4.43',
#   '4.67',
#   '3.46',
#   '4.25'],
#  'Levchenko, Kirill I.': ['3.66', '4.32'],
#  'Guthals, Sarah Marie': ['4.89'],
#  'Langlois, Marina': ['4.50',
#   '3.95',
#   '4.27',
#   '4.03',
#   '4.30',
#   '4.33',
#   '4.45',
#   '4.33',
#   '4.31',
#   '3.95',
#   '4.39',
#   '4.09',
#   '4.15',
#   '4.04',
#   '3.98',
#   '3.44',
#   '4.29',
#   '4.48',
#   '3.52'],
#  'Imani, Mohsen': ['4.24', '4.27'],
#  'Liao, Soohyun Nam': ['3.73', '3.75'],
#  'Deblasio, Michael Joseph': ['4.67'],
#  'Kohlbrenner, David William': ['4.67'],
#  'Kesden, Gregory M': ['2.92',
#   '3.89',
#   '3.79',
#   '3.43',
#   '3.43',
#   '3.89',
#   '3.69',
#   '3.75',
#   '3.39'],
#  'Loksa, Dastyni Craig': ['3.81', '3.87'],
#  'Raiko, Mikhail P.': ['3.54'],
#  'Mirza, Diba': ['4.55',
#   '4.29',
#   '4.63',
#   '4.44',
#   '4.60',
#   '4.55',
#   '4.49',
#   '4.46',
#   '4.40',
#   '4.64',
#   '4.36',
#   '4.45',
#   '4.32',
#   '4.36',
#   '4.22',
#   '4.06',
#   '4.14',
#   '4.43',
#   '4.01',
#   '4.04',
#   '3.57'],
#  'Mercati, Pietro': ['4.78', '4.84'],
#  'Yen, Dorothy': ['4.49'],
#  'Ferrante, Jeanne': ['4.50', '4.16', '4.24', '4.03'],
#  'Zhang, Weifeng': ['3.18', '3.13'],
#  'Mangione-Tran, Carmine': ['3.00'],
#  'Jensen, Henrik': ['3.44', '3.83', '4.43'],
#  'Hoover, Gregory William': ['3.73',
#   '4.46',
#   '4.56',
#   '4.33',
#   '4.77',
#   '4.33',
#   '4.41'],
#  'Aksanli, Baris': ['4.00'],
#  'Taylor, Michael': ['3.75', '4.50', '3.33', '3.86', '3.83', '3.89'],
#  'Gaasterland, Theresa': ['4.74', '4.07', '4.72', '4.42', '4.68'],
#  'Grady, Daniel Carl': ['3.66'],
#  'Jundt, Adam H': ['4.42', '4.27', '4.53', '4.30'],
#  'Yang, Shengqi': ['3.90'],
#  'Baden, Scott B.': ['3.93', '3.14', '2.32', '3.60', '2.97', '3.75'],
#  'Savage, Stefan Roberts': ['4.49', '4.34', '4.36'],
#  'Bournoutian, Garo': ['4.40', '4.26', '4.30', '4.46', '4.22'],
#  'Gayles, Eric S': ['3.69', '3.63', '3.69', '3.38'],
#  'Chockalingam, Ganapathy': ['4.40', '4.20', '4.13', '4.56', '4.20', '4.00'],
#  'Kunin, Jay Stuart': ['4.25', '3.67', '4.00', '4.00'],
#  'Shonle, Macneil Charles': ['3.67', '3.85', '2.90', '2.95'],
#  'Rhodes, Neil Campbell': ['4.00'],
#  'Frankie, Tasha Christine': ['4.70', '4.14', '4.50'],
#  'Glick, John H': ['3.96', '4.04'],
#  'Kulikov, Alexander': ['3.20'],
#  'Menarini, Massimiliano': ['3.27', '2.80', '2.94', '3.35'],
#  'Klemperer, Peter Friedrich': ['3.35', '4.24', '4.21', '4.03', '3.78'],
#  'Kim, Yeon Kyung': ['3.33'],
#  'Arsanjani, Ali Paul': ['2.57', '3.79'],
#  'Barngrover, Christopher M': ['4.06'],
#  'Porter, Jesse D': ['3.75'],
#  'Kim, Choon': ['2.70', '2.56', '2.68', '3.30', '2.79', '3.74'],
#  'Graham, Ronald L': ['4.36',
#   '4.53',
#   '4.66',
#   '4.27',
#   '3.84',
#   '4.25',
#   '4.26',
#   '3.92'],
#  'Der, Matthew Francis': ['4.44'],
#  'Rubalcaba, Robert Ramon': ['4.57', '4.49'],
#  'Chakraboty, Sourav': ['3.20', '3.34', '2.98', '2.83'],
#  'Murillo Arnal, Ana Cristin': ['3.83',
#   '3.98',
#   '3.88',
#   '3.92',
#   '3.93',
#   '4.07',
#   '3.96',
#   '3.97',
#   '4.53',
#   '3.80',
#   '3.70',
#   '4.11'],
#  'Kube, Paul Richard': ['3.99',
#   '3.98',
#   '3.95',
#   '4.06',
#   '4.18',
#   '3.87',
#   '3.96',
#   '4.27',
#   '4.23',
#   '4.16'],
#  'Chugh, Ravi K': ['4.47'],
#  'Engel, Wolfgang F.': ['3.67'],
#  'Elkan, Charles Peter': ['3.86', '4.21'],
#  'Belongie, Serge J.': ['4.44', '4.40'],
#  'Hofri, Matan': ['3.17'],
#  'Wang, Jianwu': ['2.87'],
#  'Chandrashekhar, Roshni': ['3.93'],
#  'Varna, Rakesh Laxmisha': ['4.28'],
#  'Katsis, Ioannis': ['3.58'],
#  'Cicotti, Pietro': ['3.12'],
#  'Krueger, Ingolf': ['4.20', '4.57'],
#  'Lee, Cynthia Bailey': ['4.29',
#   '4.78',
#   '4.26',
#   '4.28',
#   '4.37',
#   '4.43',
#   '4.48',
#   '4.30',
#   '4.28',
#   '4.33'],
#  'Tang, Lingjia': ['4.48'],
#  'Mars, Jason': ['4.70', '4.33'],
#  'Simon, Elizabeth A': ['4.68'],
#  'Webb, Kevin C': ['4.25'],
#  'Lin, Albert Yu Min': ['4.20'],
#  'Schurgers, Curt': ['4.75']}

# %%
#take averages
import numpy as np

prof_means1 = {}
prof_means2 = {}

for name, means in prof_dict1.items():
#     means_int = [float(numeric_string) for numeric_string in means]
    for index, num in enumerate(means):
        if num != '' or num != '  ':
            means[index] = float(num)
        else:
            means[index] = np.nan
    means = np.array([i for i in means if np.isnan(i)==False])
    prof_means1[name] = np.mean(means)

    
for name, means in prof_dict2.items():
    means_int = [float(numeric_string) for numeric_string in means]
    prof_means2[name] = np.mean(means_int)

# %%
prof_means1
# Out:
# {'Moshiri, Alexander Niema': 4.711428571428571,
#  'Kane, Daniel Mertz': 4.74,
#  'Jones, Miles E': 4.297446808510638,
#  'Meyer, Kyle Phillip': 4.0625,
#  'Cao, Yingjun': 4.586666666666669,
#  'Powell, Thomas Allan': 4.623636363636364,
#  'Gillespie, Gary N': 4.315576923076923,
#  'Miranda, Gregory Joseph': 4.525499999999999,
#  'Pasquale, Joseph': 4.795,
#  'Snoeren, Alex C.': 4.713636363636364,
#  'Heninger, Nadia A': 4.52,
#  'Jhala, Ranjit': 4.506428571428572,
#  'Vianu, Victor Dan': 4.408571428571428,
#  'Rosing, Tajana Simunic': 4.515833333333334,
#  'Eldon, John': 4.3882352941176475,
#  'Chin, Bryan W.': 4.350909090909091,
#  'Chaudhuri, Kamalika': 4.529999999999999,
#  'Ochoa, Benjamin Lawrence': 4.556666666666667,
#  'Muller, P Keith': 4.5475,
#  'Schulze, Jurgen P.': 4.718260869565217,
#  'Chern, Albert Ren-Haur': 4.39,
#  'Rotenberg, Steven Paul': 4.8149999999999995,
#  'Klemmer, Scott R': 3.9850000000000003,
#  'Swanson, Steven James': 4.5984,
#  'Pevzner, Pavel Arkadjevich': 4.732222222222222,
#  'Shalev, Aaron D': 4.674,
#  'Soosai Raj, Adalbert Geral': 4.663333333333334,
#  'Halicioglu, Daniel T': 4.8133333333333335,
#  'Alvarado, Christine J.': 4.642727272727273,
#  'Minnes Kemp, Mor Mia': 4.368048780487804,
#  'Porter, Leonard Emerson': 4.617666666666667,
#  'Cottrell, Garrison W': 4.5058823529411764,
#  'Politz, Joseph Gibbs': 4.688400000000001,
#  'Sahoo, Debashis': 3.882857142857143,
#  'Dasgupta, Sanjoy': 4.807777777777778,
#  'Bellare, Mihir': 4.703636363636363,
#  'August, Robert Henry': 4.42,
#  'Weibel, Nadir': 4.639166666666667,
#  'Voelker, Geoffrey M.': 4.828666666666666,
#  'Porter, George M': 4.672499999999999,
#  'Stefan, Deian': 4.579999999999999,
#  'Polikarpova, Nadezhda': 4.632,
#  'Orailoglu, Alex': 4.403157894736842,
#  'Pannuto, Patrick William': 4.54,
#  'Tullsen, Dean Michael': 4.693888888888889,
#  'Esmaeilzadeh, Hadi': 4.2725,
#  'Gao, Sicun': 4.6274999999999995,
#  'Berg-Kirkpatrick, Taylor D': 4.6466666666666665,
#  'Su, Hao': 4.383333333333333,
#  'McAuley, Julian John': 4.6000000000000005,
#  'Ostertag, Michael Henry': 4.488333333333333,
#  'Lovett, Shachar': 4.409090909090909,
#  'Howden, William E.': 4.736,
#  'Lerner, Sorin': 4.573529411764706,
#  'Braun, Oliver': 4.524444444444445,
#  'Jaiswal, Ragesh': 4.277142857142857,
#  'Tseng, Hung-Wei': 4.376363636363637,
#  'Geumlek, Joseph Donald': 4.678,
#  'Kumar, Rakesh': 4.4695833333333335,
#  'Bach, Quang Tran': 4.5441666666666665,
#  'Valstar, Andries': 4.3100000000000005,
#  'Dubnov, Shlomo': 4.8,
#  'Impagliazzo, Russell': 4.0874999999999995,
#  'Allos, Haytham Issa': 4.036666666666667,
#  'Zhou, Yuan-Yuan': 4.511111111111111,
#  'Zhang, Yiying': 4.67,
#  'Savage, Stefan': 4.696,
#  'Deutsch, Alin Bernard': 4.377999999999999,
#  'Kumar, Arun Kumar': 4.79,
#  'Gupta, Rajesh K.': 4.263,
#  'Kastner, Ryan Charles': 4.00125,
#  'Eldridge, Justin Matthew': 4.88,
#  'Chandraker, Manmohan Krishna': 4.445,
#  'Ramamoorthi, Ravi': 4.821428571428571,
#  'Riek, Laurel D': 4.79,
#  'Gymrek, Melissa Ann': 4.673333333333334,
#  'Chandrasekhar, Arjun': 4.425,
#  'Griswold, William G.': 4.247777777777778,
#  'Tsaur, Lih-Feng': 3.813333333333333,
#  'Freiling, Christopher Fran': 4.1899999999999995,
#  'Kriegman, David J': 4.298,
#  'Paturi, Ramamohan': 4.558181818181818,
#  'Shang, Jingbo': 4.88,
#  'Kahng, Andrew Byun': 4.377777777777777,
#  'Freund, Yoav': 3.721,
#  'Micciancio, Daniele': 4.296923076923076,
#  'Zhao, Jishen': 4.285,
#  'Nakashole, Ndapandula': 4.383333333333333,
#  'Merrill, Devon James': 4.6375,
#  'Polyzos, George C': 3.978,
#  'Pister, Kaiser Stefan': 4.56,
#  'Gupta, Anjum': 4.467142857142856,
#  'Zaitsev, Anna L': 3.857142857142857,
#  'Bakst, Alexander Goldberg': 4.71,
#  'Cheng, Chung Kuan': 4.133333333333333,
#  'Altintas De Callaf, Ilkay': 4.201612903225806,
#  'Bafna, Vineet': 4.461666666666666,
#  'Lerner, Ian Amihay': 4.67,
#  'Ord, Richard': 4.737358490566038,
#  'Safonova, Iana': 3.25,
#  'Guo, Philip J': 4.583333333333333,
#  'Bandeira, Nuno Filipe Cabrita': 4.512499999999999,
#  'Cosman, Benjamin Leverett': 4.7,
#  'Jemmott, Colin William': 4.65,
#  'Fraenkel, Aaron Mcmillan': 4.7,
#  'Cyranka, Jacek': 4.64,
#  'Marx, Susan S': 4.192285714285715,
#  'Nguyen, Hau Cao': 3.254285714285714,
#  'Papadopoulos, Philip Micha': 4.431,
#  'Gantman, Alexander': 4.3,
#  'Chu, Isaac Y': 4.373636363636363,
#  'Saul, Lawrence': 4.684285714285714,
#  'Bansal, Vikas': 4.5,
#  'Tiefenbruck, Janine LoBue': 4.60375,
#  'Barr, Iris': 3.95,
#  'Shacham, Hovav': 4.684285714285715,
#  'Vardy, Alexander': 4.5,
#  'Papakonstantinou, Yannis': 4.463684210526315,
#  'Levchenko, Kirill I.': 4.35,
#  'Guthals, Sarah Marie': 5.0,
#  'Langlois, Marina': 4.432631578947368,
#  'Imani, Mohsen': 4.5,
#  'Liao, Soohyun Nam': 3.895,
#  'Deblasio, Michael Joseph': 4.67,
#  'Kohlbrenner, David William': 4.33,
#  'Kesden, Gregory M': 4.0600000000000005,
#  'Loksa, Dastyni Craig': 4.140000000000001,
#  'Raiko, Mikhail P.': 4.77,
#  'Mirza, Diba': 4.528095238095238,
#  'Mercati, Pietro': 4.795,
#  'Yen, Dorothy': 4.32,
#  'Ferrante, Jeanne': 4.4175,
#  'Zhang, Weifeng': 4.015000000000001,
#  'Mangione-Tran, Carmine': 3.71,
#  'Jensen, Henrik': 4.896666666666667,
#  'Hoover, Gregory William': 4.541428571428571,
#  'Aksanli, Baris': 4.73,
#  'Taylor, Michael': 4.293333333333333,
#  'Gaasterland, Theresa': 4.268000000000001,
#  'Grady, Daniel Carl': 3.92,
#  'Jundt, Adam H': 4.5425,
#  'Yang, Shengqi': 4.32,
#  'Baden, Scott B.': 3.931666666666667,
#  'Savage, Stefan Roberts': 4.596666666666667,
#  'Bournoutian, Garo': 4.569999999999999,
#  'Gayles, Eric S': 4.1425,
#  'Chockalingam, Ganapathy': 4.44,
#  'Kunin, Jay Stuart': 4.1875,
#  'Shonle, Macneil Charles': 3.9275,
#  'Rhodes, Neil Campbell': 5.0,
#  'Frankie, Tasha Christine': 4.47,
#  'Glick, John H': 4.34,
#  'Kulikov, Alexander': 3.86,
#  'Menarini, Massimiliano': 3.79,
#  'Klemperer, Peter Friedrich': 4.204000000000001,
#  'Kim, Yeon Kyung': 3.92,
#  'Arsanjani, Ali Paul': 4.01,
#  'Barngrover, Christopher M': 4.34,
#  'Porter, Jesse D': 4.17,
#  'Kim, Choon': 3.758333333333333,
#  'Graham, Ronald L': 4.59,
#  'Der, Matthew Francis': 4.78,
#  'Rubalcaba, Robert Ramon': 4.609999999999999,
#  'Chakraboty, Sourav': 3.9325,
#  'Murillo Arnal, Ana Cristin': 4.2266666666666675,
#  'Kube, Paul Richard': 4.494,
#  'Chugh, Ravi K': 4.55,
#  'Engel, Wolfgang F.': 5.0,
#  'Elkan, Charles Peter': 4.04,
#  'Belongie, Serge J.': 4.835,
#  'Hofri, Matan': 3.83,
#  'Wang, Jianwu': 3.86,
#  'Chandrashekhar, Roshni': 4.17,
#  'Varna, Rakesh Laxmisha': 4.34,
#  'Katsis, Ioannis': 4.25,
#  'Cicotti, Pietro': 3.5,
#  'Krueger, Ingolf': 4.605,
#  'Lee, Cynthia Bailey': 4.5120000000000005,
#  'Tang, Lingjia': 4.83,
#  'Mars, Jason': 4.585,
#  'Simon, Elizabeth A': 4.68,
#  'Webb, Kevin C': 4.26,
#  'Lin, Albert Yu Min': 4.4,
#  'Schurgers, Curt': 4.6}

# %%
prof_means2
# Out:
# {'Moshiri, Alexander Niema': 4.695714285714286,
#  'Kane, Daniel Mertz': 4.372857142857143,
#  'Jones, Miles E': 4.102340425531915,
#  'Meyer, Kyle Phillip': 3.2975,
#  'Cao, Yingjun': 4.4105,
#  'Powell, Thomas Allan': 4.328484848484848,
#  'Gillespie, Gary N': 3.9239423076923075,
#  'Miranda, Gregory Joseph': 4.1385000000000005,
#  'Pasquale, Joseph': 4.708125,
#  'Snoeren, Alex C.': 4.578181818181818,
#  'Heninger, Nadia A': 3.825,
#  'Jhala, Ranjit': 4.392142857142858,
#  'Vianu, Victor Dan': 3.6542857142857144,
#  'Rosing, Tajana Simunic': 4.085,
#  'Eldon, John': 4.090192307692307,
#  'Chin, Bryan W.': 3.8645454545454543,
#  'Chaudhuri, Kamalika': 4.185,
#  'Ochoa, Benjamin Lawrence': 4.109999999999999,
#  'Muller, P Keith': 4.2375,
#  'Schulze, Jurgen P.': 4.520869565217391,
#  'Chern, Albert Ren-Haur': 3.3,
#  'Rotenberg, Steven Paul': 4.677,
#  'Klemmer, Scott R': 3.51125,
#  'Swanson, Steven James': 4.448,
#  'Pevzner, Pavel Arkadjevich': 3.98,
#  'Shalev, Aaron D': 4.506,
#  'Soosai Raj, Adalbert Geral': 4.52,
#  'Halicioglu, Daniel T': 4.640000000000001,
#  'Alvarado, Christine J.': 4.587090909090909,
#  'Minnes Kemp, Mor Mia': 4.317804878048781,
#  'Porter, Leonard Emerson': 4.459333333333333,
#  'Cottrell, Garrison W': 3.843529411764706,
#  'Politz, Joseph Gibbs': 4.5592,
#  'Sahoo, Debashis': 3.478571428571428,
#  'Dasgupta, Sanjoy': 4.722222222222222,
#  'Bellare, Mihir': 4.208181818181819,
#  'August, Robert Henry': 4.14,
#  'Weibel, Nadir': 4.489166666666667,
#  'Voelker, Geoffrey M.': 4.779333333333333,
#  'Porter, George M': 4.49,
#  'Stefan, Deian': 3.9749999999999996,
#  'Polikarpova, Nadezhda': 4.11,
#  'Orailoglu, Alex': 3.234736842105263,
#  'Pannuto, Patrick William': 4.33,
#  'Tullsen, Dean Michael': 4.351666666666667,
#  'Esmaeilzadeh, Hadi': 3.8,
#  'Gao, Sicun': 4.355,
#  'Berg-Kirkpatrick, Taylor D': 4.093333333333334,
#  'Su, Hao': 3.61,
#  'McAuley, Julian John': 4.21,
#  'Ostertag, Michael Henry': 4.366666666666666,
#  'Lovett, Shachar': 3.833636363636364,
#  'Howden, William E.': 4.676,
#  'Lerner, Sorin': 4.444117647058824,
#  'Braun, Oliver': 4.365555555555556,
#  'Jaiswal, Ragesh': 3.672857142857143,
#  'Tseng, Hung-Wei': 4.120909090909091,
#  'Geumlek, Joseph Donald': 4.622,
#  'Kumar, Rakesh': 4.234583333333333,
#  'Bach, Quang Tran': 4.300833333333334,
#  'Valstar, Andries': 4.225,
#  'Dubnov, Shlomo': 3.4,
#  'Impagliazzo, Russell': 3.3299999999999996,
#  'Allos, Haytham Issa': 3.8066666666666666,
#  'Zhou, Yuan-Yuan': 3.9444444444444446,
#  'Zhang, Yiying': 4.14,
#  'Savage, Stefan': 4.470000000000001,
#  'Deutsch, Alin Bernard': 3.7779999999999996,
#  'Kumar, Arun Kumar': 4.4375,
#  'Gupta, Rajesh K.': 3.7299999999999995,
#  'Kastner, Ryan Charles': 3.858571428571429,
#  'Eldridge, Justin Matthew': 4.81,
#  'Chandraker, Manmohan Krishna': 3.6825,
#  'Ramamoorthi, Ravi': 4.472857142857142,
#  'Riek, Laurel D': 4.656666666666666,
#  'Gymrek, Melissa Ann': 4.536666666666666,
#  'Chandrasekhar, Arjun': 4.055,
#  'Griswold, William G.': 4.026666666666667,
#  'Tsaur, Lih-Feng': 2.953333333333333,
#  'Freiling, Christopher Fran': 3.7,
#  'Kriegman, David J': 3.628,
#  'Paturi, Ramamohan': 4.152727272727272,
#  'Shang, Jingbo': 4.13,
#  'Kahng, Andrew Byun': 3.921111111111111,
#  'Freund, Yoav': 2.9479999999999995,
#  'Micciancio, Daniele': 3.577692307692308,
#  'Zhao, Jishen': 3.795,
#  'Nakashole, Ndapandula': 3.8299999999999996,
#  'Merrill, Devon James': 4.42,
#  'Polyzos, George C': 3.3600000000000003,
#  'Pister, Kaiser Stefan': 4.37,
#  'Gupta, Anjum': 4.33,
#  'Zaitsev, Anna L': 3.617142857142858,
#  'Bakst, Alexander Goldberg': 4.64,
#  'Cheng, Chung Kuan': 3.3144444444444443,
#  'Altintas De Callaf, Ilkay': 3.823225806451613,
#  'Bafna, Vineet': 3.776666666666666,
#  'Lerner, Ian Amihay': 4.67,
#  'Ord, Richard': 4.526981132075472,
#  'Safonova, Iana': 2.33,
#  'Guo, Philip J': 4.54,
#  'Bandeira, Nuno Filipe Cabrita': 4.3875,
#  'Cosman, Benjamin Leverett': 4.07,
#  'Jemmott, Colin William': 4.4,
#  'Fraenkel, Aaron Mcmillan': 4.6,
#  'Cyranka, Jacek': 4.09,
#  'Marx, Susan S': 3.7612857142857146,
#  'Nguyen, Hau Cao': 2.8842857142857143,
#  'Papadopoulos, Philip Micha': 3.988000000000001,
#  'Gantman, Alexander': 4.3,
#  'Chu, Isaac Y': 4.168181818181818,
#  'Saul, Lawrence': 4.384285714285714,
#  'Bansal, Vikas': 3.67,
#  'Tiefenbruck, Janine LoBue': 4.48,
#  'Barr, Iris': 3.86,
#  'Shacham, Hovav': 4.439285714285715,
#  'Vardy, Alexander': 4.085,
#  'Papakonstantinou, Yannis': 4.09,
#  'Levchenko, Kirill I.': 3.99,
#  'Guthals, Sarah Marie': 4.89,
#  'Langlois, Marina': 4.147368421052631,
#  'Imani, Mohsen': 4.255,
#  'Liao, Soohyun Nam': 3.74,
#  'Deblasio, Michael Joseph': 4.67,
#  'Kohlbrenner, David William': 4.67,
#  'Kesden, Gregory M': 3.5755555555555554,
#  'Loksa, Dastyni Craig': 3.84,
#  'Raiko, Mikhail P.': 3.54,
#  'Mirza, Diba': 4.333809523809525,
#  'Mercati, Pietro': 4.8100000000000005,
#  'Yen, Dorothy': 4.49,
#  'Ferrante, Jeanne': 4.2325,
#  'Zhang, Weifeng': 3.1550000000000002,
#  'Mangione-Tran, Carmine': 3.0,
#  'Jensen, Henrik': 3.9,
#  'Hoover, Gregory William': 4.37,
#  'Aksanli, Baris': 4.0,
#  'Taylor, Michael': 3.86,
#  'Gaasterland, Theresa': 4.526000000000001,
#  'Grady, Daniel Carl': 3.66,
#  'Jundt, Adam H': 4.38,
#  'Yang, Shengqi': 3.9,
#  'Baden, Scott B.': 3.285,
#  'Savage, Stefan Roberts': 4.396666666666667,
#  'Bournoutian, Garo': 4.328,
#  'Gayles, Eric S': 3.5975,
#  'Chockalingam, Ganapathy': 4.248333333333333,
#  'Kunin, Jay Stuart': 3.98,
#  'Shonle, Macneil Charles': 3.3425000000000002,
#  'Rhodes, Neil Campbell': 4.0,
#  'Frankie, Tasha Christine': 4.446666666666666,
#  'Glick, John H': 4.0,
#  'Kulikov, Alexander': 3.2,
#  'Menarini, Massimiliano': 3.09,
#  'Klemperer, Peter Friedrich': 3.9220000000000006,
#  'Kim, Yeon Kyung': 3.33,
#  'Arsanjani, Ali Paul': 3.1799999999999997,
#  'Barngrover, Christopher M': 4.06,
#  'Porter, Jesse D': 3.75,
#  'Kim, Choon': 2.961666666666666,
#  'Graham, Ronald L': 4.26125,
#  'Der, Matthew Francis': 4.44,
#  'Rubalcaba, Robert Ramon': 4.53,
#  'Chakraboty, Sourav': 3.0875,
#  'Murillo Arnal, Ana Cristin': 3.973333333333333,
#  'Kube, Paul Richard': 4.065,
#  'Chugh, Ravi K': 4.47,
#  'Engel, Wolfgang F.': 3.67,
#  'Elkan, Charles Peter': 4.035,
#  'Belongie, Serge J.': 4.42,
#  'Hofri, Matan': 3.17,
#  'Wang, Jianwu': 2.87,
#  'Chandrashekhar, Roshni': 3.93,
#  'Varna, Rakesh Laxmisha': 4.28,
#  'Katsis, Ioannis': 3.58,
#  'Cicotti, Pietro': 3.12,
#  'Krueger, Ingolf': 4.385,
#  'Lee, Cynthia Bailey': 4.38,
#  'Tang, Lingjia': 4.48,
#  'Mars, Jason': 4.515000000000001,
#  'Simon, Elizabeth A': 4.68,
#  'Webb, Kevin C': 4.25,
#  'Lin, Albert Yu Min': 4.2,
#  'Schurgers, Curt': 4.75}

# %%
d = {'Proficiency of Material Means': prof_means1, 'Explaining Material Well Means': prof_means2}
df = pd.DataFrame(data=d)
df.to_csv('cse_means.csv')

# %% [markdown]
# ### Biological Sciences

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os, time
import pandas as pd

# os.environ["CHROMEDRIVER_PATH"] = "/chromedriver"
# os.environ["GOOGLE_CHROME_BIN"] = "/usr/bin/google-chrome"
# chrome_options = webdriver.ChromeOptions()
# chrome_options.binary_location = os.environ.get("GOOGLE_CHROME_BIN")
# driver = webdriver.Chrome(executable_path=os.environ.get("CHROMEDRIVER_PATH"), chrome_options=chrome_options)
# dir_path = os.path.dirname(os.path.abspath(''))
driver = webdriver.Chrome(executable_path='/home/nicole/Documents/Docs/UCSD/SP21/CSE 194/CSE_194_Project/chromedriver')
driver.implicitly_wait(30)

driver.get('https://cape.ucsd.edu/responses/Results.aspx')
sso_id = driver.find_element_by_id('ssousername')
sso_id.send_keys("nmartind")
pw = driver.find_element_by_id('ssopassword')
pw.send_keys("") #insert password

login = driver.find_element_by_name('_eventId_proceed')
login.send_keys(Keys.ENTER)
time.sleep(15)

#once logged in, select department
dept = driver.find_element_by_id('ContentPlaceHolder1_ddlDepartments')
for option in dept.find_elements_by_tag_name('option'):
    if option.get_attribute("value") == 'BIOL': #different department name here
        option.click() 
        break

driver.find_element_by_id('ContentPlaceHolder1_btnSubmit').click()
driver.implicitly_wait(15)


profs = {}

#populate dict with prof names and link to each of the classes they've taught
table_id = driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs')
tbody = table_id.find_element_by_tag_name('tbody')
rows = tbody.find_elements_by_tag_name("tr")
for row in rows:
    prof = (row.find_elements_by_tag_name("td")[0]).text
    course = (row.find_elements_by_tag_name("td")[1]).find_element_by_tag_name("a").get_attribute("href")
    if prof in profs:
        profs[prof].append(course)
    else:
        profs[prof] = [course]
    
'''
# get table
df=pd.read_html(driver.find_element_by_id('ContentPlaceHolder1_gvCAPEs').get_attribute('outerHTML'))[0] 

#extract columns
df2 = df[['Instructor','Course', 'Term', 'Enroll', 'Evals Made', 'Rcmnd Class', 'Rcmnd Instr', 'Study Hrs/wk', 'Avg Grade Expected', 'Avg Grade Received']] #fix

#convert to csv
#f2.to_csv('hum_capes.csv', index=False)
'''


print("DONE w first dict")

prof_dict1 = {}
prof_dict2 = {}


#iterating through profs dict
for name, link_arr in profs.items():
    #for each link, click full details
    for link in link_arr:
        driver.get(link)
        try:
            button = driver.find_element_by_id("btnClick")
            button.click()

            #get proficiency mean score and add them to dict 1 for that prof
            proficient_mean = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_16").text
            if name in prof_dict1:
                prof_dict1[name].append(proficient_mean)
            else:
                prof_dict1[name] = [proficient_mean]

            #get explaining material well mean score and add them to dict 2 for that prof
            prof_material = driver.find_element_by_id("ContentPlaceHolder1_dlQuestionnaire_lblMean_19").text
            if name in prof_dict2:
                prof_dict2[name].append(prof_material)
            else:
                prof_dict2[name] = [prof_material]
        except:
            print("differently formatted")
            break

print("DONE")
# Out:
# DONE w first dict
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# differently formatted
# DONE

# %%
prof_dict1
# Out:
# {'Hui, Enfu': ['4.67', '4.54', '4.81', '4.52', '5.00', '4.75'],
#  'Zhao, Yunde': ['4.47',
#   '4.70',
#   '4.70',
#   '4.38',
#   '4.60',
#   '4.55',
#   '4.50',
#   '4.49',
#   '4.88',
#   '4.42',
#   '4.60',
#   '4.60',
#   '4.51',
#   '4.00',
#   '4.85'],
#  'Feng, Gen-Sheng': ['4.32',
#   '4.08',
#   '4.19',
#   '4.34',
#   '4.13',
#   '4.44',
#   '4.61',
#   '4.04'],
#  'Coleman, Aaron B.': ['4.68',
#   '4.85',
#   '4.80',
#   '4.83',
#   '4.68',
#   '4.68',
#   '4.76',
#   '4.69',
#   '4.83',
#   '4.70',
#   '4.72',
#   '4.68',
#   '4.50',
#   '4.72',
#   '4.74',
#   '4.77',
#   '4.75',
#   '4.62',
#   '4.73',
#   '4.64',
#   '4.68',
#   '4.64',
#   '4.71',
#   '4.67',
#   '4.82',
#   '4.75',
#   '4.47',
#   '4.69',
#   '4.48',
#   '4.70',
#   '4.28',
#   '4.92',
#   '4.77',
#   '4.75',
#   '4.69',
#   '4.76'],
#  'Soowal, Lara': ['',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.55',
#   '4.47',
#   '4.29',
#   '4.34'],
#  'Bozinovic, Goran': ['4.68',
#   '4.74',
#   '4.69',
#   '4.64',
#   '4.52',
#   '4.29',
#   '5.00',
#   '4.29',
#   '4.82',
#   '4.59',
#   '4.62',
#   '4.80',
#   '5.00',
#   '4.49',
#   '4.70',
#   '4.50',
#   '4.59',
#   '4.80',
#   '4.69',
#   '4.79',
#   '4.62',
#   '4.67',
#   '4.69',
#   '4.70',
#   '4.85',
#   '4.67',
#   '4.75',
#   '4.86',
#   '4.83',
#   '4.70',
#   '4.41',
#   '4.71',
#   '4.69',
#   '4.83',
#   '4.46',
#   '4.83',
#   '4.68',
#   '4.31',
#   '4.44',
#   '4.75',
#   '4.80',
#   '4.85',
#   '4.80',
#   '4.66',
#   '4.64',
#   '4.58',
#   '4.67',
#   '4.72',
#   '4.78',
#   '4.52',
#   '4.53',
#   '4.90',
#   '4.76',
#   '4.67',
#   '4.55',
#   '4.68',
#   '4.75'],
#  'Miller, Steven W.': ['4.50',
#   '4.59',
#   '4.62',
#   '4.23',
#   '4.38',
#   '4.46',
#   '4.05',
#   '4.24',
#   '4.03',
#   '4.21',
#   '4.18',
#   '4.21',
#   '4.48',
#   '4.63',
#   '4.77',
#   '4.53',
#   '4.74',
#   '4.49',
#   '4.41',
#   '4.69',
#   '4.50'],
#  'Rusert, Jessica Marie': ['4.17', '3.58', '4.18', '4.05', '4.38', '4.03'],
#  'Smith, Laurie': ['4.47',
#   '4.60',
#   '4.64',
#   '4.59',
#   '4.35',
#   '4.41',
#   '4.71',
#   '4.55',
#   '4.53',
#   '4.59',
#   '4.56',
#   '4.58',
#   '4.05'],
#  'Yelon, Deborah': ['4.42', '4.72', '4.67', '4.95'],
#  'Butler, Shannon Rhey': ['4.47',
#   '4.35',
#   '4.70',
#   '4.43',
#   '4.32',
#   '4.53',
#   '4.52',
#   '4.27',
#   '4.43',
#   '4.56',
#   '4.27',
#   '4.81',
#   '4.53'],
#  'Stockwell, Sarah R': ['4.83',
#   '4.77',
#   '4.79',
#   '4.79',
#   '4.82',
#   '4.77',
#   '4.71',
#   '4.54',
#   '4.61',
#   '4.78',
#   '4.66',
#   '4.71',
#   '4.62',
#   '4.87',
#   '4.69',
#   '4.60',
#   '4.68',
#   '4.72',
#   '4.73',
#   '4.66',
#   '4.68',
#   '4.63',
#   '4.45',
#   '4.54',
#   '4.74',
#   '4.47',
#   '4.59',
#   '4.28',
#   '4.58',
#   '4.31',
#   '5.00',
#   '4.32'],
#  'Barton, Andrew David': ['4.77', '4.64', '4.60', '4.62', '4.51', '4.59'],
#  'Chao, Lin': ['4.57',
#   '4.13',
#   '4.64',
#   '4.67',
#   '4.68',
#   '4.64',
#   '4.66',
#   '4.50',
#   '4.64',
#   '4.89',
#   '4.76',
#   '5.00',
#   '4.54',
#   '4.69',
#   '4.62',
#   '4.55',
#   '4.75'],
#  'Cooper, Andrew Michael': ['4.53',
#   '4.49',
#   '4.47',
#   '4.36',
#   '4.54',
#   '4.56',
#   '4.55',
#   '4.68',
#   '4.51',
#   '4.64',
#   '4.78',
#   '4.72',
#   '4.61',
#   '4.59',
#   '4.72',
#   '4.53',
#   '4.28',
#   '4.37',
#   '4.47'],
#  'Owens, Melinda Tsao-Ying': ['4.77',
#   '4.73',
#   '4.91',
#   '4.75',
#   '4.84',
#   '4.58',
#   '4.66',
#   '4.12',
#   '4.26',
#   '4.32',
#   '4.29',
#   '4.39',
#   '4.35'],
#  'Komiyama, Takaki': ['4.88', '4.60', '4.55', '4.54', '4.57', '4.33', '4.48'],
#  'Su, Chih-Ying': ['4.50',
#   '4.70',
#   '4.63',
#   '4.69',
#   '4.69',
#   '4.75',
#   '4.70',
#   '4.71',
#   '4.59',
#   '4.67',
#   '4.43',
#   '4.51',
#   '4.39'],
#  'Schroeder, Julian I': ['4.60',
#   '4.37',
#   '4.41',
#   '4.31',
#   '4.33',
#   '4.45',
#   '4.15'],
#  'Park, Ji Young': ['4.65',
#   '4.76',
#   '4.61',
#   '4.48',
#   '4.67',
#   '4.74',
#   '4.60',
#   '4.36'],
#  'Strause, Linda G.': ['4.50',
#   '4.58',
#   '4.47',
#   '4.55',
#   '4.46',
#   '4.43',
#   '4.54',
#   '4.52',
#   '4.53'],
#  'Gambel, Jessica Erin': ['4.50', '4.66', '4.44', '4.29', '4.46', '4.50'],
#  'Caffrey, Carolee': ['4.44', '4.79', '4.00', '4.37', '4.46'],
#  'Macagno, Eduardo R.': ['4.67',
#   '4.50',
#   '4.55',
#   '4.30',
#   '4.68',
#   '4.00',
#   '4.64',
#   '4.42',
#   '4.71',
#   '4.50',
#   '4.50',
#   '4.46',
#   '5.00',
#   '4.67'],
#  'Mel, Stephanie': ['',
#   '4.81',
#   '4.74',
#   '4.61',
#   '4.74',
#   '',
#   '',
#   '',
#   '4.50',
#   '4.62',
#   '',
#   '4.59',
#   '4.78',
#   '4.90',
#   '4.65',
#   '4.69',
#   '4.75',
#   '4.76',
#   '4.72',
#   '4.68',
#   '4.60',
#   '4.71',
#   '4.51',
#   '4.62',
#   '4.56',
#   '4.53',
#   '4.68',
#   '4.54',
#   '4.62',
#   '4.65',
#   '4.70',
#   '4.65',
#   '4.18',
#   '4.50',
#   '',
#   '4.64',
#   '',
#   '4.56',
#   '4.20',
#   '',
#   '',
#   '5.00',
#   '',
#   '',
#   '4.91'],
#  'Lo, Stanley Malvin Ming-Hi': ['4.45',
#   '4.87',
#   '4.71',
#   '4.74',
#   '4.81',
#   '4.70',
#   '4.57',
#   '4.62',
#   '4.64',
#   '4.79',
#   '4.68',
#   '4.52',
#   '4.60',
#   '4.68',
#   '4.57',
#   '4.74',
#   '4.37',
#   '4.49',
#   '4.46',
#   '4.29',
#   '4.00',
#   '4.06',
#   '4.09',
#   '4.57',
#   '4.45',
#   '4.53',
#   '4.18',
#   '4.03',
#   '4.42',
#   '4.28',
#   '4.32',
#   '4.44',
#   '4.67',
#   '4.81',
#   '4.48',
#   '4.76',
#   '4.64'],
#  'Reuther, Keefe': ['4.73',
#   '4.72',
#   '4.71',
#   '4.79',
#   '4.62',
#   '4.73',
#   '4.81',
#   '4.76',
#   '4.73',
#   '4.74',
#   '4.64',
#   '4.75',
#   '4.80',
#   '4.64',
#   '4.73',
#   '4.77',
#   '4.71',
#   '4.75',
#   '4.73',
#   '4.74',
#   '4.68',
#   '4.64',
#   '4.54',
#   '4.73',
#   '4.65',
#   '4.71',
#   '4.48',
#   '4.83',
#   '4.78',
#   '4.48',
#   '4.49',
#   '4.50',
#   '4.58',
#   '4.62',
#   '4.68',
#   '4.66',
#   '4.53',
#   '4.63',
#   '4.59',
#   '4.60',
#   '4.69',
#   '4.62',
#   '4.58',
#   '4.48',
#   '4.61',
#   '4.57',
#   '4.63',
#   '4.57',
#   '4.47',
#   '4.69',
#   '4.56',
#   '4.74',
#   '4.47',
#   '4.64',
#   '4.57',
#   '4.72',
#   '4.42',
#   '4.54',
#   '4.56',
#   '4.38',
#   '4.13',
#   '4.37',
#   '4.26',
#   '4.22'],
#  'Cleland, Elsa Eleanor': ['4.83',
#   '4.76',
#   '',
#   '',
#   '4.60',
#   '',
#   '4.40',
#   '',
#   '4.58',
#   '4.88',
#   '5.00',
#   '4.78',
#   '4.75',
#   '4.49',
#   '4.76'],
#  'Pogliano, Joseph': ['4.33',
#   '5.00',
#   '4.78',
#   '5.00',
#   '4.88',
#   '4.83',
#   '4.90',
#   '4.89',
#   '4.82',
#   '4.67',
#   '4.67',
#   '4.94',
#   '4.94',
#   '4.95',
#   '4.95',
#   '4.87',
#   '4.86'],
#  'Briggs, Steven': ['5.00', '4.83', '4.31', '4.33', '4.33', '4.90', '4.88'],
#  'Akbari, Omar Sultan': ['4.41', '4.53', '4.48', '4.89', '4.51'],
#  'Hao, Nan': ['4.77',
#   '4.60',
#   '4.64',
#   '4.74',
#   '4.57',
#   '4.73',
#   '4.71',
#   '4.73',
#   '4.54',
#   '4.64'],
#  'Meaders, Clara Leigh': [''],
#  'Burg, Michael': ['4.75',
#   '4.64',
#   '4.69',
#   '4.80',
#   '4.76',
#   '4.62',
#   '4.64',
#   '4.46',
#   '4.31',
#   '4.62',
#   '4.64',
#   '4.63',
#   '4.62',
#   '4.72',
#   '4.53',
#   '4.49',
#   '4.70',
#   '4.82',
#   '4.68',
#   '4.71',
#   '4.68',
#   '4.72',
#   '4.49',
#   '4.64',
#   '4.74',
#   '4.09',
#   '4.36',
#   '4.50',
#   '4.76',
#   '4.48',
#   '4.55',
#   '4.41',
#   '4.45',
#   '4.40',
#   '4.52'],
#  'Day, Christopher D': ['4.70',
#   '4.65',
#   '4.55',
#   '4.50',
#   '4.44',
#   '4.48',
#   '4.50',
#   '4.58',
#   '4.55',
#   '4.78',
#   '4.77',
#   '4.54',
#   '4.61',
#   '4.77',
#   '4.55',
#   '4.27',
#   '4.52',
#   '4.54',
#   '4.15',
#   '4.37',
#   '4.48',
#   '4.20',
#   '4.50',
#   '4.18',
#   '4.25',
#   '4.60',
#   '4.56'],
#  'Grossman, Emily N': ['',
#   '',
#   '4.29',
#   '',
#   '',
#   '',
#   '3.87',
#   '',
#   '3.61',
#   '',
#   '3.93',
#   '',
#   '4.01',
#   '',
#   '4.54',
#   '4.31',
#   '4.65',
#   '3.90',
#   '4.64',
#   '4.64',
#   '4.74',
#   '',
#   '4.63',
#   '4.04',
#   '',
#   '',
#   '3.37'],
#  'Zhang, Dong-Er': ['4.29', '4.48', '4.59', '4.63', '4.58', '4.68'],
#  'Duttke, Sascha Hans Christian': ['4.30'],
#  'Daugherty, Matthew Dorton': ['4.69', '4.71', '4.78', '4.73', '4.62'],
#  'Golden, James W': ['4.35',
#   '4.64',
#   '4.38',
#   '4.42',
#   '4.19',
#   '4.63',
#   '4.35',
#   '4.35',
#   '4.05',
#   '4.26',
#   '4.47'],
#  'Pickett, Brooke Elizabeth': [''],
#  'Petrie, Katherine Lynn': ['',
#   '',
#   '4.71',
#   '',
#   '4.76',
#   '',
#   '4.68',
#   '',
#   '',
#   '4.69',
#   '4.82',
#   '4.72'],
#  'Pirino, Giorgia': ['4.68',
#   '4.46',
#   '4.63',
#   '4.61',
#   '4.65',
#   '4.49',
#   '4.58',
#   '4.39',
#   '4.36',
#   '',
#   '',
#   '4.44',
#   '',
#   '4.55',
#   '4.56',
#   '',
#   '4.43',
#   '',
#   '4.58',
#   '4.08',
#   '',
#   '',
#   ''],
#  'Schiffer, Jamie Michelle': ['4.70', '4.40'],
#  'Pevzner, Pavel Arkadjevich': ['4.32',
#   '4.75',
#   '4.67',
#   '4.69',
#   '4.63',
#   '4.00',
#   '4.80'],
#  'Murre, Cornelis': ['4.73',
#   '4.80',
#   '4.92',
#   '4.86',
#   '5.00',
#   '4.86',
#   '4.64',
#   '4.70',
#   '4.82',
#   '4.71',
#   '4.43',
#   '4.65'],
#  'Hasty, Jeff M': ['4.89',
#   '4.76',
#   '5.00',
#   '4.69',
#   '4.77',
#   '4.79',
#   '4.56',
#   '5.00'],
#  'Yanofsky, Martin F.': ['4.92',
#   '4.90',
#   '4.70',
#   '4.90',
#   '4.70',
#   '4.75',
#   '4.75',
#   '4.48',
#   '4.81',
#   '4.54',
#   '4.67',
#   '4.36',
#   '4.55',
#   '4.72',
#   '4.79',
#   '4.50'],
#  'Bloodgood, Brenda Laurie': ['4.82',
#   '4.79',
#   '4.67',
#   '4.70',
#   '4.61',
#   '4.60',
#   '4.55',
#   '4.38'],
#  'Cooke, James Edward': ['4.73',
#   '4.74',
#   '4.68',
#   '4.85',
#   '4.84',
#   '4.45',
#   '4.70',
#   '4.86',
#   '4.69',
#   '4.76',
#   '4.68',
#   '4.75',
#   '4.86',
#   '4.66',
#   '4.61',
#   '4.73',
#   '4.77',
#   '4.88',
#   '4.80',
#   '4.79',
#   '4.68',
#   '4.80',
#   '4.68',
#   '4.57',
#   '4.59',
#   '4.70',
#   '4.83',
#   '4.48',
#   '3.74',
#   '4.49',
#   '4.44',
#   '4.27'],
#  'Reyes Gonzalez, Catalina': ['4.71',
#   '4.40',
#   '4.52',
#   '4.17',
#   '4.49',
#   '4.64',
#   '4.93',
#   '4.82',
#   '4.74',
#   '4.88',
#   '4.65',
#   '4.84',
#   '4.50',
#   '4.89',
#   '4.56',
#   '4.80',
#   '4.92',
#   '4.83',
#   '4.73',
#   '4.70',
#   '4.59',
#   '4.52',
#   '4.81',
#   '4.70'],
#  'Armour, Jon Christopher': ['4.92',
#   '4.85',
#   '4.66',
#   '4.72',
#   '4.93',
#   '4.94',
#   '4.92',
#   '4.82',
#   '4.84',
#   '4.97',
#   '4.91',
#   '4.96',
#   '5.00',
#   '4.92',
#   '5.00',
#   '4.95',
#   '4.92',
#   '4.92',
#   '4.78',
#   '4.98',
#   '4.93',
#   '5.00',
#   '4.76',
#   '4.73',
#   '4.93',
#   '4.92',
#   '4.94',
#   '5.00',
#   '4.70',
#   '4.83',
#   '4.89',
#   '4.93',
#   '4.88',
#   '4.76',
#   '4.93',
#   '4.92',
#   '4.97'],
#  'Hampton, Randolph Y.': ['4.67',
#   '4.71',
#   '4.69',
#   '4.73',
#   '4.76',
#   '4.31',
#   '4.55',
#   '4.66',
#   '4.79',
#   '4.64',
#   '4.72',
#   '4.44',
#   '4.40',
#   '4.76',
#   '4.67',
#   '4.63',
#   '4.67',
#   '4.73'],
#  'Banghart, Matthew Ryan': ['4.15', '5.00'],
#  'Leutgeb, Stefan': ['4.43',
#   '4.03',
#   '4.02',
#   '4.29',
#   '4.22',
#   '4.54',
#   '4.46',
#   '4.31',
#   '4.30',
#   '4.63',
#   '4.64',
#   '4.76'],
#  'Wang, Jing': ['4.61',
#   '3.58',
#   '4.44',
#   '4.19',
#   '4.32',
#   '4.61',
#   '4.40',
#   '4.67'],
#  'Juavinett, Ashley Lauren': ['', '', '4.57', '', '4.84', '', '4.80', '4.78'],
#  'Chu, Monica W': ['4.64',
#   '4.56',
#   '4.50',
#   '4.50',
#   '4.76',
#   '4.44',
#   '4.74',
#   '4.67',
#   '4.74',
#   '4.63',
#   '4.67',
#   '4.59',
#   '4.40',
#   '4.76',
#   '4.34',
#   '4.71',
#   '4.64',
#   '4.57',
#   '4.47'],
#  'Zou, Yimin': ['4.41',
#   '4.69',
#   '4.38',
#   '4.11',
#   '4.34',
#   '4.65',
#   '4.60',
#   '4.41',
#   '4.23',
#   '4.21',
#   '4.38'],
#  'Lim, Byungkook': ['4.73', '4.63', '4.24', '4.43', '4.64', '4.41', '4.33'],
#  'Root, Cory Matthew': ['4.40', '3.37', '3.22'],
#  'Leutgeb, Jill K.': ['4.88'],
#  'Ackerman, Susan': ['4.86'],
#  'Newsam, John': ['4.84',
#   '4.57',
#   '4.56',
#   '4.65',
#   '4.79',
#   '4.81',
#   '4.57',
#   '4.79',
#   '4.77'],
#  'Niwa, Maho': ['4.81', '4.36', '4.73', '4.37', '4.32', '3.93', '4.08'],
#  'Huffaker, Alisa': ['4.71',
#   '4.75',
#   '4.73',
#   '4.86',
#   '4.71',
#   '4.92',
#   '4.52',
#   '4.63',
#   '4.49'],
#  'Schmelz, Eric Alexander': ['4.48',
#   '4.70',
#   '4.46',
#   '4.87',
#   '4.45',
#   '4.85',
#   '4.09',
#   '4.13'],
#  'McDonnell, Lisa Marie': ['4.41',
#   '4.70',
#   '4.91',
#   '4.88',
#   '4.81',
#   '4.60',
#   '4.42',
#   '4.75',
#   '4.83',
#   '4.69',
#   '4.64',
#   '4.60',
#   '4.50',
#   '4.34',
#   '4.16',
#   '4.59',
#   '4.48',
#   '4.58',
#   '4.60',
#   '4.78',
#   '4.49',
#   '4.49',
#   '4.78',
#   '4.50',
#   '4.59',
#   '4.52',
#   '4.63',
#   '4.65'],
#  'Kiger, Amy': ['4.35', '4.41', '4.44', '4.41', '4.22', '4.20', '4.39'],
#  'Zuniga, Elina I': ['4.74',
#   '4.75',
#   '4.71',
#   '4.54',
#   '4.15',
#   '4.47',
#   '4.45',
#   '4.51',
#   '4.70'],
#  'Kohn, Joshua R': ['4.50',
#   '4.57',
#   '4.55',
#   '4.47',
#   '4.17',
#   '4.65',
#   '4.42',
#   '4.52',
#   '4.74',
#   '4.27'],
#  'Rennison, Diana': ['3.91'],
#  'Pekkurnaz Banghart, Gulcin': ['4.63',
#   '4.57',
#   '4.76',
#   '5.00',
#   '4.48',
#   '5.00',
#   '3.94',
#   '5.00',
#   '4.50'],
#  'Glasgow, Stacey Marie': ['4.50', '4.56', '4.35', '3.91'],
#  'Kuret, Thomas Joseph': ['4.55', '4.56'],
#  'Rana, Brinda Kanti': ['4.48',
#   '4.59',
#   '4.34',
#   '4.56',
#   '4.14',
#   '3.71',
#   '4.30'],
#  'Hedrick, Stephen M': ['4.70', '4.42', '4.57', '4.18'],
#  'Cook-Andersen, Heidi Leigh': ['4.32', '4.33'],
#  'Pasquinelli, Amy': ['4.69', '4.61', '4.77', '4.86', '4.72', '4.76', '4.81'],
#  'Golden, Susan S.': ['4.54',
#   '4.50',
#   '4.46',
#   '4.80',
#   '4.47',
#   '5.00',
#   '4.37',
#   '4.86',
#   '4.37',
#   '4.44',
#   '4.40',
#   '4.34',
#   '4.56',
#   '4.44'],
#  'Gorman, Michael R.': ['4.49',
#   '4.53',
#   '4.47',
#   '4.35',
#   '4.46',
#   '4.49',
#   '4.65',
#   '4.45'],
#  'Allen, Eric': ['4.92',
#   '5.00',
#   '4.63',
#   '4.72',
#   '4.93',
#   '4.92',
#   '4.64',
#   '4.80',
#   '4.76'],
#  'Russell, Alistair B': ['4.78'],
#  'Suel, Gurol Mehmet': ['4.61',
#   '4.59',
#   '4.49',
#   '4.70',
#   '4.61',
#   '4.78',
#   '5.00',
#   '4.86'],
#  'Grant, Barry J': ['4.86',
#   '4.80',
#   '4.91',
#   '4.84',
#   '4.92',
#   '4.83',
#   '4.71',
#   '4.95',
#   '4.83',
#   '4.79'],
#  'Mayfield, Stephen P.': ['4.79',
#   '4.80',
#   '4.88',
#   '4.82',
#   '4.44',
#   '4.66',
#   '4.75',
#   '4.81',
#   '4.80',
#   '4.50',
#   '4.80',
#   '4.78',
#   '5.00',
#   '4.69',
#   '4.40',
#   '4.64',
#   '4.63'],
#  'Lykke-Andersen, Jens': ['5.00',
#   '4.70',
#   '4.65',
#   '4.65',
#   '4.73',
#   '4.69',
#   '4.61',
#   '4.64',
#   '4.75'],
#  'Vijapurkar, Ulka': ['4.67',
#   '4.25',
#   '4.29',
#   '4.48',
#   '4.42',
#   '4.34',
#   '4.65',
#   '4.75',
#   '4.37',
#   '4.29',
#   '4.45'],
#  'Spitzer, Nicholas': ['4.53',
#   '4.68',
#   '4.78',
#   '4.56',
#   '4.72',
#   '4.69',
#   '4.56',
#   '4.69',
#   '4.70'],
#  'Wertheim, Joel Okrent': ['4.94', '4.86', '4.79'],
#  'Flagg, Matthew Paul': ['4.70', '4.67'],
#  'Petty, Emily L': ['4.78', '4.67'],
#  'Gustafson-Brown, Cindy': ['4.50',
#   '4.28',
#   '',
#   '4.85',
#   '4.38',
#   '',
#   '4.83',
#   '4.87',
#   '4.40',
#   '',
#   '4.66',
#   '4.83',
#   '',
#   '',
#   '4.81',
#   '4.87',
#   '4.65',
#   '4.77',
#   '',
#   '',
#   '4.80',
#   '',
#   '4.88',
#   '4.65',
#   '',
#   '4.62',
#   '',
#   '4.71',
#   '4.79',
#   '4.75',
#   '4.70',
#   '4.68',
#   '',
#   '',
#   '4.82',
#   '4.77',
#   '4.80',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '4.77',
#   '4.76',
#   '4.94',
#   '',
#   '',
#   '',
#   '4.80',
#   '4.84',
#   '4.83',
#   '',
#   '',
#   '4.76',
#   '4.77'],
#  'Pagniello, Camille': ['4.71'],
#  'Wills, Christopher': ['4.53',
#   '4.89',
#   '4.61',
#   '4.81',
#   '4.54',
#   '4.26',
#   '4.35',
#   '4.57',
#   '4.40',
#   '4.44',
#   '4.50'],
#  'Pagliuso, Delaney Catherine': ['4.50'],
#  'Mudla, Anusorn': ['4.27', '4.50', '4.58'],
#  'Tat, John': ['4.75', '4.73'],
#  'Alfonso, Stephanie Isabel': ['4.38', '4.37', '4.36'],
#  'Cook, Orna': ['4.42', '4.64', '4.47'],
#  'Teodorof, Carmen': ['4.51',
#   '4.63',
#   '4.40',
#   '4.41',
#   '4.04',
#   '4.30',
#   '4.13',
#   '3.75'],
#  'Chun, Lauren Elizabeth': ['4.29'],
#  'McCulloch, Katherine Anne': ['4.40'],
#  'Lebeaupin, Cynthia D': ['4.72'],
#  'Hsu, Jeremy Lutan': ['4.72'],
#  'Ita, Sergio': ['4.53'],
#  'Coley, Austin Avery': ['4.06'],
#  'Forbes, Douglass Jane': ['4.57',
#   '4.64',
#   '4.61',
#   '4.68',
#   '4.53',
#   '4.68',
#   '4.67',
#   '4.58'],
#  'Cooper, Kimberly Lynn': ['4.74',
#   '4.58',
#   '4.65',
#   '4.65',
#   '4.63',
#   '4.60',
#   '4.63',
#   '4.82',
#   '4.55'],
#  'Traver, David': ['4.61', '4.76', '4.61', '4.60', '4.84', '4.22'],
#  'Lu, Li-Fan': ['4.56',
#   '4.75',
#   '4.79',
#   '4.69',
#   '4.75',
#   '4.52',
#   '4.70',
#   '4.47',
#   '4.54',
#   '4.75',
#   '4.70'],
#  'Rifkin, Scott': ['4.44',
#   '4.06',
#   '4.59',
#   '4.70',
#   '3.92',
#   '4.88',
#   '3.80',
#   '5.00',
#   '4.07',
#   '4.06',
#   '4.82',
#   '4.06',
#   '4.55',
#   '4.07'],
#  'Meyer, Justin Raymond': ['4.79', '4.57', '4.54', '4.59', '4.30'],
#  'Nieh, James Charles': ['4.93',
#   '4.82',
#   '4.83',
#   '4.80',
#   '4.76',
#   '4.00',
#   '4.87',
#   '4.92',
#   '4.74',
#   '4.93'],
#  'Patrick, Gentry': ['4.41',
#   '4.44',
#   '4.31',
#   '4.40',
#   '4.06',
#   '4.78',
#   '4.86',
#   '4.45',
#   '4.44'],
#  'Kurle, Carolyn M.': ['4.70',
#   '4.83',
#   '4.75',
#   '4.71',
#   '4.61',
#   '4.72',
#   '4.75',
#   '4.78',
#   '4.75',
#   '4.73',
#   '4.72',
#   '4.75',
#   '4.60'],
#  'Bier, Ethan': ['4.68',
#   '4.40',
#   '4.46',
#   '4.43',
#   '4.69',
#   '4.36',
#   '4.53',
#   '4.58',
#   '4.56',
#   '4.33',
#   '4.56'],
#  'Pruneda-Paz, Jose L.': ['4.54',
#   '4.75',
#   '4.59',
#   '4.82',
#   '4.67',
#   '4.77',
#   '4.54',
#   '4.89',
#   '4.38',
#   '4.63',
#   '4.38',
#   '4.75',
#   '4.22',
#   '4.14'],
#  "O'Rourke, Aubrie Elise": ['', ''],
#  'Dutton, Rachel Janelle': ['4.86', '4.61', '4.88', '4.28'],
#  'Bafna, Vineet': ['4.69', '4.30', '4.25', '4.67', '4.00', '5.00'],
#  'Goldrath, Ananda': ['4.92',
#   '4.79',
#   '4.70',
#   '4.59',
#   '4.79',
#   '4.60',
#   '4.56',
#   '4.71',
#   '4.52'],
#  'Sejnowski, Terrence J': ['4.14',
#   '4.00',
#   '4.64',
#   '4.29',
#   '4.50',
#   '4.54',
#   '3.80'],
#  'Halpain, Shelley': ['4.70',
#   '3.92',
#   '4.31',
#   '4.34',
#   '4.22',
#   '4.31',
#   '4.20',
#   '4.63',
#   '4.06',
#   '4.15'],
#  'Malinow, Roberto': ['4.86',
#   '4.92',
#   '5.00',
#   '4.91',
#   '4.60',
#   '4.63',
#   '4.75',
#   '5.00'],
#  'French, Kathleen Ann': ['4.63',
#   '4.00',
#   '4.40',
#   '4.20',
#   '5.00',
#   '4.08',
#   '4.65',
#   '4.25',
#   '4.38',
#   '4.57',
#   '4.36',
#   '4.35',
#   '4.50',
#   '4.67',
#   '4.64',
#   '4.52',
#   '4.13',
#   '4.31',
#   '4.77',
#   '4.34',
#   '4.70',
#   '4.64',
#   '4.47',
#   '4.53',
#   '4.30',
#   '4.92'],
#  'Greenspan, Ralph J.': ['4.67'],
#  'Chisholm, Andrew D.': ['4.88'],
#  'Estelle, Mark': ['4.63',
#   '5.00',
#   '4.76',
#   '4.67',
#   '5.00',
#   '4.54',
#   '4.63',
#   '4.60'],
#  'Troemel, Emily Ruth': ['4.57',
#   '4.46',
#   '4.24',
#   '4.52',
#   '4.50',
#   '4.48',
#   '4.50'],
#  'Villa Rodriguez, Elizabeth': ['4.13', '4.80', '4.30', '5.00', '4.16'],
#  'Shurin, Jonathan': ['4.45',
#   '4.78',
#   '4.42',
#   '4.77',
#   '4.46',
#   '4.41',
#   '4.33',
#   '4.49',
#   '4.29',
#   '4.71',
#   '4.41'],
#  'Holway, David A.': ['4.84',
#   '4.70',
#   '4.80',
#   '4.45',
#   '4.76',
#   '4.44',
#   '4.67',
#   '4.48',
#   '4.69'],
#  'Saier, Milton H.': ['4.67',
#   '4.67',
#   '4.43',
#   '4.50',
#   '3.67',
#   '3.99',
#   '4.57',
#   '4.82',
#   '4.78',
#   '4.25',
#   '4.09',
#   '4.44',
#   '4.41',
#   '4.50',
#   '4.50',
#   '4.27',
#   '4.83',
#   '4.18',
#   '4.25',
#   '4.20',
#   '4.60',
#   '3.88',
#   '5.00',
#   '4.80',
#   '4.33',
#   '4.20',
#   '4.36',
#   '4.42',
#   '4.56',
#   '5.00',
#   '4.20',
#   '4.60',
#   '4.50',
#   '4.36',
#   '4.11',
#   '4.61',
#   '4.70',
#   '4.54',
#   '4.58',
#   '3.95',
#   '4.80',
#   '5.00',
#   '4.56',
#   '4.77',
#   '4.50',
#   '4.50',
#   '4.26',
#   '4.60',
#   '4.77',
#   '4.64',
#   '4.46',
#   '4.29',
#   '4.32',
#   '4.00',
#   '4.38',
#   '4.63',
#   '4.89'],
#  'Lauberth, Shannon Marie': ['4.50', '4.44', '4.62', '4.64', '4.66', '4.32'],
#  'Kadonaga, James T': ['4.79',
#   '4.89',
#   '4.77',
#   '4.81',
#   '4.62',
#   '4.78',
#   '4.86',
#   '4.76'],
#  'David, Michael': ['4.69',
#   '4.71',
#   '4.80',
#   '4.71',
#   '4.82',
#   '4.75',
#   '4.73',
#   '4.77'],
#  'Bennett, Eric J': ['4.76', '4.73', '4.77', '4.54', '4.67', '4.63', '4.63'],
#  'Herzik, Mark Anthony': ['5.00'],
#  'McHugh, Colleen A': ['4.40', '4.25'],
#  'Jin, Yishi': ['4.40', '5.00', '5.00', '4.67', '4.36', '4.80'],
#  'Muotri, Alysson': ['5.00', '4.40', '4.70', '4.50', '4.57', '5.00'],
#  'Wilhelm, James E.': ['4.69', '4.85', '4.81', '4.53', '4.67', '4.67', '4.58'],
#  'Kryazhimskiy, Sergey A': ['4.58', '4.75', '4.83', '4.70'],
#  'Ryan, Elizabeth Mary': ['4.71'],
#  'Butler, Madeline': ['4.64',
#   '4.76',
#   '4.57',
#   '5.00',
#   '4.73',
#   '4.83',
#   '4.73',
#   '4.90',
#   '4.87',
#   '4.73',
#   '4.89',
#   '4.92',
#   '4.76',
#   '4.88',
#   '4.70'],
#  'McGinnis, William James': ['4.56', '4.36'],
#  'Tour, Ella': ['4.78',
#   '4.90',
#   '',
#   '',
#   '',
#   '4.27',
#   '',
#   '4.40',
#   '4.43',
#   '',
#   '4.43',
#   '4.56',
#   '',
#   '',
#   '4.49',
#   '4.69',
#   '4.86',
#   '4.42',
#   '4.74',
#   '4.70',
#   '4.40'],
#  'Karlseder, Jan': ['4.60', '5.00', '4.67'],
#  'Saghatelian, Alan': ['4.60', '5.00', '4.73'],
#  'Paxman, Julie Roberts': ['4.39'],
#  'Rizk, Maryan Girgis Soliman': ['4.52', '4.47', '4.00'],
#  'Mak, Raymond Hengfai': ['4.13'],
#  'Painter, Chelsea Danielle': ['4.45', '4.76'],
#  'Puritty, Chandler Elizabeth': ['4.67'],
#  'Adomako, Marie Antonia': ['4.36'],
#  'Mohan, Swarna': ['4.72',
#   '4.38',
#   '4.69',
#   '4.28',
#   '4.66',
#   '4.94',
#   '4.31',
#   '4.54',
#   '4.82',
#   '',
#   '',
#   '4.66',
#   '4.56'],
#  'Desai, Arshad': ['5.00', '4.88', '4.92', '4.75'],
#  'Oegema, Karen': ['5.00', '4.89', '4.83', '4.80'],
#  'Roy, Kaustuv': ['4.80',
#   '4.56',
#   '4.79',
#   '5.00',
#   '4.62',
#   '4.64',
#   '4.71',
#   '5.00',
#   '4.56'],
#  'Wasserman, Steven A.': ['4.65', '4.75', '4.70', '4.70', '4.78', '4.80'],
#  'Farley, Emma Kristen': ['4.55'],
#  'Fortes, P. A. George': ['4.56',
#   '4.51',
#   '4.61',
#   '4.82',
#   '4.52',
#   '4.66',
#   '4.11',
#   '3.90',
#   '4.16',
#   '4.41',
#   '4.07',
#   '4.47',
#   '4.64',
#   '4.33',
#   '4.35',
#   '4.25',
#   '4.28',
#   '4.33',
#   '4.13',
#   '4.42',
#   '4.29',
#   '4.43',
#   '4.43',
#   '4.53',
#   '4.50',
#   '4.50',
#   '4.60',
#   '3.98',
#   '4.63',
#   '4.09',
#   '4.50',
#   '4.00',
#   '4.48',
#   '4.48',
#   '4.32',
#   '4.44',
#   '4.18',
#   '4.40',
#   '4.57',
#   '4.68',
#   '4.47',
#   '4.29',
#   '4.38',
#   '4.44',
#   '4.62'],
#  'Xu, Yang': ['3.44',
#   '3.88',
#   '4.43',
#   '4.19',
#   '4.44',
#   '4.33',
#   '4.28',
#   '4.33',
#   '4.83',
#   '4.25',
#   '3.95',
#   '4.67',
#   '4.30'],
#  'Broccard Bell, Heather Chr': ['4.58', '4.72', '4.75', '4.36'],
#  'Byrne, Kathryne': ['3.49', '4.19', '3.28', '3.11'],
#  'Gentner, Tim': ['4.67'],
#  'Pfaff, Samuel': ['4.80', '4.67', '4.74', '4.47', '4.58'],
#  'Doblas Ibanez, Paula Adela': ['4.72'],
#  'Ryan, Genevieve Elaine': ['4.09', '4.37'],
#  'Davis, Amanda Gabrielle': ['4.78'],
#  'Waterton, Joseph Sebastian': ['4.48'],
#  'Herndon, Jenny Dyann': ['4.63',
#   '4.27',
#   '4.36',
#   '4.69',
#   '4.71',
#   '4.65',
#   '4.25',
#   '4.39',
#   '4.19',
#   '4.64',
#   '4.78',
#   '4.51',
#   '4.32',
#   '4.57',
#   '4.53',
#   '4.38',
#   '4.07'],
#  'Baker, Timothy Stanley': ['4.75', '4.63', '4.86', '4.86', '4.33'],
#  'Bansal, Vikas': ['4.33'],
#  'Heinrich, Erica C': ['4.71'],
#  'Crawford, Nigel M.': ['4.78',
#   '4.88',
#   '4.71',
#   '4.80',
#   '4.72',
#   '5.00',
#   '4.71',
#   '4.79',
#   '4.76',
#   '4.76',
#   '4.66',
#   '4.89'],
#  'Henter, Heather J.': ['4.71', '4.83', '4.83', '4.73', '4.63', '4.65'],
#  'Espin Palazon, Raquel': ['4.17', '3.77'],
#  'Grainger, Stephanie L': ['4.62'],
#  'Markmiller, Rea Lardelli': ['4.39'],
#  'De Silva, Shermin': ['4.31'],
#  'Chilukuri, Lakshmi N': ['',
#   '4.60',
#   '',
#   '',
#   '4.32',
#   '4.80',
#   '',
#   '',
#   '',
#   '',
#   '4.60',
#   '',
#   '',
#   '4.14',
#   '',
#   '',
#   '',
#   '4.50',
#   '',
#   '',
#   '4.76'],
#  'Erb, Marcella L': ['4.91'],
#  'Raiko, Mikhail P.': ['3.86'],
#  'Rodionov, Dmitry A': ['4.20'],
#  'Medrano Soto, Luis Arturo': ['4.57'],
#  'Posakony, James W': ['4.82', '4.69', '4.67', '4.86', '4.58'],
#  'Montal, S. Maurice': ['4.22', '4.30'],
#  'Heinrichsen, Erilynn Terese': ['4.04'],
#  'Ghosh Dastidar, Ranita': ['3.53'],
#  'Bloomekatz, Joshua': ['3.77'],
#  'Hicks, Jenna Schug': ['4.63'],
#  'Lewis, Levi Steele': ['4.35'],
#  'Wang, Jean Yin Jen': ['4.41', '4.47'],
#  'Dunbar, Tiffany L': ['', '', '', '', '', '', '', '4.72', '4.58'],
#  'Ring, Gabriela Aviva': ['', '', '', '4.59', '4.35'],
#  'Pogliano, Kit J.': ['4.82', '4.64', '4.67', '4.70'],
#  'Do, Long Hoang': ['', '', ''],
#  'Collins, Eva-Maria Schoetz': ['4.72', '4.64'],
#  'Goulding, Martyn': ['4.45', '4.09', '4.23', '4.27'],
#  'Lee, Kuo Fen': ['4.40', '4.32', '4.23', '4.09'],
#  'La Spada, Albert': ['4.40', '4.50', '4.86', '4.50'],
#  'Reinagel, Pam': ['3.71', '4.10', '4.41'],
#  'Kristan, William B.': ['4.19', '4.39'],
#  'Todd, Krista L.': ['4.35', '3.22', '4.23'],
#  'Perks, Krista Eva': ['3.38'],
#  'Noto, Akana Elizabeth': ['4.31'],
#  'Clark, Dan': ['4.86', '4.91', '4.84', '4.82'],
#  'Ghiara, Jayant': ['4.50', '4.82', '4.79', '4.77', '4.84', '4.79', '4.93'],
#  'Huberman, Andrew David': ['4.74', '4.76', '4.83'],
#  'Berg, Darwin K.': ['4.62', '4.60', '4.73', '4.73'],
#  'Markow, Therese A.': ['4.24', '4.00'],
#  'Wienhausen, Gabriele': ['4.00', '4.88', '4.91', '5.00', '4.89'],
#  'Scanziani, Massimo': ['4.35', '4.77', '4.67'],
#  'Scheffler, Immo E.': ['4.52', '4.70'],
#  'Richmond, Maxi Polihronaki': ['4.30'],
#  'Schoetz, Eva-Maria': ['4.67'],
#  'Strum, Shirley C.': ['4.35', '4.55'],
#  'Woodruff, David S': ['4.64', '4.62', '4.37', '4.67', '4.55', '4.67', '4.80'],
#  'Clemmons, Alexa Watson': ['4.68'],
#  'Emerson, Beverly Marie': ['4.43'],
#  'Jones, Katherine A.': ['4.50'],
#  'Brown, Willie C.': ['4.47', '4.71'],
#  'Aroian, Raffi V.': ['4.84', '4.62'],
#  'Sternfeld, Matthew J': ['4.64'],
#  'Marietou, Angeliki': [''],
#  'Gantner, Marin Leigh': ['4.64'],
#  'Pykalainen, Anette': ['3.85'],
#  'Price, Paul A.': ['4.78', '4.93'],
#  'Curington, John Gibson': ['4.59', '4.54'],
#  'Rypien, Krystal L': ['4.53', '4.59', '4.54'],
#  'Johnson, Tracy Lanise': ['5.00', '4.70'],
#  'Tam, Tobey M': ['4.22'],
#  'Trujillo, Gloriana V.': ['3.96'],
#  'Trial, Rachelle Marie': ['4.48']}

# %%
prof_dict2
# Out:
# {'Hui, Enfu': ['4.57', '4.33', '4.73', '4.23', '5.00', '4.60'],
#  'Zhao, Yunde': ['3.59',
#   '4.10',
#   '4.30',
#   '3.64',
#   '3.60',
#   '3.75',
#   '3.82',
#   '3.68',
#   '4.13',
#   '3.39',
#   '4.20',
#   '3.84',
#   '3.92',
#   '2.63',
#   '4.31'],
#  'Feng, Gen-Sheng': ['3.60',
#   '3.46',
#   '3.58',
#   '3.66',
#   '3.61',
#   '3.62',
#   '3.94',
#   '3.07'],
#  'Coleman, Aaron B.': ['4.59',
#   '4.79',
#   '4.66',
#   '4.69',
#   '4.73',
#   '4.65',
#   '4.68',
#   '4.54',
#   '4.74',
#   '4.60',
#   '4.59',
#   '4.73',
#   '4.43',
#   '4.63',
#   '4.67',
#   '4.73',
#   '4.67',
#   '4.57',
#   '4.58',
#   '4.55',
#   '4.64',
#   '4.63',
#   '4.68',
#   '4.57',
#   '4.82',
#   '4.76',
#   '4.48',
#   '4.60',
#   '4.26',
#   '4.48',
#   '4.39',
#   '4.92',
#   '4.70',
#   '4.65',
#   '4.61',
#   '4.76'],
#  'Soowal, Lara': ['4.38',
#   '4.15',
#   '4.86',
#   '4.57',
#   '4.62',
#   '4.50',
#   '4.36',
#   '4.57',
#   '4.03',
#   '4.53',
#   '4.39',
#   '3.00',
#   '4.32',
#   '3.88',
#   '4.00',
#   '3.38',
#   '3.36',
#   '4.33',
#   '4.33',
#   '4.04',
#   '3.89',
#   '4.33',
#   '4.27',
#   '4.57',
#   '4.32'],
#  'Bozinovic, Goran': ['4.14',
#   '4.04',
#   '4.41',
#   '4.41',
#   '4.26',
#   '4.43',
#   '4.80',
#   '3.60',
#   '4.53',
#   '4.35',
#   '4.08',
#   '4.58',
#   '4.88',
#   '3.82',
#   '4.60',
#   '4.43',
#   '4.03',
#   '4.10',
#   '4.27',
#   '4.42',
#   '4.25',
#   '4.25',
#   '4.42',
#   '3.86',
#   '4.49',
#   '4.25',
#   '4.24',
#   '4.57',
#   '4.58',
#   '4.29',
#   '3.83',
#   '4.37',
#   '4.37',
#   '4.67',
#   '3.92',
#   '4.33',
#   '4.36',
#   '3.52',
#   '4.13',
#   '4.69',
#   '4.60',
#   '4.65',
#   '4.47',
#   '4.00',
#   '4.00',
#   '4.30',
#   '4.00',
#   '4.34',
#   '4.43',
#   '4.26',
#   '4.47',
#   '4.62',
#   '4.59',
#   '4.15',
#   '3.64',
#   '3.96',
#   '4.25'],
#  'Miller, Steven W.': ['4.14',
#   '4.24',
#   '4.31',
#   '4.00',
#   '4.38',
#   '4.15',
#   '3.46',
#   '3.71',
#   '3.82',
#   '3.64',
#   '3.67',
#   '3.79',
#   '4.20',
#   '4.50',
#   '4.77',
#   '4.41',
#   '4.68',
#   '4.16',
#   '4.44',
#   '4.65',
#   '4.10'],
#  'Rusert, Jessica Marie': ['3.86', '3.13', '3.88', '3.59', '4.03', '3.78'],
#  'Smith, Laurie': ['4.16',
#   '4.36',
#   '4.24',
#   '4.44',
#   '4.53',
#   '4.47',
#   '4.64',
#   '4.45',
#   '4.24',
#   '4.42',
#   '4.34',
#   '4.42',
#   '4.33'],
#  'Yelon, Deborah': ['4.37', '4.72', '4.52'],
#  'Butler, Shannon Rhey': ['4.25',
#   '4.19',
#   '4.29',
#   '4.20',
#   '4.25',
#   '4.31',
#   '4.13',
#   '4.01',
#   '4.25',
#   '4.42',
#   '4.00',
#   '4.81',
#   '4.35'],
#  'Stockwell, Sarah R': ['4.71',
#   '4.71',
#   '4.83',
#   '4.82',
#   '4.82',
#   '4.69',
#   '4.69',
#   '4.43',
#   '4.59',
#   '4.61',
#   '4.51',
#   '4.61',
#   '4.60',
#   '4.87',
#   '4.54',
#   '4.42',
#   '4.51',
#   '4.59',
#   '4.67',
#   '4.52',
#   '4.59',
#   '4.53',
#   '4.15',
#   '4.39',
#   '4.63',
#   '4.35',
#   '4.45',
#   '4.04',
#   '4.39',
#   '3.74',
#   '5.00',
#   '3.92'],
#  'Barton, Andrew David': ['4.61', '4.49', '4.72', '4.54', '4.40', '4.44'],
#  'Chao, Lin': ['4.15',
#   '3.33',
#   '4.50',
#   '4.33',
#   '4.44',
#   '4.55',
#   '4.43',
#   '4.38',
#   '4.46',
#   '4.78',
#   '4.49',
#   '4.80',
#   '4.38',
#   '4.38',
#   '4.51',
#   '4.55',
#   '4.71'],
#  'Cooper, Andrew Michael': ['4.30',
#   '4.26',
#   '4.28',
#   '3.99',
#   '4.23',
#   '4.30',
#   '4.29',
#   '4.32',
#   '4.25',
#   '4.57',
#   '4.73',
#   '4.61',
#   '4.55',
#   '4.47',
#   '4.38',
#   '4.39',
#   '4.11',
#   '4.40',
#   '4.35'],
#  'Owens, Melinda Tsao-Ying': ['4.71',
#   '4.63',
#   '4.84',
#   '4.69',
#   '4.75',
#   '4.51',
#   '4.51',
#   '3.84',
#   '3.88',
#   '4.08',
#   '4.09',
#   '4.03',
#   '4.09'],
#  'Komiyama, Takaki': ['4.37', '4.42', '4.43', '4.26', '4.54', '4.29', '4.33'],
#  'Su, Chih-Ying': ['4.17',
#   '4.39',
#   '4.24',
#   '4.64',
#   '4.16',
#   '4.68',
#   '4.38',
#   '4.51',
#   '4.07',
#   '4.45',
#   '4.05',
#   '3.95',
#   '3.96'],
#  'Schroeder, Julian I': ['4.29',
#   '4.05',
#   '4.12',
#   '3.99',
#   '4.15',
#   '4.32',
#   '3.88'],
#  'Park, Ji Young': ['4.47',
#   '4.66',
#   '4.44',
#   '4.20',
#   '4.58',
#   '4.63',
#   '4.33',
#   '4.03'],
#  'Strause, Linda G.': ['4.24',
#   '4.27',
#   '4.19',
#   '4.28',
#   '4.22',
#   '4.20',
#   '4.34',
#   '4.35',
#   '4.38'],
#  'Gambel, Jessica Erin': ['4.39', '4.63', '4.36', '4.42', '4.31', '4.63'],
#  'Caffrey, Carolee': ['3.87', '4.36', '3.86', '4.37', '4.21'],
#  'Macagno, Eduardo R.': ['4.56',
#   '4.40',
#   '4.23',
#   '4.18',
#   '4.27',
#   '3.80',
#   '4.32',
#   '4.16',
#   '4.50',
#   '4.13',
#   '4.33',
#   '4.14',
#   '5.00',
#   '4.38'],
#  'Mel, Stephanie': ['4.60',
#   '4.82',
#   '4.26',
#   '4.29',
#   '4.53',
#   '4.51',
#   '4.67',
#   '4.58',
#   '4.47',
#   '4.37',
#   '4.62',
#   '4.50',
#   '4.74',
#   '4.86',
#   '4.33',
#   '4.50',
#   '4.68',
#   '4.70',
#   '4.62',
#   '4.45',
#   '4.35',
#   '4.79',
#   '4.13',
#   '4.45',
#   '4.35',
#   '4.32',
#   '4.65',
#   '4.50',
#   '4.46',
#   '4.53',
#   '4.55',
#   '4.50',
#   '4.06',
#   '4.22',
#   '4.71',
#   '4.46',
#   '4.71',
#   '4.19',
#   '4.11',
#   '4.79',
#   '4.57',
#   '5.00',
#   '4.71',
#   '4.72',
#   '4.88'],
#  'Lo, Stanley Malvin Ming-Hi': ['4.35',
#   '4.87',
#   '4.68',
#   '4.65',
#   '4.62',
#   '4.64',
#   '4.45',
#   '4.43',
#   '4.64',
#   '4.71',
#   '4.65',
#   '4.29',
#   '4.36',
#   '4.73',
#   '4.27',
#   '4.45',
#   '4.13',
#   '4.50',
#   '4.16',
#   '4.02',
#   '3.55',
#   '3.60',
#   '3.39',
#   '4.56',
#   '4.17',
#   '4.28',
#   '4.11',
#   '3.59',
#   '4.44',
#   '3.90',
#   '3.97',
#   '3.96',
#   '4.71',
#   '4.69',
#   '4.33',
#   '4.59',
#   '4.82'],
#  'Reuther, Keefe': ['4.62',
#   '4.64',
#   '4.50',
#   '4.63',
#   '4.51',
#   '4.52',
#   '4.46',
#   '4.67',
#   '4.70',
#   '4.64',
#   '4.38',
#   '4.42',
#   '4.79',
#   '4.32',
#   '4.51',
#   '4.61',
#   '4.60',
#   '4.63',
#   '4.53',
#   '4.59',
#   '4.66',
#   '4.50',
#   '4.35',
#   '4.62',
#   '4.44',
#   '4.58',
#   '4.00',
#   '4.68',
#   '4.65',
#   '4.20',
#   '4.19',
#   '4.31',
#   '4.32',
#   '4.45',
#   '4.52',
#   '4.48',
#   '4.37',
#   '4.39',
#   '4.36',
#   '4.45',
#   '4.63',
#   '4.47',
#   '4.36',
#   '4.30',
#   '4.43',
#   '4.28',
#   '4.56',
#   '4.45',
#   '4.17',
#   '4.44',
#   '4.56',
#   '4.53',
#   '4.39',
#   '4.53',
#   '4.45',
#   '4.67',
#   '4.24',
#   '4.44',
#   '4.32',
#   '4.06',
#   '3.61',
#   '4.27',
#   '4.07',
#   '3.93'],
#  'Cleland, Elsa Eleanor': ['4.83',
#   '4.64',
#   '5.00',
#   '4.56',
#   '4.26',
#   '4.43',
#   '4.07',
#   '4.57',
#   '4.26',
#   '4.82',
#   '5.00',
#   '4.72',
#   '4.81',
#   '4.27',
#   '4.47'],
#  'Pogliano, Joseph': ['4.00',
#   '4.75',
#   '4.67',
#   '4.63',
#   '4.69',
#   '4.67',
#   '4.73',
#   '4.56',
#   '4.82',
#   '4.67',
#   '4.58',
#   '4.88',
#   '4.81',
#   '4.85',
#   '4.57',
#   '4.67',
#   '4.86'],
#  'Briggs, Steven': ['5.00', '4.83', '4.23', '4.31', '4.50', '4.82', '4.75'],
#  'Akbari, Omar Sultan': ['3.99', '4.64', '4.06', '4.84', '4.24'],
#  'Hao, Nan': ['4.59',
#   '4.45',
#   '4.53',
#   '4.57',
#   '4.37',
#   '4.62',
#   '4.60',
#   '4.61',
#   '4.09',
#   '4.44'],
#  'Meaders, Clara Leigh': ['4.89'],
#  'Burg, Michael': ['4.43',
#   '4.39',
#   '4.49',
#   '4.71',
#   '4.61',
#   '4.51',
#   '4.40',
#   '4.33',
#   '4.39',
#   '4.30',
#   '4.46',
#   '4.46',
#   '4.33',
#   '4.55',
#   '4.17',
#   '4.44',
#   '4.55',
#   '4.67',
#   '4.71',
#   '4.55',
#   '4.61',
#   '4.50',
#   '4.38',
#   '4.45',
#   '4.63',
#   '3.87',
#   '4.01',
#   '4.27',
#   '4.74',
#   '4.08',
#   '4.45',
#   '4.34',
#   '4.25',
#   '4.42',
#   '4.36'],
#  'Day, Christopher D': ['4.49',
#   '4.56',
#   '4.16',
#   '4.16',
#   '3.96',
#   '4.32',
#   '4.13',
#   '4.25',
#   '4.39',
#   '4.70',
#   '4.08',
#   '4.19',
#   '4.46',
#   '4.33',
#   '4.13',
#   '3.76',
#   '4.00',
#   '4.17',
#   '3.69',
#   '3.75',
#   '4.00',
#   '4.00',
#   '4.13',
#   '3.97',
#   '3.77',
#   '4.27',
#   '4.19'],
#  'Grossman, Emily N': ['4.70',
#   '4.64',
#   '4.28',
#   '4.66',
#   '4.76',
#   '4.64',
#   '3.79',
#   '4.60',
#   '3.54',
#   '4.49',
#   '3.88',
#   '4.47',
#   '3.88',
#   '4.71',
#   '4.57',
#   '4.18',
#   '4.65',
#   '3.85',
#   '4.66',
#   '4.68',
#   '4.68',
#   '4.54',
#   '4.65',
#   '4.09',
#   '4.53',
#   '4.49',
#   '3.16'],
#  'Zhang, Dong-Er': ['4.13', '4.07', '4.13', '4.35', '4.17', '4.42'],
#  'Duttke, Sascha Hans Christian': ['3.37'],
#  'Daugherty, Matthew Dorton': ['4.57', '4.57', '4.78', '4.57', '4.55'],
#  'Golden, James W': ['4.10',
#   '4.43',
#   '4.26',
#   '4.42',
#   '4.04',
#   '4.75',
#   '4.27',
#   '4.35',
#   '3.95',
#   '4.28',
#   '4.38'],
#  'Pickett, Brooke Elizabeth': ['4.82'],
#  'Petrie, Katherine Lynn': ['4.82',
#   '4.84',
#   '4.63',
#   '4.82',
#   '4.65',
#   '4.86',
#   '4.64',
#   '4.73',
#   '4.94',
#   '4.68',
#   '4.76',
#   '4.88'],
#  'Pirino, Giorgia': ['4.53',
#   '4.22',
#   '4.41',
#   '4.31',
#   '4.34',
#   '4.15',
#   '4.28',
#   '3.97',
#   '3.97',
#   '4.51',
#   '4.75',
#   '4.02',
#   '4.58',
#   '4.28',
#   '4.43',
#   '4.56',
#   '4.13',
#   '4.26',
#   '4.36',
#   '3.50',
#   '4.48',
#   '4.65',
#   '4.58'],
#  'Schiffer, Jamie Michelle': ['4.39', '4.00'],
#  'Pevzner, Pavel Arkadjevich': ['3.26',
#   '3.47',
#   '3.40',
#   '3.92',
#   '4.00',
#   '3.40',
#   '4.20'],
#  'Murre, Cornelis': ['4.50',
#   '4.35',
#   '4.83',
#   '4.47',
#   '5.00',
#   '4.45',
#   '4.55',
#   '4.60',
#   '4.53',
#   '4.35',
#   '3.93',
#   '4.45'],
#  'Hasty, Jeff M': ['4.90',
#   '4.59',
#   '4.56',
#   '4.83',
#   '4.77',
#   '4.36',
#   '4.44',
#   '4.33'],
#  'Yanofsky, Martin F.': ['4.83',
#   '4.80',
#   '4.51',
#   '4.80',
#   '4.60',
#   '4.75',
#   '4.69',
#   '4.39',
#   '4.75',
#   '4.33',
#   '4.82',
#   '4.29',
#   '4.36',
#   '4.64',
#   '4.71',
#   '4.25'],
#  'Bloodgood, Brenda Laurie': ['4.68',
#   '4.52',
#   '4.38',
#   '4.24',
#   '4.39',
#   '4.34',
#   '4.29',
#   '4.02'],
#  'Cooke, James Edward': ['4.67',
#   '4.77',
#   '4.67',
#   '4.85',
#   '4.81',
#   '4.55',
#   '4.72',
#   '4.88',
#   '4.58',
#   '4.63',
#   '4.25',
#   '4.77',
#   '4.92',
#   '4.39',
#   '4.22',
#   '4.59',
#   '4.72',
#   '4.74',
#   '4.65',
#   '4.64',
#   '4.67',
#   '4.60',
#   '4.43',
#   '4.20',
#   '4.68',
#   '4.68',
#   '4.85',
#   '4.11',
#   '4.11',
#   '4.28',
#   '4.47',
#   '3.92'],
#  'Reyes Gonzalez, Catalina': ['4.39',
#   '4.02',
#   '4.11',
#   '4.20',
#   '4.10',
#   '4.36',
#   '4.86',
#   '4.67',
#   '4.52',
#   '4.66',
#   '4.30',
#   '4.59',
#   '4.07',
#   '4.80',
#   '4.26',
#   '4.67',
#   '4.77',
#   '4.74',
#   '4.38',
#   '4.42',
#   '4.46',
#   '4.20',
#   '4.75',
#   '4.70'],
#  'Armour, Jon Christopher': ['4.69',
#   '4.58',
#   '4.38',
#   '4.50',
#   '4.79',
#   '4.87',
#   '4.79',
#   '4.86',
#   '4.71',
#   '4.92',
#   '4.64',
#   '4.87',
#   '4.95',
#   '4.81',
#   '4.80',
#   '4.72',
#   '4.87',
#   '4.83',
#   '4.67',
#   '4.90',
#   '4.87',
#   '4.92',
#   '4.53',
#   '4.76',
#   '4.80',
#   '4.75',
#   '4.88',
#   '4.79',
#   '4.55',
#   '4.70',
#   '4.50',
#   '4.90',
#   '4.76',
#   '4.57',
#   '4.86',
#   '4.86',
#   '4.92'],
#  'Hampton, Randolph Y.': ['4.42',
#   '4.32',
#   '4.58',
#   '4.44',
#   '4.27',
#   '4.11',
#   '4.24',
#   '4.02',
#   '4.64',
#   '4.35',
#   '4.20',
#   '4.44',
#   '4.35',
#   '4.48',
#   '4.29',
#   '4.42',
#   '4.43',
#   '4.35'],
#  'Banghart, Matthew Ryan': ['2.86'],
#  'Leutgeb, Stefan': ['3.93',
#   '3.30',
#   '3.24',
#   '3.55',
#   '3.46',
#   '4.19',
#   '3.57',
#   '3.45',
#   '3.80',
#   '3.88',
#   '4.23',
#   '4.39'],
#  'Wang, Jing': ['4.12',
#   '3.15',
#   '4.12',
#   '3.85',
#   '4.00',
#   '4.26',
#   '3.90',
#   '5.00'],
#  'Juavinett, Ashley Lauren': ['4.90',
#   '4.64',
#   '4.57',
#   '4.87',
#   '4.74',
#   '4.81',
#   '4.70',
#   '4.22'],
#  'Chu, Monica W': ['4.71',
#   '4.30',
#   '4.37',
#   '4.35',
#   '4.57',
#   '4.19',
#   '4.58',
#   '4.55',
#   '4.53',
#   '4.16',
#   '4.67',
#   '4.53',
#   '4.22',
#   '4.70',
#   '4.21',
#   '4.72',
#   '4.39',
#   '4.47',
#   '4.56'],
#  'Zou, Yimin': ['4.22',
#   '4.39',
#   '3.85',
#   '3.62',
#   '3.91',
#   '4.47',
#   '4.63',
#   '3.52',
#   '3.92',
#   '3.55',
#   '4.23'],
#  'Lim, Byungkook': ['4.17', '4.03', '3.82', '3.71', '4.36', '3.45', '3.80'],
#  'Root, Cory Matthew': ['3.91', '3.07', '2.67'],
#  'Newsam, John': ['4.63',
#   '4.43',
#   '4.39',
#   '4.58',
#   '4.74',
#   '4.69',
#   '4.50',
#   '4.74',
#   '4.62'],
#  'Niwa, Maho': ['4.63', '3.99', '4.73', '4.23', '3.92', '3.41', '3.72'],
#  'Huffaker, Alisa': ['4.70',
#   '4.71',
#   '4.54',
#   '4.79',
#   '4.50',
#   '4.85',
#   '4.24',
#   '4.73',
#   '4.31'],
#  'Schmelz, Eric Alexander': ['4.02',
#   '4.76',
#   '3.94',
#   '4.60',
#   '3.37',
#   '4.69',
#   '3.34',
#   '3.45'],
#  'McDonnell, Lisa Marie': ['4.20',
#   '4.51',
#   '4.83',
#   '4.75',
#   '4.80',
#   '4.60',
#   '4.19',
#   '4.59',
#   '4.72',
#   '4.38',
#   '4.60',
#   '4.60',
#   '4.50',
#   '3.81',
#   '3.32',
#   '4.30',
#   '4.14',
#   '4.52',
#   '4.45',
#   '4.73',
#   '4.20',
#   '4.20',
#   '4.82',
#   '4.00',
#   '4.54',
#   '4.36',
#   '4.58',
#   '4.59'],
#  'Kiger, Amy': ['3.88', '3.82', '3.84', '4.06', '3.67', '3.16', '4.20'],
#  'Zuniga, Elina I': ['4.43',
#   '4.52',
#   '4.51',
#   '3.86',
#   '3.58',
#   '4.08',
#   '3.97',
#   '4.16',
#   '4.60'],
#  'Kohn, Joshua R': ['4.18',
#   '3.93',
#   '4.18',
#   '4.29',
#   '3.79',
#   '4.16',
#   '4.17',
#   '4.13',
#   '4.52',
#   '3.95'],
#  'Rennison, Diana': ['3.49'],
#  'Pekkurnaz Banghart, Gulcin': ['4.53',
#   '4.09',
#   '4.55',
#   '5.00',
#   '3.99',
#   '4.89',
#   '3.19',
#   '5.00',
#   '3.88'],
#  'Glasgow, Stacey Marie': ['4.37', '4.28', '4.23', '3.58'],
#  'Kuret, Thomas Joseph': ['4.42', '4.33'],
#  'Rana, Brinda Kanti': ['3.84',
#   '4.50',
#   '3.49',
#   '4.67',
#   '3.32',
#   '3.14',
#   '4.00'],
#  'Hedrick, Stephen M': ['4.61', '4.39', '4.39', '3.98'],
#  'Cook-Andersen, Heidi Leigh': ['3.96', '3.58'],
#  'Pasquinelli, Amy': ['4.46', '4.50', '4.58', '4.76', '4.48', '4.62', '4.76'],
#  'Golden, Susan S.': ['4.25',
#   '4.70',
#   '4.10',
#   '4.83',
#   '4.09',
#   '4.75',
#   '4.13',
#   '4.86',
#   '3.99',
#   '4.03',
#   '4.03',
#   '3.79',
#   '4.27',
#   '3.94'],
#  'Gorman, Michael R.': ['4.33',
#   '4.32',
#   '4.14',
#   '4.10',
#   '4.31',
#   '4.27',
#   '4.40',
#   '4.16'],
#  'Allen, Eric': ['4.90',
#   '4.94',
#   '4.47',
#   '4.63',
#   '4.94',
#   '4.85',
#   '4.50',
#   '4.80',
#   '4.58'],
#  'Russell, Alistair B': ['4.56'],
#  'Suel, Gurol Mehmet': ['4.53',
#   '4.49',
#   '4.35',
#   '4.51',
#   '4.54',
#   '4.72',
#   '5.00',
#   '4.86'],
#  'Grant, Barry J': ['4.83',
#   '4.67',
#   '4.61',
#   '4.57',
#   '4.58',
#   '4.55',
#   '4.35',
#   '4.83',
#   '4.64',
#   '4.64'],
#  'Mayfield, Stephen P.': ['4.80',
#   '4.36',
#   '4.89',
#   '4.67',
#   '4.30',
#   '4.56',
#   '4.63',
#   '4.81',
#   '4.70',
#   '4.41',
#   '5.00',
#   '4.51',
#   '5.00',
#   '4.43',
#   '4.30',
#   '4.50',
#   '4.40'],
#  'Lykke-Andersen, Jens': ['5.00',
#   '4.34',
#   '4.33',
#   '4.33',
#   '4.41',
#   '4.51',
#   '4.19',
#   '4.29',
#   '4.38'],
#  'Vijapurkar, Ulka': ['4.58',
#   '3.94',
#   '3.57',
#   '4.15',
#   '4.08',
#   '4.05',
#   '4.51',
#   '4.63',
#   '4.19',
#   '3.80',
#   '4.17'],
#  'Spitzer, Nicholas': ['3.89',
#   '3.87',
#   '4.39',
#   '4.21',
#   '4.53',
#   '4.14',
#   '4.19',
#   '4.15',
#   '4.09'],
#  'Wertheim, Joel Okrent': ['4.94', '4.62', '4.74'],
#  'Flagg, Matthew Paul': ['4.60', '4.50'],
#  'Petty, Emily L': ['4.65', '4.38'],
#  'Gustafson-Brown, Cindy': ['4.50',
#   '4.24',
#   '4.15',
#   '4.79',
#   '4.14',
#   '4.41',
#   '4.54',
#   '4.81',
#   '4.00',
#   '4.88',
#   '4.49',
#   '4.71',
#   '4.67',
#   '4.80',
#   '4.55',
#   '4.82',
#   '4.61',
#   '4.64',
#   '4.63',
#   '4.92',
#   '4.53',
#   '4.77',
#   '4.80',
#   '4.50',
#   '4.58',
#   '4.49',
#   '4.80',
#   '4.60',
#   '4.51',
#   '4.75',
#   '4.52',
#   '4.61',
#   '4.81',
#   '4.77',
#   '4.69',
#   '4.82',
#   '4.80',
#   '4.64',
#   '4.83',
#   '4.75',
#   '4.70',
#   '4.90',
#   '4.54',
#   '4.69',
#   '4.88',
#   '4.69',
#   '4.84',
#   '4.49',
#   '4.72',
#   '4.82',
#   '4.75',
#   '4.77',
#   '4.82',
#   '4.73',
#   '4.59'],
#  'Pagniello, Camille': ['4.43'],
#  'Wills, Christopher': ['4.11',
#   '4.67',
#   '4.24',
#   '4.52',
#   '4.16',
#   '3.95',
#   '3.94',
#   '4.07',
#   '4.03',
#   '4.06',
#   '4.30'],
#  'Pagliuso, Delaney Catherine': ['4.30'],
#  'Mudla, Anusorn': ['3.88', '4.33', '4.49'],
#  'Tat, John': ['4.60', '4.20'],
#  'Alfonso, Stephanie Isabel': ['3.71', '3.98', '4.27'],
#  'Cook, Orna': ['4.00', '4.41', '3.80'],
#  'Teodorof, Carmen': ['4.06',
#   '4.17',
#   '3.83',
#   '3.99',
#   '3.56',
#   '3.89',
#   '3.60',
#   '3.13'],
#  'Chun, Lauren Elizabeth': ['4.14'],
#  'McCulloch, Katherine Anne': ['4.13'],
#  'Lebeaupin, Cynthia D': ['4.61'],
#  'Hsu, Jeremy Lutan': ['4.62'],
#  'Ita, Sergio': ['4.52'],
#  'Coley, Austin Avery': ['3.75'],
#  'Forbes, Douglass Jane': ['4.47',
#   '4.53',
#   '4.30',
#   '4.41',
#   '4.39',
#   '4.44',
#   '4.53',
#   '4.42'],
#  'Cooper, Kimberly Lynn': ['4.68',
#   '4.43',
#   '4.49',
#   '4.64',
#   '4.47',
#   '4.58',
#   '4.56',
#   '4.87',
#   '4.37'],
#  'Traver, David': ['4.52', '4.48', '4.45', '4.49', '4.78', '3.88'],
#  'Lu, Li-Fan': ['3.62',
#   '4.32',
#   '4.28',
#   '4.28',
#   '4.73',
#   '4.01',
#   '4.60',
#   '3.97',
#   '3.89',
#   '4.50',
#   '4.30'],
#  'Rifkin, Scott': ['3.78',
#   '3.69',
#   '4.41',
#   '4.70',
#   '3.23',
#   '4.88',
#   '3.20',
#   '4.89',
#   '3.09',
#   '3.30',
#   '4.45',
#   '3.25',
#   '4.45',
#   '3.48'],
#  'Meyer, Justin Raymond': ['4.61', '4.31', '4.29', '4.42', '3.81'],
#  'Nieh, James Charles': ['4.86',
#   '4.69',
#   '4.79',
#   '4.78',
#   '4.66',
#   '4.00',
#   '4.82',
#   '4.85',
#   '4.71',
#   '4.67'],
#  'Patrick, Gentry': ['3.99',
#   '3.89',
#   '3.72',
#   '3.99',
#   '3.31',
#   '4.56',
#   '4.69',
#   '4.04',
#   '3.99'],
#  'Kurle, Carolyn M.': ['4.70',
#   '4.66',
#   '4.70',
#   '4.63',
#   '4.52',
#   '4.60',
#   '4.73',
#   '4.71',
#   '4.69',
#   '4.70',
#   '4.63',
#   '4.69',
#   '4.59'],
#  'Bier, Ethan': ['4.40',
#   '4.08',
#   '3.96',
#   '3.94',
#   '4.36',
#   '4.24',
#   '3.91',
#   '4.20',
#   '4.16',
#   '3.48',
#   '4.21'],
#  'Pruneda-Paz, Jose L.': ['4.29',
#   '4.50',
#   '4.35',
#   '4.82',
#   '4.52',
#   '4.69',
#   '4.38',
#   '4.89',
#   '4.04',
#   '4.63',
#   '3.93',
#   '5.00',
#   '3.84',
#   '3.89'],
#  "O'Rourke, Aubrie Elise": ['3.88', '3.33'],
#  'Dutton, Rachel Janelle': ['4.43', '4.36', '4.65', '3.89'],
#  'Bafna, Vineet': ['4.23', '3.50', '3.67', '4.33', '3.25', '3.67'],
#  'Goldrath, Ananda': ['4.92',
#   '4.50',
#   '4.33',
#   '4.37',
#   '4.54',
#   '4.11',
#   '4.44',
#   '4.43',
#   '3.96'],
#  'Sejnowski, Terrence J': ['3.57',
#   '3.33',
#   '3.73',
#   '3.40',
#   '3.58',
#   '3.92',
#   '3.40'],
#  'Halpain, Shelley': ['4.53',
#   '3.59',
#   '3.91',
#   '4.11',
#   '3.75',
#   '4.13',
#   '3.85',
#   '4.48',
#   '3.68',
#   '4.00'],
#  'Malinow, Roberto': ['4.14',
#   '4.75',
#   '4.70',
#   '4.82',
#   '4.00',
#   '4.50',
#   '4.75',
#   '5.00'],
#  'French, Kathleen Ann': ['4.56',
#   '3.88',
#   '4.20',
#   '4.20',
#   '5.00',
#   '4.29',
#   '4.47',
#   '3.40',
#   '3.78',
#   '4.43',
#   '3.67',
#   '4.03',
#   '4.00',
#   '4.67',
#   '4.07',
#   '4.03',
#   '4.17',
#   '3.76',
#   '4.64',
#   '3.79',
#   '4.35',
#   '4.54',
#   '4.29',
#   '4.50',
#   '3.73',
#   '4.83'],
#  'Greenspan, Ralph J.': ['4.33'],
#  'Chisholm, Andrew D.': ['4.50'],
#  'Estelle, Mark': ['4.40',
#   '4.75',
#   '4.59',
#   '4.56',
#   '5.00',
#   '4.38',
#   '4.63',
#   '4.60'],
#  'Troemel, Emily Ruth': ['4.16',
#   '4.22',
#   '3.84',
#   '4.27',
#   '4.40',
#   '4.16',
#   '4.32'],
#  'Villa Rodriguez, Elizabeth': ['3.59', '4.60', '3.84', '4.25', '3.56'],
#  'Shurin, Jonathan': ['4.12',
#   '4.38',
#   '3.86',
#   '4.32',
#   '4.16',
#   '4.01',
#   '3.88',
#   '4.17',
#   '3.50',
#   '4.21',
#   '4.12'],
#  'Holway, David A.': ['4.63',
#   '4.49',
#   '4.71',
#   '4.01',
#   '4.61',
#   '4.12',
#   '4.67',
#   '4.08',
#   '4.63'],
#  'Saier, Milton H.': ['4.43',
#   '4.33',
#   '4.29',
#   '4.40',
#   '4.17',
#   '3.64',
#   '4.29',
#   '4.78',
#   '4.63',
#   '4.29',
#   '4.10',
#   '4.44',
#   '4.16',
#   '4.00',
#   '4.50',
#   '4.18',
#   '4.43',
#   '3.02',
#   '4.13',
#   '4.22',
#   '4.60',
#   '3.71',
#   '5.00',
#   '4.80',
#   '4.00',
#   '4.40',
#   '3.30',
#   '4.36',
#   '4.56',
#   '4.80',
#   '3.98',
#   '3.80',
#   '4.50',
#   '4.45',
#   '4.11',
#   '3.45',
#   '4.10',
#   '4.54',
#   '4.42',
#   '3.86',
#   '5.00',
#   '4.60',
#   '4.56',
#   '4.13',
#   '4.50',
#   '4.50',
#   '4.02',
#   '4.60',
#   '4.19',
#   '4.64',
#   '3.31',
#   '4.29',
#   '4.12',
#   '3.67',
#   '4.25',
#   '3.84',
#   '4.78'],
#  'Lauberth, Shannon Marie': ['3.75', '3.91', '4.07', '3.97', '4.24', '3.51'],
#  'Kadonaga, James T': ['4.53',
#   '4.62',
#   '4.44',
#   '4.66',
#   '4.27',
#   '4.41',
#   '4.57',
#   '4.39'],
#  'David, Michael': ['4.49',
#   '4.58',
#   '4.62',
#   '4.53',
#   '4.64',
#   '4.58',
#   '4.44',
#   '4.52'],
#  'Bennett, Eric J': ['4.52', '4.47', '4.31', '4.27', '4.44', '3.97', '4.88'],
#  'Herzik, Mark Anthony': ['4.60'],
#  'McHugh, Colleen A': ['4.40', '4.00'],
#  'Jin, Yishi': ['4.10', '4.89', '4.82', '4.69', '3.90', '4.80'],
#  'Muotri, Alysson': ['4.82', '4.56', '4.64', '4.56', '4.67', '4.00'],
#  'Wilhelm, James E.': ['4.60', '4.58', '4.73', '4.36', '4.52', '4.35', '4.38'],
#  'Kryazhimskiy, Sergey A': ['4.15', '4.29', '4.33', '3.80'],
#  'Ryan, Elizabeth Mary': ['4.71'],
#  'Butler, Madeline': ['4.58',
#   '4.75',
#   '4.50',
#   '5.00',
#   '4.82',
#   '4.89',
#   '4.73',
#   '4.90',
#   '4.73',
#   '4.73',
#   '4.88',
#   '4.92',
#   '4.64',
#   '4.88',
#   '4.70'],
#  'McGinnis, William James': ['4.39', '4.00'],
#  'Tour, Ella': ['4.75',
#   '4.85',
#   '4.54',
#   '4.75',
#   '4.74',
#   '3.88',
#   '4.78',
#   '4.21',
#   '4.22',
#   '4.86',
#   '4.35',
#   '4.43',
#   '4.94',
#   '4.83',
#   '4.27',
#   '4.60',
#   '4.79',
#   '4.16',
#   '4.67',
#   '4.64',
#   '4.27'],
#  'Karlseder, Jan': ['4.60', '4.86', '4.73'],
#  'Saghatelian, Alan': ['4.60', '4.86', '4.67'],
#  'Paxman, Julie Roberts': ['4.21'],
#  'Rizk, Maryan Girgis Soliman': ['4.43', '4.35', '4.06'],
#  'Mak, Raymond Hengfai': ['4.75'],
#  'Painter, Chelsea Danielle': ['4.42', '4.67'],
#  'Puritty, Chandler Elizabeth': ['4.57'],
#  'Adomako, Marie Antonia': ['4.19'],
#  'Mohan, Swarna': ['4.54',
#   '4.03',
#   '4.40',
#   '3.90',
#   '4.28',
#   '5.00',
#   '4.00',
#   '4.25',
#   '4.71',
#   '4.17',
#   '4.26',
#   '4.60',
#   '3.93'],
#  'Desai, Arshad': ['5.00', '4.88', '4.83', '4.50'],
#  'Oegema, Karen': ['4.86', '4.89', '4.83', '4.80'],
#  'Roy, Kaustuv': ['4.64',
#   '4.56',
#   '4.52',
#   '5.00',
#   '4.42',
#   '4.39',
#   '4.61',
#   '4.75',
#   '4.26'],
#  'Wasserman, Steven A.': ['4.29', '4.53', '4.40', '4.51', '4.62', '4.64'],
#  'Farley, Emma Kristen': ['4.45'],
#  'Fortes, P. A. George': ['3.82',
#   '4.14',
#   '3.94',
#   '4.18',
#   '3.78',
#   '4.09',
#   '3.10',
#   '2.73',
#   '3.24',
#   '3.79',
#   '3.43',
#   '3.40',
#   '3.78',
#   '3.48',
#   '3.94',
#   '3.66',
#   '3.56',
#   '3.78',
#   '3.46',
#   '3.39',
#   '3.46',
#   '3.53',
#   '3.83',
#   '3.78',
#   '2.83',
#   '3.82',
#   '3.86',
#   '3.33',
#   '4.11',
#   '3.38',
#   '3.83',
#   '2.75',
#   '3.89',
#   '3.62',
#   '3.47',
#   '3.54',
#   '3.42',
#   '3.45',
#   '3.21',
#   '4.06',
#   '3.82',
#   '3.41',
#   '3.48',
#   '3.80',
#   '4.06'],
#  'Xu, Yang': ['2.78',
#   '3.07',
#   '4.29',
#   '3.57',
#   '3.89',
#   '3.69',
#   '3.64',
#   '3.56',
#   '4.67',
#   '3.88',
#   '3.27',
#   '4.33',
#   '3.80'],
#  'Broccard Bell, Heather Chr': ['4.45', '4.50', '4.56', '4.04'],
#  'Byrne, Kathryne': ['2.64', '3.84', '2.91', '2.04'],
#  'Gentner, Tim': ['3.67'],
#  'Pfaff, Samuel': ['4.60', '4.59', '4.66', '4.53', '4.50'],
#  'Doblas Ibanez, Paula Adela': ['4.72'],
#  'Ryan, Genevieve Elaine': ['3.73', '4.05'],
#  'Davis, Amanda Gabrielle': ['4.56'],
#  'Waterton, Joseph Sebastian': ['4.04'],
#  'Herndon, Jenny Dyann': ['4.72',
#   '3.80',
#   '4.20',
#   '4.39',
#   '4.57',
#   '4.57',
#   '3.74',
#   '4.20',
#   '3.75',
#   '4.58',
#   '4.73',
#   '4.49',
#   '3.79',
#   '4.38',
#   '4.53',
#   '4.27',
#   '3.02'],
#  'Baker, Timothy Stanley': ['4.50', '4.13', '4.43', '4.71', '3.67'],
#  'Bansal, Vikas': ['3.00'],
#  'Heinrich, Erica C': ['4.75'],
#  'Crawford, Nigel M.': ['4.75',
#   '4.94',
#   '4.68',
#   '4.80',
#   '4.67',
#   '4.80',
#   '4.63',
#   '4.79',
#   '4.71',
#   '4.71',
#   '4.61',
#   '4.94'],
#  'Henter, Heather J.': ['4.18', '4.67', '4.55', '4.64', '4.13', '4.26'],
#  'Espin Palazon, Raquel': ['3.91', '3.11'],
#  'Grainger, Stephanie L': ['4.48'],
#  'Markmiller, Rea Lardelli': ['4.28'],
#  'De Silva, Shermin': ['3.63'],
#  'Chilukuri, Lakshmi N': ['4.64',
#   '4.48',
#   '4.80',
#   '4.97',
#   '3.99',
#   '4.80',
#   '4.74',
#   '4.56',
#   '4.74',
#   '4.60',
#   '5.00',
#   '4.69',
#   '4.78',
#   '4.29',
#   '4.88',
#   '4.86',
#   '4.67',
#   '4.50',
#   '4.70',
#   '4.85',
#   '4.66'],
#  'Erb, Marcella L': ['4.82'],
#  'Raiko, Mikhail P.': ['3.14'],
#  'Rodionov, Dmitry A': ['2.40'],
#  'Medrano Soto, Luis Arturo': ['4.33'],
#  'Posakony, James W': ['4.90', '4.19', '4.78', '4.57', '4.35'],
#  'Montal, S. Maurice': ['3.14'],
#  'Heinrichsen, Erilynn Terese': ['4.03'],
#  'Ghosh Dastidar, Ranita': ['2.86'],
#  'Bloomekatz, Joshua': ['2.54'],
#  'Hicks, Jenna Schug': ['4.49'],
#  'Lewis, Levi Steele': ['4.35'],
#  'Wang, Jean Yin Jen': ['4.33', '4.26'],
#  'Dunbar, Tiffany L': ['4.78',
#   '4.79',
#   '4.88',
#   '4.83',
#   '4.94',
#   '4.90',
#   '4.85',
#   '4.77',
#   '4.61'],
#  'Ring, Gabriela Aviva': ['4.27', '4.14', '4.80', '4.55', '4.19'],
#  'Pogliano, Kit J.': ['4.76', '4.64', '4.67', '4.40'],
#  'Do, Long Hoang': ['4.00', '4.67', '4.33'],
#  'Collins, Eva-Maria Schoetz': ['3.52', '4.45'],
#  'Goulding, Martyn': ['4.00', '3.94', '4.08', '3.91'],
#  'Lee, Kuo Fen': ['4.06', '3.97', '3.46', '3.36'],
#  'La Spada, Albert': ['4.45', '4.50', '4.71', '4.67'],
#  'Reinagel, Pam': ['3.08', '3.46', '3.70'],
#  'Kristan, William B.': ['3.78', '3.72'],
#  'Todd, Krista L.': ['4.16', '2.50', '3.88'],
#  'Perks, Krista Eva': ['3.14'],
#  'Noto, Akana Elizabeth': ['4.14'],
#  'Clark, Dan': ['4.89', '4.89', '4.83', '4.84'],
#  'Ghiara, Jayant': ['4.50', '4.65', '4.68', '4.63', '4.66', '4.68', '4.71'],
#  'Huberman, Andrew David': ['4.54', '4.36', '4.69'],
#  'Berg, Darwin K.': ['4.24', '4.23', '4.50', '4.24'],
#  'Markow, Therese A.': ['4.05', '3.70'],
#  'Wienhausen, Gabriele': ['4.40', '4.88', '4.91', '5.00', '4.90'],
#  'Scanziani, Massimo': ['4.12', '4.60', '4.48'],
#  'Scheffler, Immo E.': ['4.01', '4.30'],
#  'Richmond, Maxi Polihronaki': ['4.25'],
#  'Schoetz, Eva-Maria': ['4.67'],
#  'Strum, Shirley C.': ['4.05', '4.25'],
#  'Woodruff, David S': ['4.50', '4.69', '3.68', '4.50', '4.17', '4.51', '4.80'],
#  'Clemmons, Alexa Watson': ['4.71'],
#  'Emerson, Beverly Marie': ['4.14'],
#  'Jones, Katherine A.': ['4.67'],
#  'Brown, Willie C.': ['4.08', '4.71'],
#  'Aroian, Raffi V.': ['4.58', '4.11'],
#  'Sternfeld, Matthew J': ['4.57'],
#  'Marietou, Angeliki': ['4.69'],
#  'Gantner, Marin Leigh': ['4.55'],
#  'Pykalainen, Anette': ['3.26'],
#  'Price, Paul A.': ['4.46', '4.86'],
#  'Curington, John Gibson': ['4.62', '4.43'],
#  'Rypien, Krystal L': ['4.46', '4.26', '4.49'],
#  'Johnson, Tracy Lanise': ['5.00', '4.63'],
#  'Tam, Tobey M': ['4.18'],
#  'Trujillo, Gloriana V.': ['3.41'],
#  'Trial, Rachelle Marie': ['4.31']}

# %%
#take averages
import numpy as np

prof_means1 = {}
prof_means2 = {}

for name, means in prof_dict1.items():
#     means_int = [float(numeric_string) for numeric_string in means]
    for index, num in enumerate(means):
        if num != '' or num != ' ' or num != '  ':
            means[index] = float(num)
        else:
            means[index] = np.nan
    means = np.array([i for i in means if np.isnan(i)==False])
    prof_means1[name] = np.mean(means)

    
for name, means in prof_dict2.items():
    means_int = [float(numeric_string) for numeric_string in means]
    prof_means2[name] = np.mean(means_int)

# %%
prof_means1
# Out:
# {'Hui, Enfu': 4.715,
#  'Zhao, Yunde': 4.55,
#  'Feng, Gen-Sheng': 4.26875,
#  'Coleman, Aaron B.': 4.698611111111111,
#  'Soowal, Lara': 4.4125,
#  'Bozinovic, Goran': 4.676315789473684,
#  'Miller, Steven W.': 4.425714285714285,
#  'Rusert, Jessica Marie': 4.065,
#  'Smith, Laurie': 4.51,
#  'Yelon, Deborah': 4.69,
#  'Butler, Shannon Rhey': 4.4761538461538475,
#  'Stockwell, Sarah R': 4.654375,
#  'Barton, Andrew David': 4.621666666666667,
#  'Chao, Lin': 4.642941176470588,
#  'Cooper, Andrew Michael': 4.5473684210526315,
#  'Owens, Melinda Tsao-Ying': 4.536153846153846,
#  'Komiyama, Takaki': 4.564285714285714,
#  'Su, Chih-Ying': 4.612307692307693,
#  'Schroeder, Julian I': 4.374285714285714,
#  'Park, Ji Young': 4.608750000000001,
#  'Strause, Linda G.': 4.5088888888888885,
#  'Gambel, Jessica Erin': 4.4750000000000005,
#  'Caffrey, Carolee': 4.412000000000001,
#  'Macagno, Eduardo R.': 4.542857142857143,
#  'Mel, Stephanie': 4.644117647058824,
#  'Lo, Stanley Malvin Ming-Hi': 4.514324324324323,
#  'Reuther, Keefe': 4.61703125,
#  'Cleland, Elsa Eleanor': 4.711818181818182,
#  'Pogliano, Joseph': 4.84,
#  'Briggs, Steven': 4.654285714285714,
#  'Akbari, Omar Sultan': 4.564,
#  'Hao, Nan': 4.667,
#  'Meaders, Clara Leigh': nan,
#  'Burg, Michael': 4.589142857142857,
#  'Day, Christopher D': 4.503333333333334,
#  'Grossman, Emily N': 4.211333333333333,
#  'Zhang, Dong-Er': 4.541666666666667,
#  'Duttke, Sascha Hans Christian': 4.3,
#  'Daugherty, Matthew Dorton': 4.706,
#  'Golden, James W': 4.371818181818181,
#  'Pickett, Brooke Elizabeth': nan,
#  'Petrie, Katherine Lynn': 4.7299999999999995,
#  'Pirino, Giorgia': 4.499333333333333,
#  'Schiffer, Jamie Michelle': 4.550000000000001,
#  'Pevzner, Pavel Arkadjevich': 4.551428571428572,
#  'Murre, Cornelis': 4.760000000000001,
#  'Hasty, Jeff M': 4.807499999999999,
#  'Yanofsky, Martin F.': 4.6899999999999995,
#  'Bloodgood, Brenda Laurie': 4.640000000000001,
#  'Cooke, James Edward': 4.659375,
#  'Reyes Gonzalez, Catalina': 4.680833333333333,
#  'Armour, Jon Christopher': 4.89,
#  'Hampton, Randolph Y.': 4.640555555555555,
#  'Banghart, Matthew Ryan': 4.575,
#  'Leutgeb, Stefan': 4.385833333333333,
#  'Wang, Jing': 4.3525,
#  'Juavinett, Ashley Lauren': 4.7475000000000005,
#  'Chu, Monica W': 4.596315789473685,
#  'Zou, Yimin': 4.400909090909092,
#  'Lim, Byungkook': 4.4871428571428575,
#  'Root, Cory Matthew': 3.6633333333333336,
#  'Leutgeb, Jill K.': 4.88,
#  'Ackerman, Susan': 4.86,
#  'Newsam, John': 4.705555555555555,
#  'Niwa, Maho': 4.371428571428572,
#  'Huffaker, Alisa': 4.702222222222222,
#  'Schmelz, Eric Alexander': 4.50375,
#  'McDonnell, Lisa Marie': 4.604285714285714,
#  'Kiger, Amy': 4.345714285714285,
#  'Zuniga, Elina I': 4.557777777777779,
#  'Kohn, Joshua R': 4.486,
#  'Rennison, Diana': 3.91,
#  'Pekkurnaz Banghart, Gulcin': 4.653333333333333,
#  'Glasgow, Stacey Marie': 4.33,
#  'Kuret, Thomas Joseph': 4.555,
#  'Rana, Brinda Kanti': 4.302857142857143,
#  'Hedrick, Stephen M': 4.4675,
#  'Cook-Andersen, Heidi Leigh': 4.325,
#  'Pasquinelli, Amy': 4.7457142857142856,
#  'Golden, Susan S.': 4.539285714285714,
#  'Gorman, Michael R.': 4.48625,
#  'Allen, Eric': 4.8133333333333335,
#  'Russell, Alistair B': 4.78,
#  'Suel, Gurol Mehmet': 4.705,
#  'Grant, Barry J': 4.843999999999999,
#  'Mayfield, Stephen P.': 4.7170588235294115,
#  'Lykke-Andersen, Jens': 4.713333333333334,
#  'Vijapurkar, Ulka': 4.45090909090909,
#  'Spitzer, Nicholas': 4.656666666666667,
#  'Wertheim, Joel Okrent': 4.863333333333333,
#  'Flagg, Matthew Paul': 4.6850000000000005,
#  'Petty, Emily L': 4.725,
#  'Gustafson-Brown, Cindy': 4.731515151515152,
#  'Pagniello, Camille': 4.71,
#  'Wills, Christopher': 4.536363636363636,
#  'Pagliuso, Delaney Catherine': 4.5,
#  'Mudla, Anusorn': 4.45,
#  'Tat, John': 4.74,
#  'Alfonso, Stephanie Isabel': 4.37,
#  'Cook, Orna': 4.509999999999999,
#  'Teodorof, Carmen': 4.27125,
#  'Chun, Lauren Elizabeth': 4.29,
#  'McCulloch, Katherine Anne': 4.4,
#  'Lebeaupin, Cynthia D': 4.72,
#  'Hsu, Jeremy Lutan': 4.72,
#  'Ita, Sergio': 4.53,
#  'Coley, Austin Avery': 4.06,
#  'Forbes, Douglass Jane': 4.62,
#  'Cooper, Kimberly Lynn': 4.6499999999999995,
#  'Traver, David': 4.6066666666666665,
#  'Lu, Li-Fan': 4.656363636363636,
#  'Rifkin, Scott': 4.3585714285714285,
#  'Meyer, Justin Raymond': 4.558,
#  'Nieh, James Charles': 4.76,
#  'Patrick, Gentry': 4.461111111111111,
#  'Kurle, Carolyn M.': 4.723076923076923,
#  'Bier, Ethan': 4.507272727272727,
#  'Pruneda-Paz, Jose L.': 4.576428571428571,
#  "O'Rourke, Aubrie Elise": nan,
#  'Dutton, Rachel Janelle': 4.657500000000001,
#  'Bafna, Vineet': 4.485,
#  'Goldrath, Ananda': 4.686666666666666,
#  'Sejnowski, Terrence J': 4.272857142857143,
#  'Halpain, Shelley': 4.284,
#  'Malinow, Roberto': 4.83375,
#  'French, Kathleen Ann': 4.473461538461539,
#  'Greenspan, Ralph J.': 4.67,
#  'Chisholm, Andrew D.': 4.88,
#  'Estelle, Mark': 4.72875,
#  'Troemel, Emily Ruth': 4.467142857142857,
#  'Villa Rodriguez, Elizabeth': 4.478,
#  'Shurin, Jonathan': 4.501818181818181,
#  'Holway, David A.': 4.647777777777778,
#  'Saier, Milton H.': 4.468245614035087,
#  'Lauberth, Shannon Marie': 4.53,
#  'Kadonaga, James T': 4.785,
#  'David, Michael': 4.7475000000000005,
#  'Bennett, Eric J': 4.675714285714285,
#  'Herzik, Mark Anthony': 5.0,
#  'McHugh, Colleen A': 4.325,
#  'Jin, Yishi': 4.705,
#  'Muotri, Alysson': 4.695,
#  'Wilhelm, James E.': 4.685714285714285,
#  'Kryazhimskiy, Sergey A': 4.715,
#  'Ryan, Elizabeth Mary': 4.71,
#  'Butler, Madeline': 4.794,
#  'McGinnis, William James': 4.46,
#  'Tour, Ella': 4.576428571428572,
#  'Karlseder, Jan': 4.756666666666667,
#  'Saghatelian, Alan': 4.776666666666666,
#  'Paxman, Julie Roberts': 4.39,
#  'Rizk, Maryan Girgis Soliman': 4.329999999999999,
#  'Mak, Raymond Hengfai': 4.13,
#  'Painter, Chelsea Danielle': 4.605,
#  'Puritty, Chandler Elizabeth': 4.67,
#  'Adomako, Marie Antonia': 4.36,
#  'Mohan, Swarna': 4.596363636363637,
#  'Desai, Arshad': 4.887499999999999,
#  'Oegema, Karen': 4.88,
#  'Roy, Kaustuv': 4.742222222222222,
#  'Wasserman, Steven A.': 4.73,
#  'Farley, Emma Kristen': 4.55,
#  'Fortes, P. A. George': 4.394666666666667,
#  'Xu, Yang': 4.2553846153846155,
#  'Broccard Bell, Heather Chr': 4.6025,
#  'Byrne, Kathryne': 3.5175,
#  'Gentner, Tim': 4.67,
#  'Pfaff, Samuel': 4.651999999999999,
#  'Doblas Ibanez, Paula Adela': 4.72,
#  'Ryan, Genevieve Elaine': 4.23,
#  'Davis, Amanda Gabrielle': 4.78,
#  'Waterton, Joseph Sebastian': 4.48,
#  'Herndon, Jenny Dyann': 4.4670588235294115,
#  'Baker, Timothy Stanley': 4.686,
#  'Bansal, Vikas': 4.33,
#  'Heinrich, Erica C': 4.71,
#  'Crawford, Nigel M.': 4.788333333333333,
#  'Henter, Heather J.': 4.73,
#  'Espin Palazon, Raquel': 3.9699999999999998,
#  'Grainger, Stephanie L': 4.62,
#  'Markmiller, Rea Lardelli': 4.39,
#  'De Silva, Shermin': 4.31,
#  'Chilukuri, Lakshmi N': 4.531428571428571,
#  'Erb, Marcella L': 4.91,
#  'Raiko, Mikhail P.': 3.86,
#  'Rodionov, Dmitry A': 4.2,
#  'Medrano Soto, Luis Arturo': 4.57,
#  'Posakony, James W': 4.724000000000001,
#  'Montal, S. Maurice': 4.26,
#  'Heinrichsen, Erilynn Terese': 4.04,
#  'Ghosh Dastidar, Ranita': 3.53,
#  'Bloomekatz, Joshua': 3.77,
#  'Hicks, Jenna Schug': 4.63,
#  'Lewis, Levi Steele': 4.35,
#  'Wang, Jean Yin Jen': 4.4399999999999995,
#  'Dunbar, Tiffany L': 4.65,
#  'Ring, Gabriela Aviva': 4.47,
#  'Pogliano, Kit J.': 4.7075000000000005,
#  'Do, Long Hoang': nan,
#  'Collins, Eva-Maria Schoetz': 4.68,
#  'Goulding, Martyn': 4.26,
#  'Lee, Kuo Fen': 4.26,
#  'La Spada, Albert': 4.565,
#  'Reinagel, Pam': 4.073333333333333,
#  'Kristan, William B.': 4.29,
#  'Todd, Krista L.': 3.9333333333333336,
#  'Perks, Krista Eva': 3.38,
#  'Noto, Akana Elizabeth': 4.31,
#  'Clark, Dan': 4.8575,
#  'Ghiara, Jayant': 4.777142857142857,
#  'Huberman, Andrew David': 4.776666666666666,
#  'Berg, Darwin K.': 4.67,
#  'Markow, Therese A.': 4.12,
#  'Wienhausen, Gabriele': 4.736,
#  'Scanziani, Massimo': 4.596666666666667,
#  'Scheffler, Immo E.': 4.609999999999999,
#  'Richmond, Maxi Polihronaki': 4.3,
#  'Schoetz, Eva-Maria': 4.67,
#  'Strum, Shirley C.': 4.449999999999999,
#  'Woodruff, David S': 4.6171428571428565,
#  'Clemmons, Alexa Watson': 4.68,
#  'Emerson, Beverly Marie': 4.43,
#  'Jones, Katherine A.': 4.5,
#  'Brown, Willie C.': 4.59,
#  'Aroian, Raffi V.': 4.73,
#  'Sternfeld, Matthew J': 4.64,
#  'Marietou, Angeliki': nan,
#  'Gantner, Marin Leigh': 4.64,
#  'Pykalainen, Anette': 3.85,
#  'Price, Paul A.': 4.855,
#  'Curington, John Gibson': 4.5649999999999995,
#  'Rypien, Krystal L': 4.553333333333334,
#  'Johnson, Tracy Lanise': 4.85,
#  'Tam, Tobey M': 4.22,
#  'Trujillo, Gloriana V.': 3.96,
#  'Trial, Rachelle Marie': 4.48}

# %%
prof_means2
# Out:
# {'Hui, Enfu': 4.576666666666667,
#  'Zhao, Yunde': 3.7933333333333343,
#  'Feng, Gen-Sheng': 3.5675,
#  'Coleman, Aaron B.': 4.6325,
#  'Soowal, Lara': 4.199199999999999,
#  'Bozinovic, Goran': 4.2859649122807015,
#  'Miller, Steven W.': 4.153333333333333,
#  'Rusert, Jessica Marie': 3.7116666666666673,
#  'Smith, Laurie': 4.3876923076923084,
#  'Yelon, Deborah': 4.536666666666666,
#  'Butler, Shannon Rhey': 4.266153846153847,
#  'Stockwell, Sarah R': 4.5287500000000005,
#  'Barton, Andrew David': 4.533333333333333,
#  'Chao, Lin': 4.421764705882352,
#  'Cooper, Andrew Michael': 4.3568421052631585,
#  'Owens, Melinda Tsao-Ying': 4.357692307692308,
#  'Komiyama, Takaki': 4.377142857142856,
#  'Su, Chih-Ying': 4.2807692307692315,
#  'Schroeder, Julian I': 4.114285714285715,
#  'Park, Ji Young': 4.4175,
#  'Strause, Linda G.': 4.274444444444445,
#  'Gambel, Jessica Erin': 4.456666666666666,
#  'Caffrey, Carolee': 4.134,
#  'Macagno, Eduardo R.': 4.314285714285715,
#  'Mel, Stephanie': 4.529111111111111,
#  'Lo, Stanley Malvin Ming-Hi': 4.331351351351352,
#  'Reuther, Keefe': 4.436718750000001,
#  'Cleland, Elsa Eleanor': 4.580666666666667,
#  'Pogliano, Joseph': 4.671176470588235,
#  'Briggs, Steven': 4.634285714285714,
#  'Akbari, Omar Sultan': 4.353999999999999,
#  'Hao, Nan': 4.487,
#  'Meaders, Clara Leigh': 4.89,
#  'Burg, Michael': 4.423142857142857,
#  'Day, Christopher D': 4.148518518518518,
#  'Grossman, Emily N': 4.361851851851852,
#  'Zhang, Dong-Er': 4.211666666666667,
#  'Duttke, Sascha Hans Christian': 3.37,
#  'Daugherty, Matthew Dorton': 4.6080000000000005,
#  'Golden, James W': 4.293636363636364,
#  'Pickett, Brooke Elizabeth': 4.82,
#  'Petrie, Katherine Lynn': 4.770833333333333,
#  'Pirino, Giorgia': 4.3160869565217395,
#  'Schiffer, Jamie Michelle': 4.195,
#  'Pevzner, Pavel Arkadjevich': 3.664285714285714,
#  'Murre, Cornelis': 4.5008333333333335,
#  'Hasty, Jeff M': 4.5975,
#  'Yanofsky, Martin F.': 4.595000000000001,
#  'Bloodgood, Brenda Laurie': 4.3575,
#  'Cooke, James Edward': 4.563124999999999,
#  'Reyes Gonzalez, Catalina': 4.458333333333333,
#  'Armour, Jon Christopher': 4.758648648648649,
#  'Hampton, Randolph Y.': 4.352777777777778,
#  'Banghart, Matthew Ryan': 2.86,
#  'Leutgeb, Stefan': 3.749166666666666,
#  'Wang, Jing': 4.05,
#  'Juavinett, Ashley Lauren': 4.68125,
#  'Chu, Monica W': 4.462105263157895,
#  'Zou, Yimin': 4.028181818181818,
#  'Lim, Byungkook': 3.9057142857142857,
#  'Root, Cory Matthew': 3.216666666666667,
#  'Newsam, John': 4.591111111111111,
#  'Niwa, Maho': 4.09,
#  'Huffaker, Alisa': 4.596666666666668,
#  'Schmelz, Eric Alexander': 4.02125,
#  'McDonnell, Lisa Marie': 4.4225,
#  'Kiger, Amy': 3.804285714285714,
#  'Zuniga, Elina I': 4.19,
#  'Kohn, Joshua R': 4.13,
#  'Rennison, Diana': 3.49,
#  'Pekkurnaz Banghart, Gulcin': 4.346666666666668,
#  'Glasgow, Stacey Marie': 4.115,
#  'Kuret, Thomas Joseph': 4.375,
#  'Rana, Brinda Kanti': 3.8514285714285714,
#  'Hedrick, Stephen M': 4.3425,
#  'Cook-Andersen, Heidi Leigh': 3.77,
#  'Pasquinelli, Amy': 4.594285714285715,
#  'Golden, Susan S.': 4.268571428571428,
#  'Gorman, Michael R.': 4.25375,
#  'Allen, Eric': 4.734444444444445,
#  'Russell, Alistair B': 4.56,
#  'Suel, Gurol Mehmet': 4.625,
#  'Grant, Barry J': 4.627,
#  'Mayfield, Stephen P.': 4.604117647058824,
#  'Lykke-Andersen, Jens': 4.42,
#  'Vijapurkar, Ulka': 4.151818181818182,
#  'Spitzer, Nicholas': 4.162222222222222,
#  'Wertheim, Joel Okrent': 4.766666666666667,
#  'Flagg, Matthew Paul': 4.55,
#  'Petty, Emily L': 4.515000000000001,
#  'Gustafson-Brown, Cindy': 4.65090909090909,
#  'Pagniello, Camille': 4.43,
#  'Wills, Christopher': 4.1863636363636365,
#  'Pagliuso, Delaney Catherine': 4.3,
#  'Mudla, Anusorn': 4.233333333333333,
#  'Tat, John': 4.4,
#  'Alfonso, Stephanie Isabel': 3.9866666666666664,
#  'Cook, Orna': 4.07,
#  'Teodorof, Carmen': 3.77875,
#  'Chun, Lauren Elizabeth': 4.14,
#  'McCulloch, Katherine Anne': 4.13,
#  'Lebeaupin, Cynthia D': 4.61,
#  'Hsu, Jeremy Lutan': 4.62,
#  'Ita, Sergio': 4.52,
#  'Coley, Austin Avery': 3.75,
#  'Forbes, Douglass Jane': 4.43625,
#  'Cooper, Kimberly Lynn': 4.565555555555555,
#  'Traver, David': 4.433333333333333,
#  'Lu, Li-Fan': 4.2272727272727275,
#  'Rifkin, Scott': 3.9142857142857146,
#  'Meyer, Justin Raymond': 4.288,
#  'Nieh, James Charles': 4.683000000000001,
#  'Patrick, Gentry': 4.0200000000000005,
#  'Kurle, Carolyn M.': 4.657692307692307,
#  'Bier, Ethan': 4.085454545454545,
#  'Pruneda-Paz, Jose L.': 4.4121428571428565,
#  "O'Rourke, Aubrie Elise": 3.605,
#  'Dutton, Rachel Janelle': 4.3325,
#  'Bafna, Vineet': 3.775,
#  'Goldrath, Ananda': 4.4,
#  'Sejnowski, Terrence J': 3.5614285714285714,
#  'Halpain, Shelley': 4.003,
#  'Malinow, Roberto': 4.5825,
#  'French, Kathleen Ann': 4.203076923076923,
#  'Greenspan, Ralph J.': 4.33,
#  'Chisholm, Andrew D.': 4.5,
#  'Estelle, Mark': 4.61375,
#  'Troemel, Emily Ruth': 4.195714285714286,
#  'Villa Rodriguez, Elizabeth': 3.968,
#  'Shurin, Jonathan': 4.066363636363636,
#  'Holway, David A.': 4.438888888888889,
#  'Saier, Milton H.': 4.24859649122807,
#  'Lauberth, Shannon Marie': 3.9083333333333337,
#  'Kadonaga, James T': 4.48625,
#  'David, Michael': 4.55,
#  'Bennett, Eric J': 4.408571428571428,
#  'Herzik, Mark Anthony': 4.6,
#  'McHugh, Colleen A': 4.2,
#  'Jin, Yishi': 4.533333333333333,
#  'Muotri, Alysson': 4.541666666666667,
#  'Wilhelm, James E.': 4.502857142857143,
#  'Kryazhimskiy, Sergey A': 4.1425,
#  'Ryan, Elizabeth Mary': 4.71,
#  'Butler, Madeline': 4.776666666666668,
#  'McGinnis, William James': 4.195,
#  'Tour, Ella': 4.549047619047619,
#  'Karlseder, Jan': 4.73,
#  'Saghatelian, Alan': 4.71,
#  'Paxman, Julie Roberts': 4.21,
#  'Rizk, Maryan Girgis Soliman': 4.28,
#  'Mak, Raymond Hengfai': 4.75,
#  'Painter, Chelsea Danielle': 4.545,
#  'Puritty, Chandler Elizabeth': 4.57,
#  'Adomako, Marie Antonia': 4.19,
#  'Mohan, Swarna': 4.313076923076924,
#  'Desai, Arshad': 4.8025,
#  'Oegema, Karen': 4.845,
#  'Roy, Kaustuv': 4.572222222222222,
#  'Wasserman, Steven A.': 4.498333333333334,
#  'Farley, Emma Kristen': 4.45,
#  'Fortes, P. A. George': 3.6095555555555556,
#  'Xu, Yang': 3.7261538461538466,
#  'Broccard Bell, Heather Chr': 4.387499999999999,
#  'Byrne, Kathryne': 2.8575,
#  'Gentner, Tim': 3.67,
#  'Pfaff, Samuel': 4.576,
#  'Doblas Ibanez, Paula Adela': 4.72,
#  'Ryan, Genevieve Elaine': 3.8899999999999997,
#  'Davis, Amanda Gabrielle': 4.56,
#  'Waterton, Joseph Sebastian': 4.04,
#  'Herndon, Jenny Dyann': 4.219411764705882,
#  'Baker, Timothy Stanley': 4.287999999999999,
#  'Bansal, Vikas': 3.0,
#  'Heinrich, Erica C': 4.75,
#  'Crawford, Nigel M.': 4.7525,
#  'Henter, Heather J.': 4.405,
#  'Espin Palazon, Raquel': 3.51,
#  'Grainger, Stephanie L': 4.48,
#  'Markmiller, Rea Lardelli': 4.28,
#  'De Silva, Shermin': 3.63,
#  'Chilukuri, Lakshmi N': 4.676190476190476,
#  'Erb, Marcella L': 4.82,
#  'Raiko, Mikhail P.': 3.14,
#  'Rodionov, Dmitry A': 2.4,
#  'Medrano Soto, Luis Arturo': 4.33,
#  'Posakony, James W': 4.558,
#  'Montal, S. Maurice': 3.14,
#  'Heinrichsen, Erilynn Terese': 4.03,
#  'Ghosh Dastidar, Ranita': 2.86,
#  'Bloomekatz, Joshua': 2.54,
#  'Hicks, Jenna Schug': 4.49,
#  'Lewis, Levi Steele': 4.35,
#  'Wang, Jean Yin Jen': 4.295,
#  'Dunbar, Tiffany L': 4.816666666666666,
#  'Ring, Gabriela Aviva': 4.390000000000001,
#  'Pogliano, Kit J.': 4.6175,
#  'Do, Long Hoang': 4.333333333333333,
#  'Collins, Eva-Maria Schoetz': 3.9850000000000003,
#  'Goulding, Martyn': 3.9825,
#  'Lee, Kuo Fen': 3.7124999999999995,
#  'La Spada, Albert': 4.5825,
#  'Reinagel, Pam': 3.4133333333333336,
#  'Kristan, William B.': 3.75,
#  'Todd, Krista L.': 3.513333333333333,
#  'Perks, Krista Eva': 3.14,
#  'Noto, Akana Elizabeth': 4.14,
#  'Clark, Dan': 4.8625,
#  'Ghiara, Jayant': 4.644285714285714,
#  'Huberman, Andrew David': 4.53,
#  'Berg, Darwin K.': 4.3025,
#  'Markow, Therese A.': 3.875,
#  'Wienhausen, Gabriele': 4.8180000000000005,
#  'Scanziani, Massimo': 4.3999999999999995,
#  'Scheffler, Immo E.': 4.154999999999999,
#  'Richmond, Maxi Polihronaki': 4.25,
#  'Schoetz, Eva-Maria': 4.67,
#  'Strum, Shirley C.': 4.15,
#  'Woodruff, David S': 4.407142857142857,
#  'Clemmons, Alexa Watson': 4.71,
#  'Emerson, Beverly Marie': 4.14,
#  'Jones, Katherine A.': 4.67,
#  'Brown, Willie C.': 4.395,
#  'Aroian, Raffi V.': 4.345000000000001,
#  'Sternfeld, Matthew J': 4.57,
#  'Marietou, Angeliki': 4.69,
#  'Gantner, Marin Leigh': 4.55,
#  'Pykalainen, Anette': 3.26,
#  'Price, Paul A.': 4.66,
#  'Curington, John Gibson': 4.525,
#  'Rypien, Krystal L': 4.403333333333333,
#  'Johnson, Tracy Lanise': 4.8149999999999995,
#  'Tam, Tobey M': 4.18,
#  'Trujillo, Gloriana V.': 3.41,
#  'Trial, Rachelle Marie': 4.31}

# %%
d = {'Proficiency of Material Means': prof_means1, 'Explaining Material Well Means': prof_means2}
df = pd.DataFrame(data=d)
df.to_csv('bio_means.csv')
